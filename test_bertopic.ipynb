# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# !pip install Elasticsearch
# Out:
# Requirement already satisfied: Elasticsearch in /usr/local/lib/python3.10/dist-packages (8.9.0)
# Requirement already satisfied: elastic-transport<9,>=8 in /usr/local/lib/python3.10/dist-packages (from Elasticsearch) (8.4.0)
# Requirement already satisfied: urllib3<2,>=1.26.2 in /usr/local/lib/python3.10/dist-packages (from elastic-transport<9,>=8->Elasticsearch) (1.26.16)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from elastic-transport<9,>=8->Elasticsearch) (2023.7.22)

# %%
import requests as req
import json
import xml.etree.ElementTree as ET
import itertools
import os
import argparse
import sys
sys.path.append('..')
# from biomedkg_utils import switch_dictset_to_dictlist
from elasticsearch import Elasticsearch
from multiprocessing import cpu_count, Process

# %%
def switch_dictset_to_dictlist(the_dict):
    '''
    FUNCTION:
    - Make a new dictionary with values as lists
      instead of values as sets

    PARAMS:
    - the_dict: The initial dict with values of sets
    '''

    dictlist = dict()

    for k in the_dict.copy():
        dictlist[k] = list(the_dict[k])

    return dictlist

# %%
def map_disease_mesh_name_to_id(mesh_desc_file = '../data/MeSH/desc2022.xml',
                                output_folder='../parsed_mappings/MeSH'):
    '''
    FUNCTION:
    - Map the disease MeSH names/terms to the
      MeSH IDs.
    '''
    print('Mapping MeSH disease names to IDs')
    tree = ET.parse(mesh_desc_file)
    root = tree.getroot()

    name2id = dict()

    for ele in root:
        try:
            # MeSH Tree Number
            tree_numbers = ele.find('TreeNumberList').findall('TreeNumber')

            # If Tree is a disease
            for tree_number in tree_numbers:
                if tree_number.text.startswith(('C','F03')):
                    tree_number = tree_number.text

                    # ID to Name
                    try:
                        ID = ele.find('DescriptorUI').text
                        name = ele.find('DescriptorName').find('String').text
                        name2id.setdefault(name,set()).add(ID)
                    except:
                        pass
        except:
            continue

    name2id = switch_dictset_to_dictlist(name2id)
    json.dump(name2id, open(os.path.join(output_folder,'name2id.json'),'w'))

# %%
def map_categories2terms(output_folder,
                         meshterms_per_cat_file='../parsed_mappings/MeSH/meshterms_per_cat.json',
                         category_names_file='../config/textcube_config.json'):
    '''
    FUNCTION:
    - Map disease categories -> MeSH terms
    '''
    print('Mapping disease categories to their terms and subcategory terms')
    terms_lol = json.load(open(meshterms_per_cat_file, 'r'))
    category_names = json.load(open(category_names_file, 'r'))
    category2terms = dict()
    for category_name, term_list in zip(category_names, terms_lol):
        category2terms[category_name] = term_list

    json.dump(category2terms,
              open(os.path.join(output_folder, 'category2terms.json'), 'w'))

    return category2terms

# %%
def get_mesh_synonyms_api(category2terms, name2id,
                          output_folder='../parsed_mappings/MeSH/'):
    '''
    FUNCTION:
    - Get MeSH synonyms via API
    '''
    category2synonyms = dict()
    total_categories = len(category2terms)
    for category_num, (category, terms) in enumerate(category2terms.items()):
        print(str(category_num) + '/' + str(total_categories), end='\r')

        # Terms in category
        for term in terms:

            mesh_id = name2id[term]
            assert len(mesh_id) == 1
            r_string = 'https://id.nlm.nih.gov/mesh/lookup/details?descriptor=' + mesh_id[0]
            r = req.get(r_string).json()

            # Add term synonyms to the category
            for entry in r['terms']:
                synonym = entry['label']
                category2synonyms.setdefault(category, set()).add(synonym)

    category2synonyms = switch_dictset_to_dictlist(category2synonyms)
    json.dump(category2synonyms,
              open(os.path.join(output_folder, 'category2synonyms.json'), 'w'))

    return category2synonyms

# %%
def permute_mesh_synonyms(mesh_synonyms):
    '''
    FUNCTION:
    - Permute MeSH synonyms

    PARAMS:
    - mesh_synonyms: list of mesh synonyms
    '''

    temp_mesh_synonyms = list()
    for mesh_synonym in mesh_synonyms:
        if ',' in mesh_synonym:
            mesh_synonym = mesh_synonym.split(', ')
            mesh_synonym_permuted = [' '.join(list(permuted_synonym)) for permuted_synonym in
                                     list(itertools.permutations(mesh_synonym))]
            temp_mesh_synonyms += mesh_synonym_permuted
        else:
            temp_mesh_synonyms.append(mesh_synonym)

    return temp_mesh_synonyms

# %%
def map_category_to_permuted_mesh_synonyms(category2synonyms,
                                           output_folder='../parsed_mappings/MeSH/'):
    '''
    FUNCTION:
    - permute the MeSH Synonyms because sometimes they're
      written weirdly with commas (e.g., Order, Messed, Up, Is;
      Messed, Order, Up)

    PARAMS:
    - category2synonyms: category -> MeSH synonyms mapping
    '''
    print('Mapping disease categories to permuted MeSH synonyms')

    # Permuted synonym->category dictionary
    category2permuted_synonyms, permuted_synonyms2category = dict(), dict()
    for category, synonyms in category2synonyms.items():
        synonyms = permute_mesh_synonyms(synonyms)
        for synonym in synonyms:
            category2permuted_synonyms.setdefault(category, set()).add(synonym)
            permuted_synonyms2category.setdefault(synonym, set()).add(category)

    category2permuted_synonyms = switch_dictset_to_dictlist(category2permuted_synonyms)
    permuted_synonyms2category = switch_dictset_to_dictlist(permuted_synonyms2category)

    json.dump(category2permuted_synonyms,
              open(os.path.join(output_folder, 'category2permuted_synonyms.json'), 'w'))
    json.dump(permuted_synonyms2category,
              open(os.path.join(output_folder, 'permuted_synonyms2category.json'), 'w'))

    return category2permuted_synonyms, permuted_synonyms2category

# %%
def get_all_uncategorized_pmids(index_name):
    '''
    FUNCTION:
    - Get the PMIDs of all the PubMed articles that
      don't have MeSH labels.
    - Purpose: For applying to unlabeled PubMed articles

    PARAMS:
    - index_name: The name of the ElasticSearch index
      where all the PubMed articles are indexed/stored
    '''

    es = Elasticsearch()
    relevant_uncategorized_pmids = set()
    for num_pmids, entry in enumerate(es_iterate_all_documents(es, index_name)):

        # Publication's MeSH (if any)
        unlabeled = (len(entry['MeSH']) == 0)

        # Save PMIDs of unlabeled documents
        if unlabeled:
            relevant_uncategorized_pmids.add(entry['pmid'])

            # Print progress
            if num_pmids % 10000 == 0:
                print(str(num_pmids) + ' PMIDs processed', end='\r')

    return list(relevant_uncategorized_pmids)

# %%
def get_document_text(entry):
    '''
    FUNCTION:
    - Get the full text of the PubMed publication

    PARAMS:
    - entry (dict): parsed indexed publication
    '''

    # Title
    title = entry['_source']['title']
    if type(title) != str:
        title = ''
    title.replace('\n', ' ').replace('\t', ' ').replace('   ', ' ')

    # Abstract
    abstract = entry['_source']['abstract']
    if type(abstract) != str:
        abstract = ''
    abstract.replace('\n', ' ').replace('\t', ' ').replace('   ', ' ')

    return abstract, title

# %%
def ds_label_matching(batch_id, relevant_pmid_batch,
                      index_name, index_type,
                      label_unlabeled_only,
                      label_labeled_only,
                      label_all,
                      filter_list,
                      stop_at_this_many_pmids,
                      run, test,
                      output_folder):
    '''
    FUNCTION:
    - Using MeSH term synonyms, label a document with a MeSH term if the
      lowercased term matches exactly within the text.

    PARAMS:
    - relevant_pmid_batch: PMIDs to look for in this batch
    - temp_outfile: temporary output file of PMID | MeSH Term
    '''
    es = Elasticsearch()
    if run:
        rot = 'run'
    elif test:
        rot = 'test'
    else:
        raise Except('Did not specify if running or testing')

    temp_outfile = os.path.join(output_folder, rot+'_temp_labeling'+str(batch_id)+'.txt')
    procs = cpu_count()
    category2permuted_synonyms = json.load(open(os.path.join(output_folder,'category2permuted_synonyms.json'),'r'))

    with open(temp_outfile,'w') as fout, \
    open(temp_outfile[:-4]+'synonym'+'.txt','w') as fout1:

        # Get PubMed article's text
        for num_pmids, pmid in enumerate(relevant_pmid_batch):
            entry = es.get(id = pmid, index = index_name, doc_type = index_type)

            # Print progress and break early
            if batch_id == 1 and num_pmids % 1000 == 0:
                print(str(num_pmids)+' PMIDs processed in one of the batches',\
                      end='\r')
            if num_pmids > stop_at_this_many_pmids/procs:
                break


            # Determine which publications to find labels for
            labeled_meshes = entry['_source']['MeSH']
            labeled = len(labeled_meshes) > 0
            unlabeled = len(labeled_meshes) == 0
            if label_labeled_only and labeled:
                pass
            elif label_unlabeled_only and unlabeled:
                pass
            elif label_all:
                pass
            else:
                continue


            # Publication's text (title, abstract, full text if provided)
            abstract, title = get_document_text(entry)
            document_text = title + ' ' + abstract
            title = ' '+title+' '
            title = title.replace(',',' ')
            title = title.replace(':',' ')

            # Only consider documents that have certain broader key words
            # E.g., for cardiovascular disease publications, only look
            # at publications that say "heart" or "cardiac"
            #dont_label = True
            #for filter_word in filter_words:
            #    if filter_word in document_text.lower():
            #        dont_label = False
            #        break
            #if dont_label:
            #    continue

            #print(dont_label, 'dont_label')

            #fout.write(title+' | '+'ignore'+'\n')

            # Check if MeSH synonym is in the text
            for category, synonyms in category2permuted_synonyms.copy().items():
                found_syns = set()
                one_syn_in_title = False

                # Each synonym in a set category
                for synonym in synonyms:

                    # Synonym in title
                    if ' '+synonym.lower()+' ' in title.lower():
                        one_syn_in_title = True
                        found_syns.add(synonym)
                        #continue

                    # Synonym in abstract

                    if synonym.lower() in abstract.lower():
                        add = True

                        # If similar synonym hasn't been counted already
                        for found_syn in found_syns:
                            fsyn = found_syn.lower().replace('\'','')
                            syn = synonym.lower()
                            if fsyn in syn or syn in fsyn:
                                add = False
                                break
                        if add:
                            found_syns.add(synonym)

                    # Categorize text with 1+ synonym per category in the text
                    # (This could be modified to include confidence levels for
                    #  how many synonyms were found, remove break then)
                    if one_syn_in_title or len(found_syns) > 1:
                        #print(pmid, category, found_syns)
                        fout.write(pmid+'|'+category+'\n')
                        fout1.write(pmid+'|'+synonym+'\n')
                        break

        try:
            print(str(num_pmids)+' PMIDs processed in one of the batches')
        except:
            # Not enough PMIDs to require doing all the batches
            pass

# %%
def multiprocess_ds_label_matching(pmids, index_name, index_type,
                                   label_unlabeled_only,
                                   label_labeled_only,
                                   label_all,
                                   filter_list,
                                   the_function,
                                   stop_at_this_many_pmids,
                                   run = False,
                                   test = False,
                                   output_folder='../parsed_mappings/MeSH/'):
    '''
    FUNCTION:
    - This takes a list of strings and splits it into input
      for separate processes. The processes then output
      their results to temp files which are then merged.

    PARARMS:
    - pmids: the list to be split into input for
      a multiprocessing function
    - the_function: the function that will use the list
      as input for multiprocessing
    '''
    # How many processors can be used
    procs = cpu_count() if len(pmids) > cpu_count() else len(pmids)

    # List of batches for multiprocessing
    batches = [[] for i in range(procs)]

    # Length of input list
    tot = len(pmids)

    # Create batches and send to multiprocessing
    for i, item in enumerate(pmids):

        # Add synonym to a batch
        b_id = i%procs
        batches[b_id].append(item)

    # Create a list of jobs
    print("Running jobs...")
    jobs = []
    for b_id, batch in enumerate(batches):
        jobs.append(Process(target = the_function,
                            args = [b_id, batch,
                                    index_name, index_type,
                                    label_unlabeled_only,
                                    label_labeled_only,
                                    label_all,
                                    filter_list,
                                    stop_at_this_many_pmids,
                                    run, test, output_folder]))

    # Run the jobs
    for j in jobs: j.start()
    for j in jobs: j.join()
    print('Done!')

# %%
def merge_pmid2new_mesh_labels(run=False, test=False, output_folder = '../parsed_mappings/MeSH/'):
    '''
    FUNCTION:
    - Merges the separate files containing PMID|category_name
      for the imputed category_name labels.
    '''

    pmid2imputed_meshsynonym, pmid2imputed_category = dict(), dict()
    procs = cpu_count()
    if run:
        rot = 'run'
    elif test:
        rot = 'test'

    for batch_id in range(procs):
        ''' PMID - MeSH Category '''
        temp_outfile = os.path.join(output_folder, rot+'_temp_labeling'+str(batch_id)+'.txt')
        with open(temp_outfile) as fin:
            for line in fin:
                line = line.split('|')

                # PMID, MeSH
                assert len(line) == 2
                pmid = line[0]
                mesh = line[1].strip()

                # PMID->MeSH
                pmid2imputed_category.setdefault(pmid, set()).add(mesh)

        ''' PMID - MeSH Synonym '''
        with open(temp_outfile[:-4]+'synonym'+'.txt') as fin1:
            for line in fin1:
                line = line.split('|')

                # PMID, MeSH
                assert len(line) == 2
                pmid = line[0]
                mesh = line[1].strip()

                # PMID->MeSH
                pmid2imputed_meshsynonym.setdefault(pmid, set()).add(mesh)

    pmid2imputed_category = switch_dictset_to_dictlist(pmid2imputed_category)
    pmid2imputed_meshsynonym = switch_dictset_to_dictlist(pmid2imputed_meshsynonym)
    print(len(pmid2imputed_category), 'PMIDs with imputed labels')

    # Export PMID-Category mappings to dictionaries
    json.dump(pmid2imputed_category,
              open(os.path.join(output_folder, 'pmid2imputed_category.json'), 'w'))
    json.dump(pmid2imputed_meshsynonym,
              open(os.path.join(output_folder, 'pmid2imputed_mesh_synonym.json'), 'w'))

    return pmid2imputed_category, pmid2imputed_meshsynonym

# %%
def index_imputed_mesh_categories(index_name, index_type):
    '''
    FUNCTION:
    - index the imputed MeSH categories as MeSH terms
      in the ElasticSearch index

    PARAMS:
    - index_name: Name of the ElasticSearch index
    - index_type: Type name of the ElastichSearch index
    '''

    es = Elasticsearch()
    for pmid, imputed_category in pmid2imputed_category.items():

        # Get current MeSH terms
        entry = es.get(id = pmid,
                       index = index_name,
                       doc_type = index_type)
        mesh_terms = entry['_source']['MeSH']
        mesh_terms += imputed_category
        mesh_terms = list(set(mesh_terms))

        # Update each publication's index
        es.update(index = index_name,
                  id = pmid,
                  doc_type = index_type,
                  doc = {'MeSH': mesh_terms})

# %%
def update_textcube_files(data_folder='../data/',
                          config_folder='../config/',
                          parsed_mapping_folder='../parsed_mappings'):
    '''
    FUNCTION:
    - Add category names to the considered MeSH Terms
    - Add pmid-category to pmid2category mapping files
    '''
    meshterms_per_cat = json.load(open(os.path.join(mapping_folder, 'MeSH/meshterms_per_cat.json'), 'r'))
    meshterms_per_cat = [set(meshlist) for meshlist in meshterms_per_cat]

    category_names = json.load(open(os.path.join(config_folder, 'textcube_config.json'), 'r'))

    for i in range(0, len(category_names)):
        meshterms_per_cat[i].add(category_names[i])
    meshterms_per_cat = [list(meshlist) for meshlist in meshterms_per_cat]
    json.dump(meshterms_per_cat, open(os.path.join(mapping_folder, 'MeSH/meshterms_per_cat.json'), 'w'))

    textcube_pmid2category = json.load(open(os.path.join(data_folder, 'textcube_pmid2category.json'), 'r'))
    textcube_category2pmid = json.load(open(os.path.join(data_folder, 'textcube_category2pmid.json'), 'r'))

    ''' Update textcube_category2pmid '''
    category_names = json.load(open(os.path.join(config_folder, 'textcube_config.json'), 'r'))
    category_name2num = {name: num for num, name in enumerate(category_names)}

    for pmid, imputed_categories in pmid2imputed_category.items():
        for imputed_category in imputed_categories:
            cat_num = category_name2num[imputed_category]
            textcube_category2pmid[cat_num].append(pmid)

    for i in range(0, len(textcube_category2pmid)):
        textcube_category2pmid[i] = list(set(textcube_category2pmid[i]))

    ''' Update textcube_pmid2category '''
    new_textcube_pmid2category = list()
    for cat_num, pmid_list in enumerate(textcube_category2pmid):
        for pmid in pmid_list:
            new_textcube_pmid2category.append([pmid, cat_num])

    json.dump(new_textcube_pmid2category, open(os.path.join(data_folder, 'textcube_pmid2category.json'), 'w'))
    json.dump(textcube_category2pmid, open(os.path.join(data_folder, 'textcube_category2pmid.json'), 'w'))

# %%
def get_all_categorized_pmids(index_name, outpath):
    '''
    FUNCTION:
    - Get the PMIDs of all the PubMed articles that
      don't have MeSH labels.
    - Purpose: For applying to unlabeled PubMed articles

    PARAMS:
    - index_name: The name of the ElasticSearch index
      where all the PubMed articles are indexed/stored
    - outpath: Where the categorized PMIDs will go.
    '''

    es = Elasticsearch()
    relevant_categorized_pmids = set()
    for num_pmids, entry in enumerate(es_iterate_all_documents(es, index_name)):

        # Publication's MeSH (if any)
        labeled = (len(entry['MeSH']) > 0)

        # Save PMIDs of unlabeled documents
        if labeled:
            relevant_categorized_pmids.add(entry['pmid'])

            # Print progress
            if num_pmids % 10000 == 0:
                print(str(num_pmids) + ' PMIDs processed', end='\r')

    relevant_categorized_pmids = list(relevant_categorized_pmids)
    json.dump(relevant_categorized_pmids, open(outpath + 'relevant_categorized_pmids.json', 'w'))

# %%
def get_groundtruth_pmid2categories(relevant_pmid_batch, index_name,
                                    index_type, permuted_synonyms2category):
    '''
    FUNCTION:
    - This gets the ground truth labels, the MeSH-labeled PubMed documents

    PARAMS:
    - relevant_pmid_batch: This is the list of the PubMed IDs you want to
      get ground truth for
    - index_name: name of the ElasticSearch index
    - index_type: name of the type of ElasticSearch index
    - permuted_synonyms2category: MeSH synonyms -> category
    '''
    pmids2real_categories = dict()
    es = Elasticsearch()
    total_pmids = len(relevant_pmid_batch)

    for num_pmids, pmid in enumerate(relevant_pmid_batch):
        if num_pmids % 10000 == 0:
            print('Getting real mappings' + str(num_pmids)+'/'+str(total_pmids),\
                  end='\r')
        entry = es.get(id = pmid, index = index_name, doc_type = index_type)
        pmids2real_categories[pmid] = set()

        # Publication's MeSH (if any)
        meshes = entry['_source']['MeSH']
        for mesh in meshes:
            try:
                categories = permuted_synonyms2category[mesh]
                for category in categories:
                    pmids2real_categories[pmid].add(category)
            except:
                pass
    pmids2real_categories = switch_dictset_to_dictlist(pmids2real_categories)
    return pmids2real_categories

# %%
def evaluate_label_imputation(pmid2imputed_category, pmid2real_categories):
    tp, fp, tn, fn = 0,0,0,0

    for pmid in pmid2real_categories:
        real_categories = pmid2real_categories[pmid]
        try: imputed_categories = pmid2imputed_category[pmid]
        except: imputed_categories = []
        real_and_imputed = real_categories + imputed_categories

        for category in real_and_imputed:
            #print(real_and_imputed)
            #print(real_categories)
            #print(imputed_categories)

            # Real = Yes
            if category in real_categories:

                # Real = Yes, Impute = Yes
                if category in imputed_categories:
                    tp += 1

                # Real = Yes, Impute = No
                else:
                    fn += 1

            elif category not in real_categories:

                # Real = No, Impute = Yes
                if category in imputed_categories:
                    fp += 1

    print('Precision', round(tp/(tp+fp), 4))
    print('Recall', round(tp/(tp+fn), 4))
    print('TP', tp, 'FP', fp, 'FN',fn)

# %%
index_name = 'pubmed_lift'
index_type = 'pubmed_meta_lift'
undo_category_label_imputation = False
undo_last_category_label_imputation_only = False
label_imputation = True
run = True
test = False

if undo_category_label_imputation:
    label_imputation = False

if test == True:
    run = False
STOP_AT_THIS_MANY_PMIDS = 9999999999
filter_words = ['placeholder', 'these arent used anymore']

# %%
root_directory = '../'
data_folder=os.path.join(root_directory,"data")
config_folder=os.path.join(root_directory,"config")
mapping_folder=os.path.join(root_directory,"parsed_mappings")
output_folder = os.path.join(mapping_folder,'Output')

# %%
''' Label imputation '''
if label_imputation:

    '''Map MeSH ID - Name'''
    map_disease_mesh_name_to_id()


    meshterms_per_cat_file = os.path.join(mapping_folder,'MeSH/meshterms_per_cat.json')
    category_names_file = os.path.join(config_folder,'textcube_config.json')

    ''' Get MeSH Synonyms '''
    # Category - MeSH Terms
    category2main_terms = map_categories2terms(output_folder = output_folder,
                            meshterms_per_cat_file = meshterms_per_cat_file,
                            category_names_file = category_names_file)

    # Category - MeSH Terms' Synonyms (including terms)
    name2id = json.load(open(os.path.join(mapping_folder,'MeSH/meshterm-IS-meshid.json'),'r'))
    category2main_terms = json.load(open(os.path.join(mapping_folder, 'MeSH/category2terms.json')))
    try:  category2synonym_terms = json.load(open(os.path.join(mapping_folder,'MeSH/category2synonyms.json')))
    except: category2synonym_terms = get_mesh_synonyms_api(category2main_terms, name2id,output_folder=output_folder)

    # Category - permuted MeSH Terms' Synonyms
    temp1, temp2 =  map_category_to_permuted_mesh_synonyms(category2synonym_terms,output_folder=output_folder)
    category2permuted_synonyms = temp1
    permuted_synonyms2category = temp2

# %%
if run:
    print('Running label imputation')
    '''Undo last label imputation'''
    try:
        pmid2imp_cat_path = os.path.join(mapping_folder,'MeSH/pmid2imputed_category.json')
        pmid2imputed_category = json.load(open(pmid2imp_cat_path))
        try:
            print('Removing the labels imputed last time')
            remove_imputed_category_mesh_terms_previous_li(index_name,
                                                           index_type,
                                                           pmid2imputed_category)
        except:
            raise Exception('Couldnt remove the last indexed imputed labels')
    except:
        print('No previous label imputation')
    '''Get relevant PMIDs'''
    try:
        relevant_pmids = json.load(open(data_folder+'all_uncategorized_pmids.json'))
    except:
        relevant_pmids = get_all_uncategorized_pmids(index_name)
    json.dump(relevant_pmids, open(os.path.join(data_folder,'all_uncategorized_pmids.json'),'w'))

    print(len(relevant_pmids), 'relevant pmids')

    ''' Impute missing MeSH labels '''
    # Impute PMIDs' Categories (i.e., Impute missing MeSH labels)
    multiprocess_ds_label_matching(pmids = relevant_pmids,
                                   index_name = index_name,
                                   index_type = index_type,
                                   label_unlabeled_only = True,
                                   label_labeled_only = False,
                                   label_all = False,
                                   filter_list = filter_words,
                                   stop_at_this_many_pmids = STOP_AT_THIS_MANY_PMIDS,
                                   the_function = ds_label_matching,
                                   output_folder = output_folder,
                                   run = True)
    pmid2imputed_category, pmid2imputed_meshsynonym = merge_pmid2new_mesh_labels(run=True,output_folder=output_folder)
    # Index the imputed MeSH categories into their PMID entries
    # index_imputed_mesh_categories(index_name=index_name, index_type=index_type)
    # Update the MeSH Terms Per Category file for the textcube
    # update_textcube_files(data_folder=data_folder, config_folder=config_folder, parsed_mapping_folder=mapping_folder)

# %%
if test:
    print('Testing label imputation')

    '''Get relevant PMIDs'''
    # Ground truth: PMIDs in your study already labeled by NIH with MeSH terms
    #relevant_pmids = json.load(open('../caseolap/data/pmids.json'))
    try:
        relevant_pmids = json.load(open(data_folder+'/relevant_categorized_pmids.json'))
    except:
        relevant_pmids_path = data_folder+'/relevant_categorized_pmids.json'
        relevant_pmids = get_all_categorized_pmids('pubmed_lift', relevant_pmids_path)
        json.dump(relevant_pmids, open(relevant_pmids_path, 'w'))
    ''' Impute missing MeSH labels '''
    # Impute PMIDs' Categories (i.e., Impute missing MeSH labels)
    multiprocess_ds_label_matching(pmids = relevant_pmids,
                                   index_name = index_name,
                                   index_type = index_type,
                                   label_unlabeled_only = False,
                                   label_labeled_only = True,
                                   label_all = False,
                                   filter_list = filter_words,
                                   stop_at_this_many_pmids = STOP_AT_THIS_MANY_PMIDS,
                                   the_function = ds_label_matching,
                                   test = True)
    pmid2imputed_category, pmid2imputed_meshsynonym = merge_pmid2new_mesh_labels(test=True)
    # PMID - Ground Truth Categories
    try:
        pmid2real_categories = json.load(open(output_folder+'/pmid2real_categories.json'))
    except:
        pmid2real_categories = ['']
    if len(pmid2real_categories) != STOP_AT_THIS_MANY_PMIDS:
        pmid2real_categories = get_groundtruth_pmid2categories(relevant_pmids, index_name, index_type, permuted_synonyms2category)
        json.dump(pmid2real_categories, open(output_folder+'/pmid2real_categories.json','w'))
    # Evaluate results on ground truth
    evaluate_label_imputation(pmid2imputed_category, pmid2real_categories)

# %% [markdown]
# # Start of exploration

# %%
import requests as req
import json
import xml.etree.ElementTree as ET
import itertools
import os
import argparse
import sys
sys.path.append('..')
from utils.biomedkg_utils import switch_dictset_to_dictlist
from elasticsearch import Elasticsearch
from multiprocessing import cpu_count, Process

# %%
def es_iterate_all_documents(es, index, pagesize=250, scroll_timeout="1m", **kwargs):
    """
    Helper to iterate ALL values from a single index
    Yields all the documents.
    Source: https://techoverflow.net/2019/05/07/elasticsearch-how-to-iterate-scroll-through-all-documents-in-index/
    """
    is_first = True
    while True:
        # Scroll next
        if is_first: # Initialize scroll
            result = es.search(index=index, scroll="1m", **kwargs,
                               size = pagesize)
            is_first = False
        else:
            result = es.scroll(
                scroll_id = scroll_id,
                scroll = scroll_timeout)
        scroll_id = result["_scroll_id"]
        hits = result["hits"]["hits"]

        # Stop after no more docs
        if not hits:
            break

        # Yield each entry
        yield from (hit['_source'] for hit in hits)

# %%
def get_pmids(index_name):
    '''
    Get the PMIDs of the PubMed articles that have/don't have MeSH labels or full text
    '''

    es = Elasticsearch()
    uncategorized_pmids = list()
    categorized_pmids = list()
    uncate_text_pmids = list()
    cate_text_pmids = list()
    for num_pmids, entry in enumerate(es_iterate_all_documents(es, index_name)):

        # Publication's MeSH (if any)
        unlabeled = (len(entry['MeSH']) == 0)

        # Save PMIDs
        if unlabeled:
            uncategorized_pmids.append(entry['pmid'])
        else:
            categorized_pmids.append(entry['pmid'])

        # has full text or not
        has_full_text = (len(entry['full_text']) > 0)

        if has_full_text:
            if unlabeled:
                uncate_text_pmids.append(entry['pmid'])
            else:
                cate_text_pmids.append(entry['pmid'])

        # Print progress
        if num_pmids % 10000 == 0:
            print(str(num_pmids) + ' PMIDs processed', end='\r')

    return list(set(uncategorized_pmids)), list(set(categorized_pmids)), list(set(uncate_text_pmids)), list(set(cate_text_pmids))

# %%
uncate_pmids, cate_pmids, text_pmids = get_pmids(index_name)

# %%
def get_groundtruth_pmid2categories(relevant_pmid_batch, index_name,
                                    index_type, permuted_synonyms2category):
    '''
    FUNCTION:
    - This gets the ground truth labels, the MeSH-labeled PubMed documents

    PARAMS:
    - relevant_pmid_batch: This is the list of the PubMed IDs you want to
      get ground truth for
    - index_name: name of the ElasticSearch index
    - index_type: name of the type of ElasticSearch index
    - permuted_synonyms2category: MeSH synonyms -> category
    '''
    pmids2real_categories = dict()
    es = Elasticsearch()
    total_pmids = len(relevant_pmid_batch)

    for num_pmids, pmid in enumerate(relevant_pmid_batch):
        if num_pmids % 10000 == 0:
            print('Getting real mappings' + str(num_pmids)+'/'+str(total_pmids),\
                  end='\r')
        entry = es.get(id = pmid, index = index_name, doc_type = index_type)
        pmids2real_categories[pmid] = list()

        # Publication's MeSH (if any)
        meshes = entry['_source']['MeSH']
        for mesh in meshes:
            try:
                categories = permuted_synonyms2category[mesh]
                pmids2real_categories[pmid] = list(set(pmids2real_categories[pmid] + categories))
            except:
                pass

    pmids2real_categories = switch_dictset_to_dictlist(pmids2real_categories)
    return pmids2real_categories

# %%
pmid2cate = get_groundtruth_pmid2categories(all_doc_pmids, index_name, index_type, permuted_synonyms2category)

# %%
import sys
# sys.path.append('/home/ubuntu/InternProjects/Joanne/caseolap_lift/data')

cat = open('/home/ubuntu/InternProjects/Joanne/caseolap_lift/data/relevant_categorized_pmids.json')
categorized_pmids = json.load(cat)

uncat = open('/home/ubuntu/InternProjects/Joanne/caseolap_lift/data/all_uncategorized_pmids.json')
uncategorized_pmids = json.load(uncat)

cat.close()
uncat.close()

# %%
pmids = categorized_pmids + uncategorized_pmids

# %%
len(pmids)

# %%
def generate_ctg2pmid(cat_pmids, uncat_pmids, all_pmids):
    '''
    generate a dictionary with categories as keys and pmids as values
    '''

    ctg2pmid = {'None': uncat_pmids}

    for num, key in enumerate(cat_pmids):

        # Print progress
        if num % 10000 == 0:
            print(str(num) + ' PMIDs processed', end='\r')

        if key in all_pmids:
            tags = all_pmids[key]
            if tags:
                for tag in tags:
                    if tag in ctg2pmid:
                        ctg2pmid[tag].append(key)
                    else:
                        ctg2pmid[tag] = [key]

    return ctg2pmid

# %% [markdown]
# # BERTopic quick start

# %%
! pip install bertopic
# Out:
# Collecting bertopic
#   Downloading bertopic-0.15.0-py2.py3-none-any.whl (143 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 143.4/143.4 kB 3.8 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.20.0 in /usr/local/lib/python3.10/dist-packages (from bertopic) (1.23.5)
# Collecting hdbscan>=0.8.29 (from bertopic)
#   Downloading hdbscan-0.8.33.tar.gz (5.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.2/5.2 MB 27.8 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting umap-learn>=0.5.0 (from bertopic)
#   Downloading umap-learn-0.5.3.tar.gz (88 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 88.2/88.2 kB 9.8 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: pandas>=1.1.5 in /usr/local/lib/python3.10/dist-packages (from bertopic) (1.5.3)
# Requirement already satisfied: scikit-learn>=0.22.2.post1 in /usr/local/lib/python3.10/dist-packages (from bertopic) (1.2.2)
# Requirement already satisfied: tqdm>=4.41.1 in /usr/local/lib/python3.10/dist-packages (from bertopic) (4.66.1)
# Collecting sentence-transformers>=0.4.1 (from bertopic)
#   Downloading sentence-transformers-2.2.2.tar.gz (85 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.0/86.0 kB 11.6 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: plotly>=4.7.0 in /usr/local/lib/python3.10/dist-packages (from bertopic) (5.15.0)
# Collecting cython<3,>=0.27 (from hdbscan>=0.8.29->bertopic)
#   Using cached Cython-0.29.36-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.manylinux_2_24_x86_64.whl (1.9 MB)
# Requirement already satisfied: scipy>=1.0 in /usr/local/lib/python3.10/dist-packages (from hdbscan>=0.8.29->bertopic) (1.11.2)
# Requirement already satisfied: joblib>=1.0 in /usr/local/lib/python3.10/dist-packages (from hdbscan>=0.8.29->bertopic) (1.3.2)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.1.5->bertopic) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.1.5->bertopic) (2023.3.post1)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from plotly>=4.7.0->bertopic) (8.2.3)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from plotly>=4.7.0->bertopic) (23.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.22.2.post1->bertopic) (3.2.0)
# Collecting transformers<5.0.0,>=4.6.0 (from sentence-transformers>=0.4.1->bertopic)
#   Downloading transformers-4.33.1-py3-none-any.whl (7.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.6/7.6 MB 70.4 MB/s eta 0:00:00
# Requirement already satisfied: torch>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from sentence-transformers>=0.4.1->bertopic) (2.0.1+cu118)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.10/dist-packages (from sentence-transformers>=0.4.1->bertopic) (0.15.2+cu118)
# Requirement already satisfied: nltk in /usr/local/lib/python3.10/dist-packages (from sentence-transformers>=0.4.1->bertopic) (3.8.1)
# Collecting sentencepiece (from sentence-transformers>=0.4.1->bertopic)
#   Downloading sentencepiece-0.1.99-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 74.7 MB/s eta 0:00:00
# Collecting huggingface-hub>=0.4.0 (from sentence-transformers>=0.4.1->bertopic)
#   Downloading huggingface_hub-0.17.1-py3-none-any.whl (294 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 294.8/294.8 kB 33.4 MB/s eta 0:00:00
# Requirement already satisfied: numba>=0.49 in /usr/local/lib/python3.10/dist-packages (from umap-learn>=0.5.0->bertopic) (0.56.4)
# Collecting pynndescent>=0.5 (from umap-learn>=0.5.0->bertopic)
#   Downloading pynndescent-0.5.10.tar.gz (1.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 72.1 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.4.0->sentence-transformers>=0.4.1->bertopic) (3.12.2)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.4.0->sentence-transformers>=0.4.1->bertopic) (2023.6.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.4.0->sentence-transformers>=0.4.1->bertopic) (2.31.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.4.0->sentence-transformers>=0.4.1->bertopic) (6.0.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.4.0->sentence-transformers>=0.4.1->bertopic) (4.5.0)
# Requirement already satisfied: llvmlite<0.40,>=0.39.0dev0 in /usr/local/lib/python3.10/dist-packages (from numba>=0.49->umap-learn>=0.5.0->bertopic) (0.39.1)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from numba>=0.49->umap-learn>=0.5.0->bertopic) (67.7.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.1->pandas>=1.1.5->bertopic) (1.16.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.6.0->sentence-transformers>=0.4.1->bertopic) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.6.0->sentence-transformers>=0.4.1->bertopic) (3.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.6.0->sentence-transformers>=0.4.1->bertopic) (3.1.2)
# Requirement already satisfied: triton==2.0.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.6.0->sentence-transformers>=0.4.1->bertopic) (2.0.0)
# Requirement already satisfied: cmake in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch>=1.6.0->sentence-transformers>=0.4.1->bertopic) (3.27.4.1)
# Requirement already satisfied: lit in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch>=1.6.0->sentence-transformers>=0.4.1->bertopic) (16.0.6)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers<5.0.0,>=4.6.0->sentence-transformers>=0.4.1->bertopic) (2023.6.3)
# Collecting tokenizers!=0.11.3,<0.14,>=0.11.1 (from transformers<5.0.0,>=4.6.0->sentence-transformers>=0.4.1->bertopic)
#   Downloading tokenizers-0.13.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (7.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 72.8 MB/s eta 0:00:00
# Collecting safetensors>=0.3.1 (from transformers<5.0.0,>=4.6.0->sentence-transformers>=0.4.1->bertopic)
#   Downloading safetensors-0.3.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 60.1 MB/s eta 0:00:00
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from nltk->sentence-transformers>=0.4.1->bertopic) (8.1.7)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.10/dist-packages (from torchvision->sentence-transformers>=0.4.1->bertopic) (9.4.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.6.0->sentence-transformers>=0.4.1->bertopic) (2.1.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.4.0->sentence-transformers>=0.4.1->bertopic) (3.2.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.4.0->sentence-transformers>=0.4.1->bertopic) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.4.0->sentence-transformers>=0.4.1->bertopic) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.4.0->sentence-transformers>=0.4.1->bertopic) (2023.7.22)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.6.0->sentence-transformers>=0.4.1->bertopic) (1.3.0)
# Building wheels for collected packages: hdbscan, sentence-transformers, umap-learn, pynndescent
#   Building wheel for hdbscan (pyproject.toml) ... done
#   Created wheel for hdbscan: filename=hdbscan-0.8.33-cp310-cp310-linux_x86_64.whl size=3039167 sha256=dedf895cee5560176be2ad9037efbc0360b40e34a23406a86bae921bbd74e813
#   Stored in directory: /root/.cache/pip/wheels/75/0b/3b/dc4f60b7cc455efaefb62883a7483e76f09d06ca81cf87d610
#   Building wheel for sentence-transformers (setup.py) ... done
#   Created wheel for sentence-transformers: filename=sentence_transformers-2.2.2-py3-none-any.whl size=125923 sha256=1bfd2ce7dcc7c4740269571d27ef459b1c82bf022afec42e600406db3112cf7c
#   Stored in directory: /root/.cache/pip/wheels/62/f2/10/1e606fd5f02395388f74e7462910fe851042f97238cbbd902f
#   Building wheel for umap-learn (setup.py) ... done
#   Created wheel for umap-learn: filename=umap_learn-0.5.3-py3-none-any.whl size=82807 sha256=f2433c0f650f8ebe8c0d8d7866b6f6d19f62ef2a1f475467a96175e175c3c384
#   Stored in directory: /root/.cache/pip/wheels/a0/e8/c6/a37ea663620bd5200ea1ba0907ab3c217042c1d035ef606acc
#   Building wheel for pynndescent (setup.py) ... done
#   Created wheel for pynndescent: filename=pynndescent-0.5.10-py3-none-any.whl size=55615 sha256=508a6f97211c00e69a14bd7a4d988fe0ab262e7e54480317690db97f403d5a02
#   Stored in directory: /root/.cache/pip/wheels/4a/38/5d/f60a40a66a9512b7e5e83517ebc2d1b42d857be97d135f1096
# Successfully built hdbscan sentence-transformers umap-learn pynndescent
# Installing collected packages: tokenizers, sentencepiece, safetensors, cython, huggingface-hub, transformers, pynndescent, hdbscan, umap-learn, sentence-transformers, bertopic
#   Attempting uninstall: cython
#     Found existing installation: Cython 3.0.2
#     Uninstalling Cython-3.0.2:
#       Successfully uninstalled Cython-3.0.2
# Successfully installed bertopic-0.15.0 cython-0.29.36 hdbscan-0.8.33 huggingface-hub-0.17.1 pynndescent-0.5.10 safetensors-0.3.3 sentence-transformers-2.2.2 sentencepiece-0.1.99 tokenizers-0.13.3 transformers-4.33.1 umap-learn-0.5.3

# %%
from bertopic import BERTopic
from sklearn.datasets import fetch_20newsgroups

docs = fetch_20newsgroups(subset='all',  remove=('headers', 'footers', 'quotes'))['data']

topic_model = BERTopic()
topics, probs = topic_model.fit_transform(docs)
# Out:
# Downloading (…)e9125/.gitattributes:   0%|          | 0.00/1.18k [00:00<?, ?B/s]
# Downloading (…)_Pooling/config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]
# Downloading (…)7e55de9125/README.md:   0%|          | 0.00/10.6k [00:00<?, ?B/s]
# Downloading (…)55de9125/config.json:   0%|          | 0.00/612 [00:00<?, ?B/s]
# Downloading (…)ce_transformers.json:   0%|          | 0.00/116 [00:00<?, ?B/s]
# Downloading (…)125/data_config.json:   0%|          | 0.00/39.3k [00:00<?, ?B/s]
# Downloading pytorch_model.bin:   0%|          | 0.00/90.9M [00:00<?, ?B/s]
# Downloading (…)nce_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# Downloading (…)cial_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# Downloading (…)e9125/tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# Downloading (…)okenizer_config.json:   0%|          | 0.00/350 [00:00<?, ?B/s]
# Downloading (…)9125/train_script.py:   0%|          | 0.00/13.2k [00:00<?, ?B/s]
# Downloading (…)7e55de9125/vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# Downloading (…)5de9125/modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]

# %%
topic_model.get_topic_info()
# Out:
#      Topic  Count                                      Name  \
# 0       -1   6547                          -1_to_is_the_and
# 1        0   1830                      0_game_team_games_he
# 2        1    619             1_key_clipper_chip_encryption
# 3        2    527                      2_ites_cheek_yep_huh
# 4        3    471                3_israel_israeli_jews_arab
# ..     ...    ...                                       ...
# 214    213     10  213_crohns_inflammation_patients_colitis
# 215    214     10               214_slip_packet_0x60_driver
# 216    215     10                   215_disks_ibm_3m_boxies
# 217    216     10       216_space_astronaut_nasa_candidates
# 218    217     10             217_alarm_sensor_alarms_viper
#
#                                         Representation  \
# 0       [to, is, the, and, for, of, you, in, it, that]
# 1    [game, team, games, he, players, season, hocke...
# 2    [key, clipper, chip, encryption, keys, escrow,...
# 3    [ites, cheek, yep, huh, ken, ignore, forget, w...
# 4    [israel, israeli, jews, arab, jewish, arabs, p...
# ..                                                 ...
# 214  [crohns, inflammation, patients, colitis, fatt...
# 215  [slip, packet, 0x60, driver, goto, cslipper, p...
# 216  [disks, ibm, 3m, boxies, quarenteed, st412, se...
# 217  [space, astronaut, nasa, candidates, aerospace...
# 218  [alarm, sensor, alarms, viper, shock, car, alp...
#
#                                    Representative_Docs
# 0    [->\tFirst I want to start right out and say t...
# 1    [\nNo.  Patrick Roy is the reason the game was...
# 2    [[An article from comp.org.eff.news, EFFector ...
# 3    [\nHuh?, \n \n                                ...
# 4    [From: Center for Policy Research <cpr>\nSubje...
# ..                                                 ...
# 214  [One thing that I haven't seen in this thread ...
# 215  [\n\n\nThey are working ok, but your definitio...
# 216  [I have a few the original IBM 10Mb harddisks ...
# 217  [I am looking for any information about the sp...
# 218  [\n\nAlthough, others have in the past and wil...
#
# [219 rows x 5 columns]

# %%
data = fetch_20newsgroups(subset='all',  remove=('headers', 'footers', 'quotes'))
docs = data["data"]
categories = data["target"]
category_names = data["target_names"]

# %%
categories

# %%
docs

# %%
len(','.join(docs))

# %%
len(docs)

# %%
sum([len(x) for x in docs])/len(docs)

# %%
topic_model.get_topic_info()

# %%
df = topic_model.get_topic_info()

# %%
df_docs = topic_model.get_document_info(docs)

# %%
len(df_docs[df_docs['Topic'] == 0])

# %%
topic_model.get_topic(0)

# %%
topic_model.get_document_info(docs)

# %%
topic_model.visualize_topics()

# %% [markdown]
# TO-DO:
# 1. build a data loader:
#    - parameters: include_abstract = True, include_title = True, include_full_text = False, max_docs_per_category = 1000
#    - keys: data, labels (-1, 0, 1,...), name (CVD1, CVD2, ...)
#    - return: a dict

# %%
import json
ctg2pmid = json.load(open('gdrive/MyDrive/bertopic/caseolap_lift/text_mining/ctg2pmid.json'))

# %%
ctg2pmid

# %%
index_name = 'pubmed_lift'
index_type = 'pubmed_meta_lift'

# %%
def sample_publications(pmids, size=80, sample_prop='', use_prop_sampling = False):
    '''
    return a sample given the sample size
    '''

    sample = {}

    if not use_prop_sampling:
        n = int(size/8)
        for key in pmids:
            if key != 'None':
                sample[key] = random.sample(pmids[key], n)
    else:
        for key in pmids:
            if key != 'None':
                n = int(size*sample_prop[key])
                sample[key] = random.sample(pmids[key], n)

    return sample

# %%
for num_pmids, pmid in enumerate(relevant_pmid_batch):
            entry = es.get(id = pmid, index = index_name, doc_type = index_type)

            # Print progress and break early
            if batch_id == 1 and num_pmids % 1000 == 0:
                print(str(num_pmids)+' PMIDs processed in one of the batches',\
                      end='\r')
            if num_pmids > stop_at_this_many_pmids/procs:
                break


            # Determine which publications to find labels for
            labeled_meshes = entry['_source']['MeSH']
            labeled = len(labeled_meshes) > 0
            unlabeled = len(labeled_meshes) == 0
            if label_labeled_only and labeled:
                pass
            elif label_unlabeled_only and unlabeled:
                pass
            elif label_all:
                pass
            else:
                continue


            # Publication's text (title, abstract, full text if provided)
            abstract, title = get_document_text(entry)
            document_text = title + ' ' + abstract
            title = ' '+title+' '
            title = title.replace(',',' ')
            title = title.replace(':',' ')

# %%
def get_document_text(entry):
    '''
    FUNCTION:
    - Get the full text of the PubMed publication

    PARAMS:
    - entry (dict): parsed indexed publication
    '''

    # Title
    title = entry['_source']['title']
    if type(title) != str:
        title = ''
    title.replace('\n', ' ').replace('\t', ' ').replace('   ', ' ')

    # Abstract
    abstract = entry['_source']['abstract']
    if type(abstract) != str:
        abstract = ''
    abstract.replace('\n', ' ').replace('\t', ' ').replace('   ', ' ')

    return abstract, title

# %%
import random

# %%
sample = sample_publications(ctg2pmid, size=10)
labels = list(sample.keys())
labels

# %%
def dataloader(index_name, index_type, names, sample_size=800, include_abstract=True, include_title=True, include_fulltext=False):

    sample_docs = {}
    docs_data = []
    docs_labels = []
    docs_names = []

    sample = sample_publications(ctg2pmid, size=sample_size)
    es = Elasticsearch()

    for idx, key in enumerate(names):
        pmid_batch = sample[key]

        for num_pmids, pmid in enumerate(pmid_batch):
            entry = es.get(id = pmid, index = index_name, doc_type = index_type)

            abstract, title = get_document_text(entry)
            # document_text = title + ' ' + abstract

            if include_abstract:
                if len(abstract) > 0:
                    docs_data.append(abstract)
                    docs_labels.append(idx)
                    docs_names.append(key)

            if include_title:
                docs_data.append(title)
                docs_labels.append(idx)
                docs_names.append(key)

            if include_fulltext:
                fulltext = entry['full_text']
                if len(entry['full_text']) > 0:
                    docs_data.append(fulltext)
                    docs_labels.append(idx)
                    docs_names.append(key)

            # if num_pmids % 100 == 0:
            print(str(num_pmids)+' PMIDs processed in one of the batches', end='\r')

    sample_docs['data'] = docs_data
    sample_docs['labels'] = docs_labels
    sample_docs['names'] = docs_names

    return sample_docs

# %%
order = ["CM", "ARR", "CHD", "VD", "IHD", "CCD", "VOO", "OTH"]

# %%
# docs_1 = dataloader(index_name, index_type, order, sample_size=8000)
docs_1 = json.load(open('gdrive/MyDrive/bertopic/caseolap_lift/text_mining/docs_1.json'))

# %%
docs_1

# %%
len(docs_1['data'])

# %%
len(','.join(docs_1['data']))

# %%
from bertopic import BERTopic
topic_model_1 = BERTopic()
topics, probs = topic_model_1.fit_transform(docs_1['data'])
# Out:
# Downloading (…)e9125/.gitattributes:   0%|          | 0.00/1.18k [00:00<?, ?B/s]
# Downloading (…)_Pooling/config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]
# Downloading (…)7e55de9125/README.md:   0%|          | 0.00/10.6k [00:00<?, ?B/s]
# Downloading (…)55de9125/config.json:   0%|          | 0.00/612 [00:00<?, ?B/s]
# Downloading (…)ce_transformers.json:   0%|          | 0.00/116 [00:00<?, ?B/s]
# Downloading (…)125/data_config.json:   0%|          | 0.00/39.3k [00:00<?, ?B/s]
# Downloading pytorch_model.bin:   0%|          | 0.00/90.9M [00:00<?, ?B/s]
# Downloading (…)nce_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# Downloading (…)cial_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# Downloading (…)e9125/tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# Downloading (…)okenizer_config.json:   0%|          | 0.00/350 [00:00<?, ?B/s]
# Downloading (…)9125/train_script.py:   0%|          | 0.00/13.2k [00:00<?, ?B/s]
# Downloading (…)7e55de9125/vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# Downloading (…)5de9125/modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]

# %%
topic_model_1.get_topic_info()
# Out:
#      Topic  Count                                               Name  \
# 0       -1   3038                                   -1_the_of_and_in
# 1        0    271                 0_arrest_resuscitation_cpr_cardiac
# 2        1    114              1_endocarditis_infective_ie_bacterial
# 3        2    112                   2_artery_coronary_anomalous_left
# 4        3    104              3_tumors_tumor_malignant_chemotherapy
# ..     ...    ...                                                ...
# 153    152     11  152_anticoagulant_oral_lowmolecularweight_therapy
# 154    153     10               153_ventricle_double_chambered_right
# 155    154     10             154_mitral_repair_annuloplasty_dilated
# 156    155     10                155_mitral_valve_replacement_repair
# 157    156     10                  156_root_aortic_graft_replacement
#
#                                         Representation  \
# 0    [the, of, and, in, with, to, patients, was, fo...
# 1    [arrest, resuscitation, cpr, cardiac, cardiopu...
# 2    [endocarditis, infective, ie, bacterial, absce...
# 3    [artery, coronary, anomalous, left, origin, ma...
# 4    [tumors, tumor, malignant, chemotherapy, prima...
# ..                                                 ...
# 153  [anticoagulant, oral, lowmolecularweight, ther...
# 154  [ventricle, double, chambered, right, she, dou...
# 155  [mitral, repair, annuloplasty, dilated, regurg...
# 156  [mitral, valve, replacement, repair, elderly, ...
# 157  [root, aortic, graft, replacement, allograft, ...
#
#                                    Representative_Docs
# 0    [Management of intractable ventricular tachyar...
# 1    [Do patient characteristics or factors at resu...
# 2    [Severe mitral or aortic valve regurgitation, ...
# 3    [Anomalous origin of the left coronary artery....
# 4    [Surgical Treatment of Cardiac Tumors: Insight...
# ..                                                 ...
# 153  [Unrelenting Abdominal Pain after Recent Initi...
# 154  [[Double outlet right ventricle--a case associ...
# 155  [Novel approach to mitral valve repair in chil...
# 156  [Prosthetic valve replacement in infants and c...
# 157  [Long-term results of root reconstruction usin...
#
# [158 rows x 5 columns]

# %%
docs_topic = topic_model_1.get_document_info(docs_1['data'])
docs_topic
# Out:
#                                                Document  Topic  \
# 0     Total red cell volume, plasma volume, and sodi...     -1
# 1           What is the role of myocardial mast cells?      -1
# 2     Feasibility of using multivector impedance to ...     34
# 3     Impact of predictive value of Fibrosis-4 index...     -1
# 4                Is Too Much Oxygen Bad for the Heart?      -1
# ...                                                 ...    ...
# 7995  Thrombosis and failure of a HeartMate II devic...     44
# 7996    Cardiac arrest prognostic factors in children.       0
# 7997  Identification of potent and selective amidobi...     -1
# 7998  MR demonstration of right atrial involvement i...     27
# 7999  Attitudes of patients toward cardiopulmonary r...      0
#
#                                                Name  \
# 0                                  -1_the_of_and_in
# 1                                  -1_the_of_and_in
# 2     34_icd_implantable_defibrillator_cardioverter
# 3                                  -1_the_of_and_in
# 4                                  -1_the_of_and_in
# ...                                             ...
# 7995                  44_assist_lvad_impella_device
# 7996             0_arrest_resuscitation_cpr_cardiac
# 7997                               -1_the_of_and_in
# 7998                    27_myxoma_tumor_case_atrium
# 7999             0_arrest_resuscitation_cpr_cardiac
#
#                                          Representation  \
# 0     [the, of, and, in, with, to, patients, was, fo...
# 1     [the, of, and, in, with, to, patients, was, fo...
# 2     [icd, implantable, defibrillator, cardioverter...
# 3     [the, of, and, in, with, to, patients, was, fo...
# 4     [the, of, and, in, with, to, patients, was, fo...
# ...                                                 ...
# 7995  [assist, lvad, impella, device, support, devic...
# 7996  [arrest, resuscitation, cpr, cardiac, cardiopu...
# 7997  [the, of, and, in, with, to, patients, was, fo...
# 7998  [myxoma, tumor, case, atrium, atrial, myxomas,...
# 7999  [arrest, resuscitation, cpr, cardiac, cardiopu...
#
#                                     Representative_Docs  \
# 0     [Management of intractable ventricular tachyar...
# 1     [Management of intractable ventricular tachyar...
# 2     [Association between left ventricular ejection...
# 3     [Management of intractable ventricular tachyar...
# 4     [Management of intractable ventricular tachyar...
# ...                                                 ...
# 7995  [Outcomes of patients with right ventricular f...
# 7996  [Do patient characteristics or factors at resu...
# 7997  [Management of intractable ventricular tachyar...
# 7998  [Left atrial myxoma in a patient with paroxysm...
# 7999  [Do patient characteristics or factors at resu...
#
#                                             Top_n_words  Probability  \
# 0     the - of - and - in - with - to - patients - w...     0.000000
# 1     the - of - and - in - with - to - patients - w...     0.000000
# 2     icd - implantable - defibrillator - cardiovert...     0.218832
# 3     the - of - and - in - with - to - patients - w...     0.000000
# 4     the - of - and - in - with - to - patients - w...     0.000000
# ...                                                 ...          ...
# 7995  assist - lvad - impella - device - support - d...     1.000000
# 7996  arrest - resuscitation - cpr - cardiac - cardi...     0.852608
# 7997  the - of - and - in - with - to - patients - w...     0.000000
# 7998  myxoma - tumor - case - atrium - atrial - myxo...     0.130659
# 7999  arrest - resuscitation - cpr - cardiac - cardi...     1.000000
#
#       Representative_document
# 0                       False
# 1                       False
# 2                       False
# 3                       False
# 4                       False
# ...                       ...
# 7995                    False
# 7996                    False
# 7997                    False
# 7998                    False
# 7999                    False
#
# [8000 rows x 8 columns]

# %%
docs_topic = docs_topic[docs_topic['Topic'] != -1]
docs_topic = docs_topic.reset_index(drop=True)
docs_topic

# %%
subset = docs_topic[['Document', 'Topic', 'Name', 'Representation', 'Probability']]
subset

# %%
docs_search = {}
for idx, key in enumerate(docs_1['data']):
    if key in docs_search:
        val = docs_1['names'][idx]
        if val not in docs_search[key]:
            docs_search[key].append(val)
    else:
        docs_search[key] = [docs_1['names'][idx]]

# %%
docs_search

# %%
import numpy as np

# %%
len(np.unique(subset['Document'].tolist()))

# %%
subset['Document'].apply(lambda x: x in docs_search).all()

# %%
true_topic = subset['Document'].apply(lambda x: ', '.join(docs_search[x]))
true_topic

# %%
subset['True topic'] = true_topic

# %%
subset

# %%
import pandas as pd

# %%
topic_table = pd.DataFrame(subset.groupby('True topic').apply(lambda x: list(set(x['Topic']))))

# %%
topic_table = topic_table.reset_index()

# %%
topic_table.columns

# %%
topic_table = topic_table.rename(columns={0: 'topics'})

# %%
topic_table

# %%
topic_table['length_of_topics'] = topic_table['topics'].apply(lambda x: len(x))

# %%
one_topic_table = topic_table[topic_table['True topic'].apply(lambda x: len(x)) <= 3]

# %%
one_topic_table

# %%
set.intersection(*[set(x) for x in one_topic_table['topics'].tolist()])

# %%
[set(x) for x in one_topic_table['topics'].tolist()]

# %%
topic_model_1.visualize_topics()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="cc22df6a-710f-4c0b-b11b-596d512b09c3" class="plotly-graph-div" style="height:650px; width:650px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("cc22df6a-710f-4c0b-b11b-596d512b09c3")) {                    Plotly.newPlot(                        "cc22df6a-710f-4c0b-b11b-596d512b09c3",                        [{"customdata":[[0,"arrest | resuscitation | cpr | cardiac | cardiopulmonary",271],[1,"endocarditis | infective | ie | bacterial | abscess",114],[2,"artery | coronary | anomalous | left | origin",112],[3,"tumors | tumor | malignant | chemotherapy | primary",104],[4,"exercise | training | capacity | physical | vo2",84],[5,"stroke | af | warfarin | fibrillation | bleeding",79],[6,"marfan | syndrome | marfans | fbn1 | eyes",79],[7,"tachycardia | supraventricular | ventricular | paroxysmal | episodes",76],[8,"congenital | hypoplastic | efe | heart | children",73],[9,"fetal | maternal | pregnancy | fetuses | cesarean",70],[10,"stenosis | aortic | angiodysplasia | isthmic | congenital",69],[11,"tavi | tavr | savr | transcatheter | outcomes",69],[12,"failure | heart | diuretics | angiotensin | ace",67],[13,"coronary | computed | tomography | cac | perfusion",67],[14,"reperfusion | ischemia | injury | ischemiareperfusion | min",58],[15,"pulmonary | stenosis | radiological | artery | bronchial",56],[16,"coarctation | aorta | recoarctation | arch | repair",55],[17,"ablation | af | recurrence | catheter | atrial",55],[18,"branch | block | bundle | bundlebranch | axis",53],[19,"sinus | sick | node | sinoatrial | syndrome",51],[20,"pacemaker | pacemakers | bh | ah | transvenous",49],[21,"qt | long | lqts | syndrome | family",48],[22,"brugada | brs | ecg | syndrome | pattern",48],[23,"takotsubo | cardiomyopathy | arteritis | takayasus | syndrome",47],[24,"transposition | great | arteries | vessels | mustard",47],[25,"pericarditis | pericardial | ig | hcq | constrictive",47],[26,"massachusetts | you | practice | exercises | clinicopathological",47],[27,"myxoma | tumor | case | atrium | atrial",45],[28,"transcatheter | implantation | valve | aortic | replacement",44],[29,"tricuspid | tr | regurgitation | annuloplasty | repair",44],[30,"crt | pacing | resynchronization | qrs | lv",44],[31,"turner | ts | turners | syndrome | girls",43],[32,"valvular | disease | phenfen | benfluorex | vhd",42],[33,"platelet | thrombolytic | clopidogrel | heparin | acute",42],[34,"icd | implantable | defibrillator | cardioverter | cardioverterdefibrillator",42],[35,"qtc | prolongation | interval | qt | risperidone",42],[36,"infarct | myocardial | infarction | acute | opposite",40],[37,"mitral | stenosis | auricular | parturient | insufficiency",40],[38,"septal | defect | closure | septum | interventricular",40],[39,"surgery | noncardiac | cardiac | hemicolectomy | preoperative",39],[40,"bnp | natriuretic | peptide | ntprobnp | levels",39],[41,"cad | women | coronary | men | risk",39],[42,"myocarditis | viral | virus | immune | infection",38],[43,"diabetes | mellitus | bp | diabetic | glucose",38],[44,"assist | lvad | impella | device | support",37],[45,"tetralogy | fallot | correction | dsa | fallots",37],[46,"stent | stents | des | lesions | bms",36],[47,"accessory | wolffparkinsonwhite | pathway | wpw | msec",35],[48,"block | atrioventricular | athletes | mobitz | degree",35],[49,"cholesterol | atherosclerosis | lipoprotein | hdl | rabbits",35],[50,"right | cardiomyopathy | arrhythmogenic | ventricular | arvc",35],[51,"dogs | tdp | lidocaine | pointes | cycle",33],[52,"failure | snow | shoveling | heart | ahfs",33],[53,"dogs | breathsmin | ps | cats | dog",33],[54,"cabg | bypass | pci | coronary | revascularization",33],[55,"mutations | mutation | gene | cardiomyopathy | defects",32],[56,"current | potassium ...

# %%
topic_model_1.get_params()
# Out:
# {'calculate_probabilities': False,
#  'ctfidf_model': ClassTfidfTransformer(),
#  'embedding_model': <bertopic.backend._sentencetransformers.SentenceTransformerBackend at 0x7ef776c00d60>,
#  'hdbscan_model': HDBSCAN(min_cluster_size=10, prediction_data=True),
#  'language': 'english',
#  'low_memory': False,
#  'min_topic_size': 10,
#  'n_gram_range': (1, 1),
#  'nr_topics': None,
#  'representation_model': None,
#  'seed_topic_list': None,
#  'top_n_words': 10,
#  'umap_model': UMAP(angular_rp_forest=True, low_memory=False, metric='cosine', min_dist=0.0, n_components=5, tqdm_kwds={'bar_format': '{desc}: {percentage:3.0f}%| {bar} {n_fmt}/{total_fmt} [{elapsed}]', 'desc': 'Epochs completed', 'disable': True}),
#  'vectorizer_model': CountVectorizer(),
#  'verbose': False}

# %%
from scipy.cluster import hierarchy as sch

# Hierarchical topics
linkage_function = lambda x: sch.linkage(x, 'single', optimal_ordering=True)
hierarchical_topics = topic_model_1.hierarchical_topics(docs_1['data'], linkage_function=linkage_function)

# %%
topic_model_1.visualize_hierarchy(hierarchical_topics=hierarchical_topics)

# %%
hierarchical_topics

# %%
category2synonyms = json.load(open('gdrive/MyDrive/bertopic/caseolap_lift/text_mining/category2synonyms.json'))

# %%
[len(val) for key, val in category2synonyms.items()]

# %%
category2synonyms

# %% [markdown]
# To-do:
# 1. parse xml file to find the corresponding synonyms
# 2. generate a list of categories with synonyms to fit the model
# 3. run the guided model

# %%
! wget https://nlmpubs.nlm.nih.gov/projects/mesh/MESH_FILES/xmlmesh/desc2022.xml

# %%
! ls desc2022.xml

# %%
! ls

# %%
! ls ../data/MeSH/desc2022.xml

# %%
category2synonyms['VOO']

# %%
CM_syn = [s for s in mesh.keys() if 'Cardiomyopathy' in s]
CM_syn

# %%
ARR_syn = [s for s in mesh.keys() if 'Arrhythmia' in s]
ARR_syn

# %%
CHD_syn = [s for s in mesh.keys() if 'Congenital' in s]
CHD_syn

# %%
VD_syn = [s for s in mesh.keys() if 'Valve' in s]
VD_syn

# %%
CCD_syn = [s for s in mesh.keys() if 'Cardiac Conduction' in s or 'Cardiac Complex' in s or 'Atrioventricular' in s]
CCD_syn

# %%
VOO_syn = [s for s in mesh.keys() if 'Subvalvular' in s or 'Pulmonary' in s]
VOO_syn

# %%
from bertopic import BERTopic

# %%
from bertopic import BERTopic
from bertopic.backend import BaseEmbedder
from bertopic.cluster import BaseCluster
from bertopic.vectorizers import ClassTfidfTransformer
from bertopic.dimensionality import BaseDimensionalityReduction
from sklearn.datasets import fetch_20newsgroups

docs = fetch_20newsgroups(subset='all',  remove=('headers', 'footers', 'quotes'))
data = docs["data"]

seed_topic_list = [["drug", "cancer", "drugs", "doctor"],
                   ["windows", "drive", "dos", "file"],
                   ["space", "launch", "orbit", "lunar"]]

empty_embedding_model = BaseEmbedder()
empty_dimensionality_model = BaseDimensionalityReduction()
empty_cluster_model = BaseCluster()
ctfidf_model = ClassTfidfTransformer(reduce_frequent_words=True)


topic_model = BERTopic(
    umap_model=empty_dimensionality_model,
    hdbscan_model=empty_cluster_model,
    ctfidf_model=ctfidf_model,
    seed_topic_list=seed_topic_list
)
topics, probs = topic_model.fit_transform(data, y=docs['target'])

# %%
topic_model.get_topic_info()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-fc69d99d94ea> in <cell line: 1>()
# ----> 1 topic_model.get_topic_info()
#
# NameError: name 'topic_model' is not defined

# %%
docs

# %%
list(category2synonyms.values())

# %%
from sklearn.feature_extraction.text import CountVectorizer
from bertopic.representation import KeyBERTInspired

docs_1_ = docs_1['data']
seed = list(category2synonyms.values())

# vectorizer_model = CountVectorizer(stop_words="english")
representation_model = KeyBERTInspired()

topic_model_1 = BERTopic(
    umap_model=empty_dimensionality_model,
    hdbscan_model=empty_cluster_model,
    ctfidf_model=ctfidf_model,
    # vectorizer_model=vectorizer_model,
    representation_model=representation_model,
    seed_topic_list=seed
)
topics_1, probs_1 = topic_model_1.fit_transform(docs_1_, y=docs_1['labels'])

# %%
topic_model_1.get_params()
# Out:
# {'calculate_probabilities': False,
#  'ctfidf_model': ClassTfidfTransformer(reduce_frequent_words=True),
#  'embedding_model': <bertopic.backend._sentencetransformers.SentenceTransformerBackend at 0x7afb8c18b100>,
#  'hdbscan_model': <bertopic.cluster._base.BaseCluster at 0x7afb899a9900>,
#  'language': 'english',
#  'low_memory': False,
#  'min_topic_size': 10,
#  'n_gram_range': (1, 1),
#  'nr_topics': None,
#  'representation_model': KeyBERTInspired(),
#  'seed_topic_list': [['Cardiomyopathy, Congestive',
#    'Congestive Heart Failure',
#    'Cardiomyopathy, Familial Idiopathic',
#    'Congestive Cardiomyopathy',
#    'Dilated Cardiomyopathy',
#    'Familial Hypertrophic Cardiomyopathy',
#    'Dyspnea, Paroxysmal',
#    'Asthma, Cardiac',
#    'Myocarditis',
#    'Injury, Myocardial Reperfusion',
#    'Heart Failure',
#    'Chagas Cardiomyopathy',
#    'Ventricular Dysplasia, Right, Arrhythmogenic',
#    'Secondary Myocardial Diseases',
#    'Left-Sided Heart Failure',
#    'Heart Failure, Congestive',
#    'Cardiomyopathy, Hypertrophic Obstructive',
#    'Heart Failure, Normal Ejection Fraction',
#    'Adhalinopathy, Primary',
#    'Myocardial Disease',
#    'CPEO with Myopathy',
#    'Ophthalmoplegia Plus Syndrome',
#    'Cardiomyopathies',
#    'Hypertrophic Subaortic Stenosis, Idiopathic',
#    'LGMD2D',
#    'Limb-Girdle Muscular Dystrophy, Type 2D',
#    'Noncompaction of the Left Ventricular Myocardium, Autosomal Dominant',
#    'Cardiac Failure',
#    'Myocardial Ischemic Reperfusion Injury',
#    'Alpha-Sarcoglycanopathy',
#    'Cardiomyopathy, Dilated, with Conduction Deffect1',
#    'Right-Sided Heart Failure',
#    'Chronic Progressive External Ophthalmoplegia with Myopathy',
#    'Carditis',
#    'Cardiomyopathy, Dilated, Autosomal Recessive',
#    "Kearns' Syndrome",
#    'Obstructive Asymmetric Septal Hypertrophy',
#    'Endomyocardial Fibrosis',
#    'Cardiomyopathy, Alcoholic',
#    'Sarcoglycanopathy',
#    'Kearns Syndrome',
#    'Alpha-Sarcoglycanopathies',
#    'Primary Myocardial Diseases',
#    'Myocardial Reperfusion Injury',
#    'Arrhythmogenic Right Ventricular Dysplasia',
#    'Cardiac Edema',
#    'Ventricular Hypertrophy, Familial',
#    'Familial Restrictive Cardiomyopathy',
#    'Duchenne-Like Autosomal Recessive Muscular Dystrophy, Type 2',
#    'Heart Failure, Systolic',
#    'Myocardial Failure',
#    'Isolated Noncompaction of the Ventricular Myocardium',
#    'Endomyocardial Fibroelastosis',
#    'Hereditary Ventricular Hypertrophy',
#    'Vacuolar Cardiomyopathy and Myopathy, X-linked',
#    'Asymmetric Septal Hypertrophy, Familial',
#    'Cpeo With Ragged-Red Fibers',
#    'ARVD-C',
#    'Danon Disease',
#    'Ophthalmoplegia-Plus Syndrome',
#    'Cardiomyopathy, Dilated, 1a',
#    'Primary Myocardial Disease',
#    'X-Linked Vacuolar Cardiomyopathy and Myopathy',
#    'Systolic Heart Failure',
#    'Kearns Sayre Syndrome',
#    'Cardiorenal Syndrome',
#    'Kearn-Sayre Mitochondrial Cytopathy',
#    'Lysosomal Glycogen Storage Disease with Normal Acid Maltase',
#    'Isolated Non-compaction of the Ventricular Myocardium',
#    'Dyspnea, Paroxysmal Nocturnal',
#    'Kearns-Sayre Syndrome',
#    'Myocardiopathies',
#    'Lysosomal Glycogen Storage Disease without Acid Maltase Deficiency',
#    'Arrhythmogenic Right Ventricular Cardiomyopathy',
#    'Arrhythmogenic Right Ventricular Dysplasia-Cardiomyopathy',
#    'Glycogen Storage Disease Limited to the Heart',
#    'Glycogen Storage Disease Type 2B',
#    'Myocardial Diseases',
#    'Heart Failure, Right-Sided',
#    'CPEO with Ragged Red Fibers',
#    'Alcoholic Cardiomyopathy',
#    'Cardiomyopathy, Dilated, With Conduction Defect 1',
#    'Glycogen Storage Disease IIb',
#    'Cardiomyopathy, Hypertrophic',
#    'Myocardial Diseases, Primary',
#    'Muscular Dystrophy, Limb-Girdle, Type 2D',
#    'Heart Failure, Reduced Ejection Fraction',
#    'Sarcoglycanopathies',
#    'Ophthalmoplegia, Progressive External, With Ragged-Red Fibers',
#    'Reno-Cardiac Syndrome',
#    'Oculocraniosomatic Syndrome',
#    'Arrhythmogenic Right Ventricular Cardiomyopathy-Dysplasia',
#    'Cardiomyopathy, Dilated, CMD1A',
#    'Edema, Cardiac',
#    'Pseudoglycogenosis II',
#    'Pseudoglycogenosis 2',
#    'Diabetic Cardiomyopathies',
#    'Trypanosomiasis, Cardiovascular',
#    'Cardiomyopathy, Dilated',
#    'Cardiomyopathy, Chagas',
#    'Antopol Disease',
#    'Right Ventricular Dysplasia, Arrhythmogenic',
#    'Isolated Noncompaction of the Left Ventricular Myocardium, X-Linked',
#    'Adhalinopathies',
#    'Cardiomyopathy, Familial Hypertrophic',
#    'Cardiomyopathies, Secondary',
#    'Muscular Dystrophy Limb-Girdle with Alpha-Sarcoglycan Deficiency',
#    'Glycogen Storage Cardiomyopathy',
#    'Heart Failure, Left-Sided',
#    'Heart Failure, Preserved Ejection Fraction',
#    'Cardiomyopathy, Hypertrophic, Familial',
#    'Heart Decompensation',
#    'Cardiomyopathies, Primary',
#    'Cardiomyopathy, Dilated, LMNA',
#    'Cardio-Renal Syndrome',
#    'Kearns-Sayre Mitochondrial Cytopathy',
#    'Endocardial Fibroelastosis',
#    'Heart Failure, Diastolic',
#    'Kearns-Sayre-Shy-Daroff Syndrome',
#    'Renocardiac Syndrome',
#    'Myocarditis, Chagas',
#    'Ophthalmoplegia, Pigmentary Degeneration of Retina, and Cardiomyopathy',
#    'Cardiomyopathy, Idiopathic Dilated',
#    "Chagas' Cardiomyopathy",
#    'Glycogen Storage Disease Type IIb',
#    'Diastolic Heart Failure',
#    'Cardiomyopathy, Restrictive',
#    'Myocardial Diseases, Secondary',
#    'Reperfusion Injury, Myocardial',
#    'Ventricular Hypertrophy, Hereditary'],
#   ['Wolff-Parkinson-White Syndrome',
#    'Tachycardia, Paroxysmal',
#    'Cardiac Sinus Pause',
#    'Surdo-Cardiac Syndrome',
#    'Right Bundle-Branch Block',
#    'Adam-Stokes Attacks',
#    'Extrasystole, Ventricular',
#    'Ventricular Tachycardia',
#    'Atrioventricular Conduction Block',
#    'Ventricular Fibrillation',
#    'Tachycardia, Ventricular',
#    'Ventricular Tachyarrhythmias',
#    'Nonsustained Ventricular Tachycardia',
#    'Arrhythmia',
#    'Sinus Node Dysfunction',
#    'Long QT Syndrome Type 1',
#    'Right Bundle Branch Block, ST Segment Elevation, and Sudden Death Syndrome',
#    'Andersen Syndrome',
#    'Premature Ventricular Contractions',
#    'Sinoatrial Nodal Reentry Tachycardia',
#    'Tachycardia',
#    'Tachycardia, Ectopic Atrial',
#    'AV Block',
#    'Premature Cardiac Complexes',
#    'Nodofascicular Mahaim-Type Pre-Excitation',
#    'Mahaim-Type Pre-Excitation, Nodoventricular',
#    'Sinoatrial Exit Block',
#    'Junctional Ectopic Tachycardia',
#    'WPW Syndrome',
#    'Auriculo-Ventricular Dissociation',
#    'Ectopic Junctional Tachycardia',
#    'Accelerated Idioventricular Rhythm',
#    'Paroxysmal Atrial Fibrillation',
#    'Mahaim-Type Pre-Excitation, Nodofascicular',
#    'Persistent Atrial Fibrillation',
#    'Sinoatrial Arrhythmia',
#    'Atrioventricular Nodal Re-Entrant Tachycardia',
#    'Jervell And Lange-Nielsen Syndrome 1',
#    'Fascicular Block',
#    'Ectopic Atrial Tachycardia',
#    'Interatrial Block',
#    'Pre-Excitation Syndromes',
#    'Periodic Paralysis, Potassium-Sensitive Cardiodysrhythmic Type',
#    'Extrasystole',
#    'Lown-Ganong-Levine Syndrome',
#    'Bradyarrhythmia',
#    'Tachycardia, Ectopic Junctional',
#    'Tachycardia, Reciprocating',
#    'Short PR-Normal QRS Complex Syndrome',
#    'Long QT Syndrome',
#    'Sinus Node Disease',
#    'Torsades de Pointes',
#    'Paroxysmal Supraventricular Tachycardia',
#    'Idiopathic Ventricular Tachycardia',
#    'Extrasystoles',
#    'Sudden Unexplained Nocturnal Death Syndrome (SUNDS)',
#    'Left Bundle-Branch Block',
#    'Auricular Flutter',
#    'Pre-Excitation, Mahaim-Type',
#    'Mahaim-Type Pre-Excitation',
#    'Bundle Branch Block',
#    'Ventricular Flutter',
#    'Jervell-Lange Nielsen Syndrome',
#    'Premature Cardiac Complex',
#    'Tachycardia, SA Nodal Reentrant',
#    'Atrioventricular Nodal Reentry Tachycardia',
#    'Bradycardia',
#    'Heart Block',
#    'Parasystole',
#    'Premature Atrial Contractions',
#    'Tachycardia, Atrioventricular Nodal Reentry',
#    'Mahaim-Type Preexcitation',
#    'Paroxysmal Reciprocal Tachycardia',
#    'Tachycardia, Reciprocal',
#    'Bayes Syndrome',
#    'Long QT Syndrome 1',
#    'Tachycardia, Supraventricular',
#    'Atrial Flutter',
#    'Premature Supraventricular Beats',
#    'Andersen-Tawil Syndrome',
#    'Atrial Fibrillation',
#    'Brugada Syndrome',
#    'Romano-Ward Syndrome',
#    'Adams-Stokes Syndrome',
#    'Premature Ventricular Beats',
#    'Premature Ventricular Complex',
#    'Stokes-Adams Attacks',
#    'Arrhythmia, Sinoatrial',
#    'AIVR',
#    'Atrial Ectopic Beats',
#    'Atrioventricular Nodal Reentrant Tachycardia',
#    'Brugada ECG Pattern',
#    'Reciprocal Tachycardia',
#    'Atrial Premature Complexes',
#    'Ward-Romano Syndrome',
#    'Premature Beats',
#    'Jervell and Lange-Nielsen Syndrome',
#    'Sinus Arrest, Cardiac',
#    "Bayes' Syndrome",
#    'Ventricular Premature Complexes',
#    'Sinoatrial Block',
#    'Interatrial Conduction Delay',
#    'Slow Ventricular Tachycardia',
#    'Premature Atrial Beats',
#    'Potassium-Sensitive Periodic Paralysis, Ventricular Ectopy, and Dysmorphic Features',
#    'Cardiac Complex, Premature',
#    'Cardio-Auditory-Syncope Syndrome',
#    'Sudden Unexplained Death Syndrome',
#    'Ventricular Premature Complex',
#    'A-V Dissociation',
#    'Auricular Fibrillation',
#    'Anterior Fascicular Block',
#    'Nodoventricular Mahaim-Type Pre-Excitation',
#    'Premature Atrial Complex',
#    'Ventricular Ectopic Beats',
#    'Arrhythmias, Cardiac',
#    'Tachycardia, Sinus',
#    'Tachycardia, Sinoatrial Nodal Reentry',
#    'Sinus Node Reentrant Tachycardia',
#    'Commotio Cordis',
#    'Deafness, Congenital, and Functional Heart Disease',
#    'Anomalous Ventricular Excitation Syndrome',
#    'Familial Atrial Fibrillation',
#    'Andersen Cardiodysrhythmic Periodic Paralysis',
#    'Cardiac Arrhythmias',
#    'Cardiac Dysrhythmia',
#    'Bundle-Branch Block',
#    'Atrioventricular Dissociation',
#    'Cardiac Sinus Arrest',
#    'Cardiac Arrhythmia',
#    'Extrasystole, Atrial',
#    'Tachycardia, AV Nodal Reentrant',
#    'Preexcitation Syndrome',
#    'AV Nodal Reentrant Tachycardia',
#    'Sinus Arrhythmia',
#    'Prolonged QT Interval in EKG and Sudden Death',
#    'Ventricular Pre-Excitation with Arrhythmia',
#    'Ventricular Fibrillation with Prolonged QT Interval',
#    'Electrocardiogram QT Prolonged',
#    'Brugada Syndrome 1',
#    'Atrial Premature Complex',
#    'Atrioventricular Reentrant Tachycardia',
#    'Ectopic Heartbeats',
#    'Reciprocating Tachycardia',
#    'Cardioauditory Syndrome of Jervell and Lange-Nielsen',
#    'Sick Sinus Syndrome',
#    'Sudden Unexplained Nocturnal Death Syndrome',
#    'Posterior Fascicular Block',
#    'Andersen Tawil Syndrome',
#    'Sinus Tachycardia',
#    'Sick Sinus Node Syndrome',
#    'Tachyarrhythmia',
#    'False Bundle-Branch Block Syndrome',
#    'Arrythmia',
#    'Arrhythmia, Sinus',
#    'Atrial Ectopic Tachycardia',
#    'Cardiac Concussion',
#    'Andersen Cardiodysrythmic Periodic Paralysis',
#    'Long QT Syndrome 7',
#    'Bradyarrhythmias',
#    'Torsade de Pointes',
#    'Auriculoventricular Accessory Pathway Syndrome',
#    'Stokes-Adams Syndrome',
#    'Cardiac Complexes, Premature',
#    'Atrioventricular Block',
#    'Wolf-Parkinson-White Syndrome',
#    'Brugada Type ECG Pattern'],
#   ['Taussig-Bing Anomaly',
#    'Bland-White-Garland Syndrome',
#    'Transposition of Great Vessels',
#    'Familial Turner Syndrome',
#    'Double Outlet Right Ventricle',
#    'Trisomy 13',
#    "Lutembacher's Syndrome",
#    'Heart Septal Defects, Ventricular',
#    'Truncus Arteriosus Communis',
#    'Coarctation of the Aorta',
#    'Conotruncal Anomaly Face Syndrome (CTAF)',
#    'Univentricular Heart',
#    'Anomalous Left Coronary Artery',
#    'Chromosome 13 Trisomy Syndrome',
#    'Dextro-Looped Transposition of the Great Arteries',
#    'Aorto-Left Ventricular Tunnel',
#    'Ebstein Anomaly',
#    'Aortic-Left Ventricular Tunnel',
#    "Turner's Syndrome",
#    'Septal Defects, Aorticopulmonary',
#    'Mosaic Trisomy 18 Syndrome',
#    'Tricuspid Atresia',
#    'Gonadal Dysgenesis, XO',
#    'Complete Trisomy 13 Syndrome',
#    "Fallot's Tetralogy",
#    'Criss-cross Heart',
#    'Noonan Syndrome 1',
#    'Endocardial Cushion Defect',
#    'Lentiginosis Cardiomyopathic',
#    'Ventricular Dysplasia, Right, Arrhythmogenic',
#    'Right Atrial Isomerism with Asplenia',
#    'Congenital Quadricuspid Aortic Valve',
#    'Aorticoventricular Tunnel',
#    'Atrial Septal Defect',
#    'Velocardiofacial Syndrome',
#    'Cor Triatriatum Sinistrum',
#    'Thymic Aplasia Syndrome',
#    'Chromosome 13 Duplication',
#    'Aorticopulmonary Septal Defect',
#    'Congenital Heart Defect',
#    'Heart Defects, Congenital',
#    'Marfan Syndrome Type 1',
#    'Double Outlet Right Ventricle, Subpulmonary VSD',
#    'Ventricular Septal Defect',
#    'Ductus Arteriosus, Patent',
#    'Double-Outlet Right Ventricle',
#    'Catch22',
#    'Patau Syndrome',
#    'Cardio-Cutaneous Syndrome',
#    'Dextrocardia, Bronchiectasis, and Sinusitis',
#    'Aortic Valve, Bicuspid',
#    'Double Outlet Right Ventricle, Subaortic VSD',
#    'Polysplenia Syndrome',
#    'Heart Abnormalities',
#    'Patent Oval Foramen',
#    'Patent Foramen Ovale',
#    "Tetralogy, Fallot's",
#    'Hypoplastic Left Heart Syndrome',
#    'MGA Type II',
#    'Noncompaction of the Left Ventricular Myocardium, Autosomal Dominant',
#    'Coarctation of Aorta Dominant',
#    'Aorto-Ventricular Tunnel',
#    'Foramen Ovale, Patent',
#    "Kartagener's Triad",
#    'Situs Ambiguus with Asplenia',
#    'Noonan Syndrome',
#    'Trisomy 18 Syndrome',
#    'Siewert Syndrome',
#    'Marfan Like Connective Tissue Disorder',
#    'Congenitally Corrected Transposition of the Great Arteries',
#    'Multiple Lentigines Syndrome',
#    '3-Methylglutaconicaciduria Type II',
#    'Marfan Syndrome Type 2',
#    'Septal Defects, Aortopulmonary',
#    'VCF Syndrome',
#    'Aortico-Left Ventricular Tunnel',
#    'Pharyngeal Pouch Syndrome',
#    'Persistent Truncus Arteriosus',
#    'Marfan Syndrome, Type II',
#    'Levocardia',
#    'Left Heart Hypoplasia Syndrome',
#    'Abnormality, Heart',
#    'Septal Defect, Aortopulmonary',
#    'Left Atrial Isomerism',
#    'Crisscross Heart',
#    "Ebstein's Malformation",
#    'Quadricuspid Aortic Valve Disease',
#    'Aortopulmonary Septal Defect',
#    'Situs Inversus with Levocardia',
#    'Isolated Levocardia',
#    'Septal Defect, Aorticopulmonary',
#    'Marfan Syndrome',
#    'Heart Septal Defects',
#    'Mosaic Trisomy 13 Syndrome',
#    '22q11 Deletion Syndrome',
#    'Congenital Heart Disease',
#    '22q11.2 Deletion Syndrome',
#    'Cardiomyopathic Lentiginosis',
#    'Congenital Heart Defects',
#    'Polynesian Bronchiectasis',
#    'Arrhythmogenic Right Ventricular Dysplasia',
#    'Ciliary Dyskinesia, Primary, 1, With Or Without Situs Inversus',
#    'Noonan Syndrome with Multiple Lentigines',
#    'Truncus Arteriosus, Persistent',
#    'DiGeorge Anomaly',
#    'Bicuspid Aortic Valve',
#    'Tricuspid Valve Atresia',
#    'Persistent Common Atrioventricular Canal',
#    'Cardiac Septal Defect',
#    'Coronary Vessel Anomalies',
#    'Marfan Syndrome, Type I',
#    'Subdivided Left Atrium',
#    'Leopard Syndrome 1',
#    'Persistent Ostium Primum',
#    'Isolated Noncompaction of the Ventricular Myocardium',
#    'Cardiac Septal Defects',
#    'Aortoventricular Tunnel',
#    'Aortico-Ventricular Tunnel',
#    'Barth Syndrome',
#    'Autosomal Dominant Opitz G-Bbb Syndrome',
#    'Turner Syndrome',
#    'ALCAPA',
#    'Sedlackova Syndrome',
#    'ARVD-C',
#    'Kartagener Triad',
#    'Endocardial Cushion Defects',
#    'Heart Septal Defects, Atrial',
#    'Tetralogy of Fallot',
#    'Aorto-Right Ventricular Tunnel',
#    'Quadricuspid Aortic Valve Disorder',
#    'Cor Triatriatum',
#    'Atresia, Tricuspid',
#    'Hypoplasia of Thymus and Parathyroids',
#    'Bicuspid Aortic Valve Disease',
#    'Right Atrial Isomerism',
#    'Isolated Non-compaction of the Ventricular Myocardium',
#    'DiGeorge Syndrome',
#    'Cardioskeletal Myopathy with Neutropenia and Abnormal Mitochondria',
#    'Absent Right Atrioventricular Connection',
#    'Deletion 22q11.2 Syndrome',
#    'Quadricuspid Aortic Valve',
#    'Arrhythmogenic Right Ventricular Cardiomyopathy',
#    'Arrhythmogenic Right Ventricular Dysplasia-Cardiomyopathy',
#    'Trisomy 18',
#    'Ivemark Syndrome',
#    '3-Methylglutaconicaciduria Type 2',
#    'Aortopulmonary Septal Defects',
#    'Bland White Garland Syndrome',
#    'LEOPARD Syndrome, 1',
#    'Third and Fourth Pharyngeal Pouch Syndrome',
#    'Pseudo-Ullrich-Turner Syndrome',
#    'ALCAPA Syndrome',
#    'Left Heart Syndrome, Hypoplastic',
#    'Shprintzen Syndrome',
#    'Congenitally Corrected Transposition of the Great Vessels',
#    'Situs Ambiguus Viscerum',
#    'Eisenmenger Syndrome',
#    'Defects, Congenital Heart',
#    'Complex Single Ventricle',
#    'Ciliary Dyskinesia, Primary, 1',
#    '22q11.2DS',
#    "Ebstein's Anomaly",
#    'Monosomy X',
#    "Marfan's Syndrome",
#    'Aortic Valve Disease 1',
#    "Kartagener's Syndrome",
#    'Intraventricular Septal Defects',
#    'Conotruncal Anomaly Face Syndrome',
#    'Asplenia with Cardiovascular Anomalies',
#    'Aortic Coarctation',
#    'Trisomy E Syndrome',
#    'Trilogy of Fallot',
#    'Bonnevie-Ullrich Syndrome',
#    "Eisenmenger's Complex",
#    'Eisenmenger Complex',
#    'Kartagener Syndrome',
#    'MGA Type 2',
#    'Dextrocardia',
#    'Ostium Secundum Atrial Septal Defect',
#    '3-Methylglutaconic Aciduria, Type II',
#    'Arrhythmogenic Right Ventricular Cardiomyopathy-Dysplasia',
#    'Aortic-Right Ventricular Tunnel',
#    'Transposition of Great Arteries',
#    "Patau's Syndrome",
#    'Aortico-Right Ventricular Tunnel',
#    'DiGeorge Sequence',
#    'Lutembacher Syndrome',
#    'Asplenia Syndrome',
#    'Trisomy 13 Syndrome',
#    'Turner Phenotype with Normal Karyotype',
#    'Myocardial Bridging',
#    'Heart Defect, Congenital',
#    'Ullrich-Noonan Syndrome',
#    'Edwards Syndrome',
#    'Complete Trisomy 18 Syndrome',
#    'Familial Third and Fourth Pharyngeal Pouch Syndrome',
#    'Aortic-Ventricular Tunnel',
#    'Female Pseudo-Turner Syndrome',
#    'Aorticopulmonary Septal Defects',
#    'Velo-Cardio-Facial Syndrome',
#    'Trisomy 13 Syndromes',
#    'Right Ventricular Dysplasia, Arrhythmogenic',
#    'Isolated Noncompaction of the Left Ventricular Myocardium, X-Linked',
#    "Eisenmenger's Syndrome",
#    'Situs Ambiguus',
#    'Triatrial Heart',
#    'Visceral Heterotaxy',
#    'Gonadal Dysgenesis, 45,X',
#    'Patent Ductus Arteriosus',
#    'Heart Septal Defect',
#    'Atrial Septal Defects',
#    'Situs Ambiguus with Polysplenia',
#    'Congenitally Corrected Transposition',
#    'Atrial Septal Defect Ostium Primum',
#    'Heart, Malformation Of',
#    'Noonan-Ehmke Syndrome',
#    'Patent Ductus Arteriosus Familial',
#    "Turner's Phenotype, Karyotype Normal",
#    'Turner-Like Syndrome',
#    'Ventricular Septal Defects',
#    'Patency of the Ductus Arteriosus',
#    'Bartholin-Patau Syndrome',
#    "Familial Ebstein's Anomaly",
#    'Double Outlet Right Ventricle, Noncommitted VSD',
#    'Male Turner Syndrome',
#    'Coarctation of Aorta',
#    'LEOPARD Syndrome',
#    'Progressive Cardiomyopathic Lentiginosis',
#    'Heterotaxy Syndrome',
#    'Turner Syndrome, Male',
#    'Left Atrial Isomerism with Polysplenia',
#    "Fallot's Trilogy",
#    'Status Bonnevie-Ullrich',
#    'Ullrich-Turner Syndrome',
#    'Shprintzen VCF Syndrome',
#    "Turner's Syndrome, Male",
#    'Quadricuspid Aortic Valvular Disease',
#    'Quadricuspid Aortic Valve Condition'],
#   ['Pulmonary Valve Atresias',
#    'Supravalvular Stenosis, Aortic',
#    'Pulmonary Infundibular Stenosis',
#    'Stenosis, Pulmonary Subvalvular',
#    'Atresias, Pulmonary',
#    'Atresia, Pulmonary Valve',
#    'Regurgitation, Pulmonary',
#    'Stenosis, Subvalvular Pulmonary',
#    'Familial Hypertrophic Cardiomyopathy',
#    'Pulmonary Stenosis, Subvalvular',
#    'Supravalvular Aortic Stenosis',
#    'Tricuspid Atresia',
#    'Heart Valvular Disease',
#    'Stenoses, Subvalvular Pulmonary',
#    'Lentiginosis Cardiomyopathic',
#    'Heart Valve Diseases',
#    'Atresias, Pulmonary Valve',
#    'Congenital Quadricuspid Aortic Valve',
#    'Ventricular Hypertrophy, Hereditary',
#    'Heart Valve Prolapse',
#    'Cardiomyopathy, Hypertrophic Obstructive',
#    'Aortic Valve Stenosis',
#    'Subvalvular Aortic Stenosis',
#    'Pulmonary Stenoses',
#    'Cardio-Cutaneous Syndrome',
#    'Subvalvular Pulmonary Stenoses',
#    'Aortic Valve, Bicuspid',
#    'Pulmonary Valve Regurgitation',
#    'Hypertrophic Subaortic Stenosis, Idiopathic',
#    'Pulmonary Stenosis',
#    'Stenosis, Pulmonary',
#    'Pulmonary Atresia',
#    'Tricuspid Incompetence',
#    'Floppy Mitral Valve',
#    'Stenoses, Pulmonary Subvalvular',
#    'Mitral Valve Stenosis',
#    'Regurgitation, Aortic Valve',
#    'Multiple Lentigines Syndrome',
#    'Williams Syndrome',
#    'Tricuspid Valve Insufficiency',
#    'Aortic Heart Disease',
#    'Aortic Valve Incompetence',
#    'Subvalvular Stenoses, Pulmonary',
#    'Valve Regurgitation, Pulmonary',
#    'Pulmonary Atresias',
#    'Mitral Valve Insufficiency',
#    'Pulmonary Regurgitation',
#    'Quadricuspid Aortic Valve Disease',
#    'Contiguous Gene Syndrome, Williams',
#    'Tricuspid Valve Prolapse',
#    'Pulmonary Valve Insufficiency',
#    'Obstructive Asymmetric Septal Hypertrophy',
#    'Valve Incompetence, Pulmonary',
#    'Pulmonic Stenosis',
#    'Infundibular Stenoses, Pulmonary',
#    'Cardiomyopathic Lentiginosis',
#    'Mitral Insufficiency',
#    'Aortic Supravalvular Stenosis',
#    'Stenosis, Supravalvular Aortic',
#    'Noonan Syndrome with Multiple Lentigines',
#    'Aortic Valve Disease',
#    'Bicuspid Aortic Valve',
#    'Ventricular Hypertrophy, Familial',
#    'Tricuspid Valve Atresia',
#    'Prolapsed Mitral Valve',
#    'Leopard Syndrome 1',
#    'Hereditary Ventricular Hypertrophy',
#    'Asymmetric Septal Hypertrophy, Familial',
#    'Hypercalcemia-Supravalvar Aortic Stenosis',
#    'Click-Murmur Syndrome',
#    'Aortic Valve Prolapse',
#    'Aortic Valvular Heart Disorder',
#    'Incompetence, Pulmonary Valve',
#    'Pulmonary Valve Stenoses',
#    'Quadricuspid Aortic Valve Disorder',
#    'Regurgitation, Pulmonary Valve',
#    'Pulmonary Subvalvular Stenosis',
#    'Pulmonary Infundibular Stenoses',
#    'Insufficiency, Pulmonary Valve',
#    'Atresia, Tricuspid',
#    'Mitral Valve Prolapse',
#    'Bicuspid Aortic Valve Disease',
#    'Absent Right Atrioventricular Connection',
#    'Quadricuspid Aortic Valve',
#    'Beuren Syndrome',
#    'Mitral Click-Murmur Syndrome',
#    'Aortic Regurgitation',
#    'LEOPARD Syndrome, 1',
#    'Systolic Click-Murmur Syndrome',
#    'Stenoses, Pulmonary Valve',
#    'Stenosis, Pulmonary Infundibular',
#    'Aortic Valve Insufficiency',
#    'Aortic Valve Disease 1',
#    'Mitral Regurgitation',
#    'Pulmonary Subvalvular Stenoses',
#    'Cardiomyopathy, Hypertrophic',
#    'Aortic Subvalvular Stenosis',
#    'Aortic Stenosis, Supravalvular',
#    'Tricuspid Regurgitation',
#    'Subaortic Stenosis, Discrete',
#    'Tricuspid Valve Incompetence',
#    'Pulmonary Stenoses, Subvalvular',
#    'Williams-Beuren Syndrome',
#    'Supravalvar Aortic Stenosis Syndrome',
#    'Williams Contiguous Gene Syndrome',
#    'Mitral Valve Incompetence',
#    'Aortic Valve Disorder',
#    'Stenosis, Pulmonary Valve',
#    'Infundibular Stenosis, Pulmonary',
#    'Mitral Valve Prolapse Syndrome',
#    'Valve Insufficiency, Pulmonary',
#    'Stenosis, Aortic Supravalvular',
#    'Supravalvar Aortic Stenosis',
#    'Atresia, Pulmonary',
#    'Chromosome 7q11.23 Deletion Syndrome',
#    'Tricuspid Valve Stenosis',
#    'Aortic Stenosis, Subvalvular',
#    'Valvular Pulmonic Stenosis',
#    'Cardiomyopathy, Familial Hypertrophic',
#    'Valvular Heart Diseases',
#    'Pulmonary Valve Incompetence',
#    'Subvalvular Pulmonary Stenosis',
#    'Obstructive Subaortic Conus',
#    'Aortic Valvular Heart Disease',
#    'Mitral Valve Regurgitation',
#    'Aortic Incompetence',
#    'Pulmonary Valve Stenosis',
#    'Cardiomyopathy, Hypertrophic, Familial',
#    'Mitral Stenosis',
#    'Subvalvular Stenosis, Pulmonary',
#    'Tricuspid Valve Regurgitation',
#    'Aortic Stenosis',
#    'Pulmonary Valve Atresia',
#    'LEOPARD Syndrome',
#    'Progressive Cardiomyopathic Lentiginosis',
#    'Stenoses, Pulmonary Infundibular',
#    'Stenoses, Pulmonary',
#    'Discrete Subaortic Stenosis',
#    'Quadricuspid Aortic Valvular Disease',
#    'Quadricuspid Aortic Valve Condition',
#    'Mitral Incompetence'],
#   ['X Syndrome, Angina',
#    'Shock, Cardiogenic',
#    "Prinzmetal's Angina",
#    'Angor Pectoris',
#    'Coronary Thrombosis',
#    'Coronary Aneurysm',
#    'Injury, Myocardial Reperfusion',
#    'Coronary Disease',
#    'ST Elevated Myocardial Infarction',
#    'Angina, Microvascular',
#    'Angina, Preinfarction',
#    'Allergic Myocardial Infarction',
#    'Thrombosis, Coronary',
#    'Anterolateral Myocardial Infarction',
#    'Myocardial Infarction with Nonobstructive Coronary Arteries',
#    'Angina Pectoris',
#    'Heart Attack',
#    'Myocardial Infarction with Non-obstructive Coronary Arteries',
#    'Angina, Stable',
#    'Coronary Stenosis',
#    'Coronary Arteriosclerosis',
#    'Myocardial Infarction, Anterior Wall',
#    'Diaphragmatic Myocardial Infarction',
#    'Myocardial Preinfarction Syndrome',
#    'Cardiac Syndrome X',
#    'Myocardial Ischemic Reperfusion Injury',
#    'Coronary-Subclavian Steal Syndrome',
#    'Prinzmetal Angina',
#    'Anterior Wall Myocardial Infarction',
#    'Allergic Acute Coronary Syndrome',
#    'Myocardial Infarction and Non-obstructed Coronary Arteries',
#    'Coronary Artery Disease',
#    'Coronary Restenosis',
#    'Myocardial Ischemia',
#    'Anteroseptal Myocardial Infarction',
#    'Syndrome X, Cardiac',
#    'Heart Disease, Ischemic',
#    'Angina Pectoris, Variant',
#    'Inferior Myocardial Infarction',
#    'Allergic Angina Syndrome',
#    'Cardiovascular Stroke',
#    'STEMI',
#    'Myocardial Reperfusion Injury',
#    'ST Segment Elevation Myocardial Infarction',
#    'Stenocardia',
#    'Angina Pectoris with Normal Coronary Arteriogram',
#    'Kounis Syndrome',
#    'Left Main Coronary Artery Disease',
#    'Inferior Wall Myocardial Infarction',
#    'Acute Coronary Syndrome',
#    'Chronic Stable Angina',
#    'Acute Inferior Myocardial Infarction',
#    'Ischemic Heart Disease',
#    'Microvascular Angina',
#    'Left Main Disease',
#    'Arteriosclerosis, Coronary',
#    'MINOCA',
#    'Coronary Atherosclerosis',
#    'Myocardial Infarction and Nonobstructed Coronary Arteries',
#    'Coronary Occlusion',
#    'Non-ST Elevated Myocardial Infarction',
#    'Acute Anterior Wall Myocardial Infarction',
#    'NSTEMI',
#    'Coronary Artery Vasospasm',
#    'Angina at Rest',
#    'Angina Pectoris, Stable',
#    'Atherosclerosis, Coronary',
#    'ST Elevation Myocardial Infarction',
#    'Myocardial Infarction, Inferior Wall',
#    'Angina, Unstable',
#    'Angina Pectoris, Unstable',
#    'Aneurysm, Coronary',
#    'Syndrome X, Angina',
#    'Coronary Heart Disease',
#    'Non-ST-Elevation Myocardial Infarction',
#    'Left Main Coronary Disease',
#    'Unstable Angina',
#    'Coronary Artery Stenosis',
#    'Coronary Vasospasm',
#    'Myocardial Infarction',
#    'Ischemia, Myocardial',
#    'Myocardial Infarct',
#    'Coronary Stenoses',
#    'Reperfusion Injury, Myocardial'],
#   ['Wolff-Parkinson-White Syndrome',
#    'Tachycardia, Paroxysmal',
#    'Cardiac Conduction Defects',
#    'Surdo-Cardiac Syndrome',
#    'Right Bundle-Branch Block',
#    'Adam-Stokes Attacks',
#    'Extrasystole, Ventricular',
#    'Ventricular Tachycardia',
#    'Atrioventricular Conduction Block',
#    'Tachycardia, Ventricular',
#    'Ventricular Tachyarrhythmias',
#    'Nonsustained Ventricular Tachycardia',
#    'Sinus Node Dysfunction',
#    'Long QT Syndrome Type 1',
#    'Right Bundle Branch Block, ST Segment Elevation, and Sudden Death Syndrome',
#    'Andersen Syndrome',
#    'Premature Ventricular Contractions',
#    'Sinoatrial Nodal Reentry Tachycardia',
#    'Tachycardia',
#    'Tachycardia, Ectopic Atrial',
#    'AV Block',
#    'Cardiac Conduction System Diseases',
#    'Premature Cardiac Complexes',
#    'Nodofascicular Mahaim-Type Pre-Excitation',
#    'Mahaim-Type Pre-Excitation, Nodoventricular',
#    'Sinoatrial Exit Block',
#    'Junctional Ectopic Tachycardia',
#    'WPW Syndrome',
#    'Auriculo-Ventricular Dissociation',
#    'Ectopic Junctional Tachycardia',
#    'Accelerated Idioventricular Rhythm',
#    'Mahaim-Type Pre-Excitation, Nodofascicular',
#    'Ectopic Atrial Tachycardia',
#    'Atrioventricular Nodal Re-Entrant Tachycardia',
#    'Jervell And Lange-Nielsen Syndrome 1',
#    'Fascicular Block',
#    'Interatrial Block',
#    'Cardiac Conduction System Disease',
#    'Pre-Excitation Syndromes',
#    'Periodic Paralysis, Potassium-Sensitive Cardiodysrhythmic Type',
#    'Extrasystole',
#    'Lown-Ganong-Levine Syndrome',
#    'Tachycardia, Ectopic Junctional',
#    'Tachycardia, Reciprocating',
#    'Short PR-Normal QRS Complex Syndrome',
#    'Long QT Syndrome',
#    'Sinus Node Disease',
#    'Torsades de Pointes',
#    'Paroxysmal Supraventricular Tachycardia',
#    'Idiopathic Ventricular Tachycardia',
#    'Extrasystoles',
#    'Sudden Unexplained Nocturnal Death Syndrome (SUNDS)',
#    'Left Bundle-Branch Block',
#    'Pre-Excitation, Mahaim-Type',
#    'Mahaim-Type Pre-Excitation',
#    'Bundle Branch Block',
#    'Jervell-Lange Nielsen Syndrome',
#    'Premature Cardiac Complex',
#    'Tachycardia, SA Nodal Reentrant',
#    'Atrioventricular Nodal Reentry Tachycardia',
#    'Heart Block',
#    'Premature Atrial Contractions',
#    'Tachycardia, Atrioventricular Nodal Reentry',
#    'Mahaim-Type Preexcitation',
#    'Paroxysmal Reciprocal Tachycardia',
#    'Tachycardia, Reciprocal',
#    'Bayes Syndrome',
#    'Long QT Syndrome 1',
#    'Tachycardia, Supraventricular',
#    'Premature Supraventricular Beats',
#    'Andersen-Tawil Syndrome',
#    'Brugada Syndrome',
#    'Romano-Ward Syndrome',
#    'Adams-Stokes Syndrome',
#    'Premature Ventricular Beats',
#    'Premature Ventricular Complex',
#    'Stokes-Adams Attacks',
#    'AIVR',
#    'Atrial Ectopic Beats',
#    'Atrioventricular Nodal Reentrant Tachycardia',
#    'Brugada ECG Pattern',
#    'Reciprocal Tachycardia',
#    'Atrial Premature Complexes',
#    'Ward-Romano Syndrome',
#    'Premature Beats',
#    'Jervell and Lange-Nielsen Syndrome',
#    "Bayes' Syndrome",
#    'Ventricular Premature Complexes',
#    'Sinoatrial Block',
#    'Interatrial Conduction Delay',
#    'Slow Ventricular Tachycardia',
#    'Premature Atrial Beats',
#    'Potassium-Sensitive Periodic Paralysis, Ventricular Ectopy, and Dysmorphic Features',
#    'Cardiac Complex, Premature',
#    'Cardio-Auditory-Syncope Syndrome',
#    'Sudden Unexplained Death Syndrome',
#    'Ventricular Premature Complex',
#    'A-V Dissociation',
#    'Cardiac Conduction Defect',
#    'Anterior Fascicular Block',
#    'Nodoventricular Mahaim-Type Pre-Excitation',
#    'Premature Atrial Complex',
#    'Ventricular Ectopic Beats',
#    'Tachycardia, Sinus',
#    'Tachycardia, Sinoatrial Nodal Reentry',
#    'Sinus Node Reentrant Tachycardia',
#    'Deafness, Congenital, and Functional Heart Disease',
#    'Anomalous Ventricular Excitation Syndrome',
#    'Andersen Cardiodysrhythmic Periodic Paralysis',
#    'Bundle-Branch Block',
#    'Atrioventricular Dissociation',
#    'Extrasystole, Atrial',
#    'Tachycardia, AV Nodal Reentrant',
#    'Preexcitation Syndrome',
#    'AV Nodal Reentrant Tachycardia',
#    'Prolonged QT Interval in EKG and Sudden Death',
#    'Ventricular Pre-Excitation with Arrhythmia',
#    'Ventricular Fibrillation with Prolonged QT Interval',
#    'Electrocardiogram QT Prolonged',
#    'Brugada Syndrome 1',
#    'Atrial Premature Complex',
#    'Atrioventricular Reentrant Tachycardia',
#    'Ectopic Heartbeats',
#    'Reciprocating Tachycardia',
#    'Cardioauditory Syndrome of Jervell and Lange-Nielsen',
#    'Sick Sinus Syndrome',
#    'Sudden Unexplained Nocturnal Death Syndrome',
#    'Posterior Fascicular Block',
#    'Andersen Tawil Syndrome',
#    'Sinus Tachycardia',
#    'Sick Sinus Node Syndrome',
#    'Tachyarrhythmia',
#    'False Bundle-Branch Block Syndrome',
#    'Atrial Ectopic Tachycardia',
#    'Andersen Cardiodysrythmic Periodic Paralysis',
#    'Long QT Syndrome 7',
#    'Torsade de Pointes',
#    'Auriculoventricular Accessory Pathway Syndrome',
#    'Stokes-Adams Syndrome',
#    'Cardiac Complexes, Premature',
#    'Atrioventricular Block',
#    'Wolf-Parkinson-White Syndrome',
#    'Brugada Type ECG Pattern'],
#   ['Supravalvular Stenosis, Aortic',
#    'Outflow Obstruction, Right Ventricular',
#    'Pulmonary Infundibular Stenosis',
#    'Outflow Obstruction, Left Ventricular',
#    'Pulmonary Valve Stenoses',
#    'Stenoses, Pulmonary Subvalvular',
#    'Stenosis, Pulmonary Subvalvular',
#    'Ventricular Outflow Obstruction, Left',
#    'Pulmonary Subvalvular Stenosis',
#    'Stenosis, Pulmonary Valve',
#    'Infundibular Stenosis, Pulmonary',
#    'Pulmonary Infundibular Stenoses',
#    'Stenosis, Subvalvular Pulmonary',
#    'Subvalvular Stenoses, Pulmonary',
#    'Pulmonary Stenosis, Subvalvular',
#    'Stenosis, Aortic Supravalvular',
#    'Right Ventricular Outflow Obstruction',
#    'Supravalvar Aortic Stenosis',
#    'Supravalvular Aortic Stenosis',
#    'Valvular Pulmonic Stenosis',
#    'Stenoses, Subvalvular Pulmonary',
#    'Aortic Stenosis, Subvalvular',
#    'Ventricular Outflow Obstruction',
#    'Subvalvular Pulmonary Stenosis',
#    'Pulmonic Stenosis',
#    'Infundibular Stenoses, Pulmonary',
#    'Obstructive Subaortic Conus',
#    'Stenoses, Pulmonary Valve',
#    'Ventricular Outflow Obstruction, Right',
#    'Aortic Supravalvular Stenosis',
#    'Pulmonary Valve Stenosis',
#    'Stenosis, Pulmonary Infundibular',
#    'Aortic Valve Stenosis',
#    'Subvalvular Aortic Stenosis',
#    'Stenosis, Supravalvular Aortic',
#    'Pulmonary Subvalvular Stenoses',
#    'Subvalvular Stenosis, Pulmonary',
#    'Pulmonary Stenoses',
#    'Subvalvular Pulmonary Stenoses',
#    'Aortic Stenosis',
#    'Aortic Subvalvular Stenosis',
#    'Stenoses, Pulmonary Infundibular',
#    'Pulmonary Stenosis',
#    'Aortic Stenosis, Supravalvular',
#    'Left Ventricular Outflow Obstruction',
#    'Subaortic Stenosis, Discrete',
#    'Stenoses, Pulmonary',
#    'Discrete Subaortic Stenosis',
#    'Pulmonary Stenoses, Subvalvular',
#    'Stenosis, Pulmonary'],
#   ['Cardiomyopathy, Congestive',
#    'Cardiopulmonary Arrest',
#    'Cardiomegaly',
#    'Broken Heart Syndrome',
#    'Cardiomyopathy, Familial Idiopathic',
#    'Pick Disease of Heart',
#    'Congestive Cardiomyopathy',
#    'Dilated Cardiomyopathy',
#    'Endocarditis, Non-Bacterial Thrombotic',
#    'Papillary Fibroelastoma',
#    'Apical Ballooning Syndrome',
#    'NAME Syndrome',
#    'Bacterial Endocarditides, Subacute',
#    'Karoshi Death',
#    'Death, Sudden, Cardiac',
#    'Constrictive Pericarditis',
#    'Left Ventricular Hypertrophy',
#    'Sudden Cardiac Death',
#    'Left Ventricular Apical Ballooning Syndrome',
#    'Bacterial Endocarditis',
#    'Cardiac Free Wall Rupture',
#    'Endocarditis',
#    'Cardiac Rupture',
#    'Right Ventricular Hypertrophy',
#    'Neoplasms, Cardiac',
#    'Post-Infarction Heart Rupture',
#    'Cardiac Arrest, Sudden',
#    'Out-of-Hospital Heart Arrest',
#    'Marantic Endocarditis',
#    'Intracavitary Tumors of the Heart',
#    'Cardiomyopathy, Dilated, with Conduction Deffect1',
#    'Ventricular Hypertrophy, Right',
#    'LAMB Syndrome',
#    'Cardiomyopathy, Dilated, Autosomal Recessive',
#    'Cardiac Carcinoma',
#    'Pericarditis, Tuberculous',
#    'Neoplasms, Heart',
#    'Endocarditis, Bacterial',
#    'Cardiac Tumor',
#    'Infective Endocarditis',
#    'Heart Arrest',
#    'Ventricular Hypertrophy, Left',
#    'Cardiac Sudden Death',
#    'Ventricular Dysfunction, Right',
#    'Cardiac Neoplasms',
#    'Asystole',
#    'Cardiomyopathy, Dilated, 1a',
#    'Pericarditis',
#    'Heart Rupture',
#    'Carney Myxoma-Endocrine Complex',
#    'Carney Complex',
#    'Ventricular Septal Perforation',
#    'Pericarditis, Constrictive',
#    'Cardiac Hypertrophy',
#    'Takotsubo Syndrome',
#    'Heart Enlargement',
#    'Sudden Cardiac Arrest',
#    'Tako-tsubo Cardiomyopathy',
#    'Heart Neoplasms',
#    'Non-Bacterial Thrombotic Endocarditis',
#    'Endocarditides, Bacterial',
#    'Cardiac Papillary Fibroelastoma',
#    'Cardiac Tumors',
#    'Carney Myxoma-Endocrine Complex, Type II',
#    'Ventricular Septal Rupture',
#    'Stress Cardiomyopathy',
#    'Cardiomyopathy, Dilated, With Conduction Defect 1',
#    'Takotsubo Cardiomyopathy',
#    'Cardiac Cancer',
#    'LAMB - Lentigines, Atrial Myxoma, Mucocutaneous Myoma, Blue Nevus Syndrome',
#    'Carney Complex, Type 1',
#    'Myxoma, Spotty Pigmentation, and Endocrine Overactivity',
#    'Subacute Bacterial Endocarditis',
#    'Hypertrophy, Left Ventricular',
#    "Pick's Disease of Heart",
#    'Heart Tumor',
#    'Heart Rupture, Post-Infarction',
#    'Endocarditides, Subacute Bacterial',
#    'Cardiomyopathy, Dilated, CMD1A',
#    'Ventricular Dysfunction',
#    'Right Ventricular Dysfunction',
#    'Myocardial Tumors (Rhabdomyomas and Fibromas)',
#    'Transient Apical Ballooning Syndrome',
#    'Cardiac Arrest',
#    'Ventricular Dysfunction, Left',
#    'Subacute Bacterial Endocarditides',
#    'Cardiomyopathy, Dilated',
#    'Bacterial Endocarditides',
#    'Tuberculous Pericarditis',
#    'Enlarged Heart',
#    'Tako-tsubo Syndrome',
#    'Endocarditis, Subacute Bacterial',
#    'Bacterial Endocarditis, Subacute',
#    'Carney Syndrome',
#    'Pleuropericarditis',
#    'Endocarditis, Non-Infective',
#    'Out-of-Hospital Cardiac Arrest',
#    'Carney Complex, Type I',
#    'Cardiac Rupture, Post-Infarction',
#    'Non-Infective Endocarditis',
#    'Heart Cancer',
#    'Karoshi-Death',
#    'Primary Cardiac Tumors, Childhood',
#    'Cardiomyopathy, Dilated, LMNA',
#    'Nevi, Atrial Myxoma, Skin Myxoma, Ephelides Syndrome',
#    'Carney Complex, Type 2',
#    'Carney Complex, Type II',
#    'Heart Hypertrophy',
#    'Endocarditis Lenta',
#    'Cardiomyopathy, Idiopathic Dilated',
#    'Hypertrophy, Right Ventricular',
#    'Left Ventricular Dysfunction',
#    'Free Wall Rupture, Heart',
#    'Ventricular Free Wall Rupture']],
#  'top_n_words': 10,
#  'umap_model': <bertopic.dimensionality._base.BaseDimensionalityReduction at 0x7afb8dd98f10>,
#  'vectorizer_model': CountVectorizer(),
#  'verbose': False}

# %%
df = topic_model_1.get_topic_info()

# %%
df
# Out:
#    Topic  Count                                               Name  \
# 0     -1  11454             -1_stenosis_aortic_ventricular_cardiac
# 1      0    614       0_abnormalities_trisomy_mutations_congenital
# 2      1    301  1_tachyarrhythmias_arrhythmias_tachycardia_arr...
# 3      2    200        2_cardiac_ventricular_tachycardia_mutations
# 4      3    148  3_endocarditis_coxsackievirus_myocarditis_peri...
# 5      4     57  4_cardiomyocyte_myocarditis_immunoglobulins_pr...
# 6      5     32        5_dysplasia_congenital_diagnosis_dyskinesia
# 7      6     21  6_peroxidation_lipoperoxidation_hypercholester...
# 8      7     16   7_dilution_saturation_sampling_bronchoscopically
#
#                                       Representation  \
# 0  [stenosis, aortic, ventricular, cardiac, myoca...
# 1  [abnormalities, trisomy, mutations, congenital...
# 2  [tachyarrhythmias, arrhythmias, tachycardia, a...
# 3  [cardiac, ventricular, tachycardia, mutations,...
# 4  [endocarditis, coxsackievirus, myocarditis, pe...
# 5  [cardiomyocyte, myocarditis, immunoglobulins, ...
# 6  [dysplasia, congenital, diagnosis, dyskinesia,...
# 7  [peroxidation, lipoperoxidation, hypercholeste...
# 8  [dilution, saturation, sampling, bronchoscopic...
#
#                                  Representative_Docs
# 0  [The study aim was to assess the value of exer...
# 1  [Conotruncal heart defects (CTDs) are present ...
# 2  [A computer-assisted analysis of the TU-comple...
# 3  [The congenital long QT syndrome is a potentia...
# 4  [BACKGROUND Calcified amorphous tumor (CAT) of...
# 5  [The impact and clinical relevance of pregnanc...
# 6  [To determine whether CT-guided mucociliary cl...
# 7  [It was found that glucose in the range of con...
# 8  [In an article in a previous issue of the Jour...

# %%
sum(df['Count'])
# Out:
# 12843

# %%
len(data)
# Out:
# 18846

# %%
list(df['Representation'])[0]
# Out:
# ['and', 'in', 'with', 'to', 'of', 'the', 'patients', 'was', 'for', 'were']

# %%
df_doc = topic_model_1.get_document_info(docs_1_)

# %%
df_doc['Top_n_words'][0]
# Out:
# 'and - in - with - to - of - the - patients - was - for - were'

# %%
topic_model_1.visualize_topics()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="5f6adb9f-a454-47e6-bd52-de5354312860" class="plotly-graph-div" style="height:650px; width:650px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("5f6adb9f-a454-47e6-bd52-de5354312860")) {                    Plotly.newPlot(                        "5f6adb9f-a454-47e6-bd52-de5354312860",                        [{"customdata":[[0,"syndrome | turner | chromosome | deletion | congenital",614],[1,"tachycardia | atrial | fibrillation | syndrome | qt",301],[2,"syndrome | wolffparkinsonwhite | long | qt | mutations",200],[3,"endocarditis | infection | case | myocarditis | infective",148],[4,"cruzi | c1qtnf1 | mice | autophagy | nafld",57],[5,"pcd | bronchiectasis | cyclopia | children | distress",32],[6,"klf7 | macrophages | monocytes | wk | kgl",21],[7,"tracheostomy | pdt | exchange | tubes | saturation",16]],"hovertemplate":"\u003cb\u003eTopic %{customdata[0]}\u003c\u002fb\u003e\u003cbr\u003e%{customdata[1]}\u003cbr\u003eSize: %{customdata[2]}","legendgroup":"","marker":{"color":"#B0BEC5","size":[614,301,200,148,57,32,21,16],"sizemode":"area","sizeref":0.38375,"symbol":"circle","line":{"color":"DarkSlateGrey","width":2}},"mode":"markers","name":"","orientation":"v","showlegend":false,"x":[11.738675117492676,18.08922004699707,17.76169204711914,-22.14584732055664,-21.75462532043457,11.447576522827148,-21.39516830444336,11.031296730041504],"xaxis":"x","y":[-15.10908031463623,27.508865356445312,27.181312561035156,7.226250648498535,6.834833145141602,-14.817999839782715,6.475526332855225,-14.401703834533691],"yaxis":"y","type":"scatter"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"rgb(36,36,36)"},"error_y":{"color":"rgb(36,36,36)"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"rgb(36,36,36)","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"rgb(36,36,36)"},"baxis":{"endlinecolor":"rgb(36,36,36)","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"rgb(36,36,36)"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"type":"heatmapgl"}],"heatmap":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"type":"heatmap"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":1,"tickcol ...

# %% [markdown]
# ## To-Do: 08/31
#   - combine the title and abstract together
#   - model:
#     - try to see if possible to modify the weights of the seed (1.2 to 1.5)
#     - change ngram range
#   - seed_topic_list:
#     - lowercase everything
#     - split them into individual words and remove trivial words
#     - include words that are only in one topic (remove overlapping words maybe)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import json
category2synonyms = json.load(open('drive/MyDrive/bertopic/caseolap_lift/text_mining/category2synonyms.json'))

# %%
category2synonyms
# Out:
# {'CM': ['Cardiomyopathy, Congestive',
#   'Congestive Heart Failure',
#   'Cardiomyopathy, Familial Idiopathic',
#   'Congestive Cardiomyopathy',
#   'Dilated Cardiomyopathy',
#   'Familial Hypertrophic Cardiomyopathy',
#   'Dyspnea, Paroxysmal',
#   'Asthma, Cardiac',
#   'Myocarditis',
#   'Injury, Myocardial Reperfusion',
#   'Heart Failure',
#   'Chagas Cardiomyopathy',
#   'Ventricular Dysplasia, Right, Arrhythmogenic',
#   'Secondary Myocardial Diseases',
#   'Left-Sided Heart Failure',
#   'Heart Failure, Congestive',
#   'Cardiomyopathy, Hypertrophic Obstructive',
#   'Heart Failure, Normal Ejection Fraction',
#   'Adhalinopathy, Primary',
#   'Myocardial Disease',
#   'CPEO with Myopathy',
#   'Ophthalmoplegia Plus Syndrome',
#   'Cardiomyopathies',
#   'Hypertrophic Subaortic Stenosis, Idiopathic',
#   'LGMD2D',
#   'Limb-Girdle Muscular Dystrophy, Type 2D',
#   'Noncompaction of the Left Ventricular Myocardium, Autosomal Dominant',
#   'Cardiac Failure',
#   'Myocardial Ischemic Reperfusion Injury',
#   'Alpha-Sarcoglycanopathy',
#   'Cardiomyopathy, Dilated, with Conduction Deffect1',
#   'Right-Sided Heart Failure',
#   'Chronic Progressive External Ophthalmoplegia with Myopathy',
#   'Carditis',
#   'Cardiomyopathy, Dilated, Autosomal Recessive',
#   "Kearns' Syndrome",
#   'Obstructive Asymmetric Septal Hypertrophy',
#   'Endomyocardial Fibrosis',
#   'Cardiomyopathy, Alcoholic',
#   'Sarcoglycanopathy',
#   'Kearns Syndrome',
#   'Alpha-Sarcoglycanopathies',
#   'Primary Myocardial Diseases',
#   'Myocardial Reperfusion Injury',
#   'Arrhythmogenic Right Ventricular Dysplasia',
#   'Cardiac Edema',
#   'Ventricular Hypertrophy, Familial',
#   'Familial Restrictive Cardiomyopathy',
#   'Duchenne-Like Autosomal Recessive Muscular Dystrophy, Type 2',
#   'Heart Failure, Systolic',
#   'Myocardial Failure',
#   'Isolated Noncompaction of the Ventricular Myocardium',
#   'Endomyocardial Fibroelastosis',
#   'Hereditary Ventricular Hypertrophy',
#   'Vacuolar Cardiomyopathy and Myopathy, X-linked',
#   'Asymmetric Septal Hypertrophy, Familial',
#   'Cpeo With Ragged-Red Fibers',
#   'ARVD-C',
#   'Danon Disease',
#   'Ophthalmoplegia-Plus Syndrome',
#   'Cardiomyopathy, Dilated, 1a',
#   'Primary Myocardial Disease',
#   'X-Linked Vacuolar Cardiomyopathy and Myopathy',
#   'Systolic Heart Failure',
#   'Kearns Sayre Syndrome',
#   'Cardiorenal Syndrome',
#   'Kearn-Sayre Mitochondrial Cytopathy',
#   'Lysosomal Glycogen Storage Disease with Normal Acid Maltase',
#   'Isolated Non-compaction of the Ventricular Myocardium',
#   'Dyspnea, Paroxysmal Nocturnal',
#   'Kearns-Sayre Syndrome',
#   'Myocardiopathies',
#   'Lysosomal Glycogen Storage Disease without Acid Maltase Deficiency',
#   'Arrhythmogenic Right Ventricular Cardiomyopathy',
#   'Arrhythmogenic Right Ventricular Dysplasia-Cardiomyopathy',
#   'Glycogen Storage Disease Limited to the Heart',
#   'Glycogen Storage Disease Type 2B',
#   'Myocardial Diseases',
#   'Heart Failure, Right-Sided',
#   'CPEO with Ragged Red Fibers',
#   'Alcoholic Cardiomyopathy',
#   'Cardiomyopathy, Dilated, With Conduction Defect 1',
#   'Glycogen Storage Disease IIb',
#   'Cardiomyopathy, Hypertrophic',
#   'Myocardial Diseases, Primary',
#   'Muscular Dystrophy, Limb-Girdle, Type 2D',
#   'Heart Failure, Reduced Ejection Fraction',
#   'Sarcoglycanopathies',
#   'Ophthalmoplegia, Progressive External, With Ragged-Red Fibers',
#   'Reno-Cardiac Syndrome',
#   'Oculocraniosomatic Syndrome',
#   'Arrhythmogenic Right Ventricular Cardiomyopathy-Dysplasia',
#   'Cardiomyopathy, Dilated, CMD1A',
#   'Edema, Cardiac',
#   'Pseudoglycogenosis II',
#   'Pseudoglycogenosis 2',
#   'Diabetic Cardiomyopathies',
#   'Trypanosomiasis, Cardiovascular',
#   'Cardiomyopathy, Dilated',
#   'Cardiomyopathy, Chagas',
#   'Antopol Disease',
#   'Right Ventricular Dysplasia, Arrhythmogenic',
#   'Isolated Noncompaction of the Left Ventricular Myocardium, X-Linked',
#   'Adhalinopathies',
#   'Cardiomyopathy, Familial Hypertrophic',
#   'Cardiomyopathies, Secondary',
#   'Muscular Dystrophy Limb-Girdle with Alpha-Sarcoglycan Deficiency',
#   'Glycogen Storage Cardiomyopathy',
#   'Heart Failure, Left-Sided',
#   'Heart Failure, Preserved Ejection Fraction',
#   'Cardiomyopathy, Hypertrophic, Familial',
#   'Heart Decompensation',
#   'Cardiomyopathies, Primary',
#   'Cardiomyopathy, Dilated, LMNA',
#   'Cardio-Renal Syndrome',
#   'Kearns-Sayre Mitochondrial Cytopathy',
#   'Endocardial Fibroelastosis',
#   'Heart Failure, Diastolic',
#   'Kearns-Sayre-Shy-Daroff Syndrome',
#   'Renocardiac Syndrome',
#   'Myocarditis, Chagas',
#   'Ophthalmoplegia, Pigmentary Degeneration of Retina, and Cardiomyopathy',
#   'Cardiomyopathy, Idiopathic Dilated',
#   "Chagas' Cardiomyopathy",
#   'Glycogen Storage Disease Type IIb',
#   'Diastolic Heart Failure',
#   'Cardiomyopathy, Restrictive',
#   'Myocardial Diseases, Secondary',
#   'Reperfusion Injury, Myocardial',
#   'Ventricular Hypertrophy, Hereditary'],
#  'ARR': ['Wolff-Parkinson-White Syndrome',
#   'Tachycardia, Paroxysmal',
#   'Cardiac Sinus Pause',
#   'Surdo-Cardiac Syndrome',
#   'Right Bundle-Branch Block',
#   'Adam-Stokes Attacks',
#   'Extrasystole, Ventricular',
#   'Ventricular Tachycardia',
#   'Atrioventricular Conduction Block',
#   'Ventricular Fibrillation',
#   'Tachycardia, Ventricular',
#   'Ventricular Tachyarrhythmias',
#   'Nonsustained Ventricular Tachycardia',
#   'Arrhythmia',
#   'Sinus Node Dysfunction',
#   'Long QT Syndrome Type 1',
#   'Right Bundle Branch Block, ST Segment Elevation, and Sudden Death Syndrome',
#   'Andersen Syndrome',
#   'Premature Ventricular Contractions',
#   'Sinoatrial Nodal Reentry Tachycardia',
#   'Tachycardia',
#   'Tachycardia, Ectopic Atrial',
#   'AV Block',
#   'Premature Cardiac Complexes',
#   'Nodofascicular Mahaim-Type Pre-Excitation',
#   'Mahaim-Type Pre-Excitation, Nodoventricular',
#   'Sinoatrial Exit Block',
#   'Junctional Ectopic Tachycardia',
#   'WPW Syndrome',
#   'Auriculo-Ventricular Dissociation',
#   'Ectopic Junctional Tachycardia',
#   'Accelerated Idioventricular Rhythm',
#   'Paroxysmal Atrial Fibrillation',
#   'Mahaim-Type Pre-Excitation, Nodofascicular',
#   'Persistent Atrial Fibrillation',
#   'Sinoatrial Arrhythmia',
#   'Atrioventricular Nodal Re-Entrant Tachycardia',
#   'Jervell And Lange-Nielsen Syndrome 1',
#   'Fascicular Block',
#   'Ectopic Atrial Tachycardia',
#   'Interatrial Block',
#   'Pre-Excitation Syndromes',
#   'Periodic Paralysis, Potassium-Sensitive Cardiodysrhythmic Type',
#   'Extrasystole',
#   'Lown-Ganong-Levine Syndrome',
#   'Bradyarrhythmia',
#   'Tachycardia, Ectopic Junctional',
#   'Tachycardia, Reciprocating',
#   'Short PR-Normal QRS Complex Syndrome',
#   'Long QT Syndrome',
#   'Sinus Node Disease',
#   'Torsades de Pointes',
#   'Paroxysmal Supraventricular Tachycardia',
#   'Idiopathic Ventricular Tachycardia',
#   'Extrasystoles',
#   'Sudden Unexplained Nocturnal Death Syndrome (SUNDS)',
#   'Left Bundle-Branch Block',
#   'Auricular Flutter',
#   'Pre-Excitation, Mahaim-Type',
#   'Mahaim-Type Pre-Excitation',
#   'Bundle Branch Block',
#   'Ventricular Flutter',
#   'Jervell-Lange Nielsen Syndrome',
#   'Premature Cardiac Complex',
#   'Tachycardia, SA Nodal Reentrant',
#   'Atrioventricular Nodal Reentry Tachycardia',
#   'Bradycardia',
#   'Heart Block',
#   'Parasystole',
#   'Premature Atrial Contractions',
#   'Tachycardia, Atrioventricular Nodal Reentry',
#   'Mahaim-Type Preexcitation',
#   'Paroxysmal Reciprocal Tachycardia',
#   'Tachycardia, Reciprocal',
#   'Bayes Syndrome',
#   'Long QT Syndrome 1',
#   'Tachycardia, Supraventricular',
#   'Atrial Flutter',
#   'Premature Supraventricular Beats',
#   'Andersen-Tawil Syndrome',
#   'Atrial Fibrillation',
#   'Brugada Syndrome',
#   'Romano-Ward Syndrome',
#   'Adams-Stokes Syndrome',
#   'Premature Ventricular Beats',
#   'Premature Ventricular Complex',
#   'Stokes-Adams Attacks',
#   'Arrhythmia, Sinoatrial',
#   'AIVR',
#   'Atrial Ectopic Beats',
#   'Atrioventricular Nodal Reentrant Tachycardia',
#   'Brugada ECG Pattern',
#   'Reciprocal Tachycardia',
#   'Atrial Premature Complexes',
#   'Ward-Romano Syndrome',
#   'Premature Beats',
#   'Jervell and Lange-Nielsen Syndrome',
#   'Sinus Arrest, Cardiac',
#   "Bayes' Syndrome",
#   'Ventricular Premature Complexes',
#   'Sinoatrial Block',
#   'Interatrial Conduction Delay',
#   'Slow Ventricular Tachycardia',
#   'Premature Atrial Beats',
#   'Potassium-Sensitive Periodic Paralysis, Ventricular Ectopy, and Dysmorphic Features',
#   'Cardiac Complex, Premature',
#   'Cardio-Auditory-Syncope Syndrome',
#   'Sudden Unexplained Death Syndrome',
#   'Ventricular Premature Complex',
#   'A-V Dissociation',
#   'Auricular Fibrillation',
#   'Anterior Fascicular Block',
#   'Nodoventricular Mahaim-Type Pre-Excitation',
#   'Premature Atrial Complex',
#   'Ventricular Ectopic Beats',
#   'Arrhythmias, Cardiac',
#   'Tachycardia, Sinus',
#   'Tachycardia, Sinoatrial Nodal Reentry',
#   'Sinus Node Reentrant Tachycardia',
#   'Commotio Cordis',
#   'Deafness, Congenital, and Functional Heart Disease',
#   'Anomalous Ventricular Excitation Syndrome',
#   'Familial Atrial Fibrillation',
#   'Andersen Cardiodysrhythmic Periodic Paralysis',
#   'Cardiac Arrhythmias',
#   'Cardiac Dysrhythmia',
#   'Bundle-Branch Block',
#   'Atrioventricular Dissociation',
#   'Cardiac Sinus Arrest',
#   'Cardiac Arrhythmia',
#   'Extrasystole, Atrial',
#   'Tachycardia, AV Nodal Reentrant',
#   'Preexcitation Syndrome',
#   'AV Nodal Reentrant Tachycardia',
#   'Sinus Arrhythmia',
#   'Prolonged QT Interval in EKG and Sudden Death',
#   'Ventricular Pre-Excitation with Arrhythmia',
#   'Ventricular Fibrillation with Prolonged QT Interval',
#   'Electrocardiogram QT Prolonged',
#   'Brugada Syndrome 1',
#   'Atrial Premature Complex',
#   'Atrioventricular Reentrant Tachycardia',
#   'Ectopic Heartbeats',
#   'Reciprocating Tachycardia',
#   'Cardioauditory Syndrome of Jervell and Lange-Nielsen',
#   'Sick Sinus Syndrome',
#   'Sudden Unexplained Nocturnal Death Syndrome',
#   'Posterior Fascicular Block',
#   'Andersen Tawil Syndrome',
#   'Sinus Tachycardia',
#   'Sick Sinus Node Syndrome',
#   'Tachyarrhythmia',
#   'False Bundle-Branch Block Syndrome',
#   'Arrythmia',
#   'Arrhythmia, Sinus',
#   'Atrial Ectopic Tachycardia',
#   'Cardiac Concussion',
#   'Andersen Cardiodysrythmic Periodic Paralysis',
#   'Long QT Syndrome 7',
#   'Bradyarrhythmias',
#   'Torsade de Pointes',
#   'Auriculoventricular Accessory Pathway Syndrome',
#   'Stokes-Adams Syndrome',
#   'Cardiac Complexes, Premature',
#   'Atrioventricular Block',
#   'Wolf-Parkinson-White Syndrome',
#   'Brugada Type ECG Pattern'],
#  'CHD': ['Taussig-Bing Anomaly',
#   'Bland-White-Garland Syndrome',
#   'Transposition of Great Vessels',
#   'Familial Turner Syndrome',
#   'Double Outlet Right Ventricle',
#   'Trisomy 13',
#   "Lutembacher's Syndrome",
#   'Heart Septal Defects, Ventricular',
#   'Truncus Arteriosus Communis',
#   'Coarctation of the Aorta',
#   'Conotruncal Anomaly Face Syndrome (CTAF)',
#   'Univentricular Heart',
#   'Anomalous Left Coronary Artery',
#   'Chromosome 13 Trisomy Syndrome',
#   'Dextro-Looped Transposition of the Great Arteries',
#   'Aorto-Left Ventricular Tunnel',
#   'Ebstein Anomaly',
#   'Aortic-Left Ventricular Tunnel',
#   "Turner's Syndrome",
#   'Septal Defects, Aorticopulmonary',
#   'Mosaic Trisomy 18 Syndrome',
#   'Tricuspid Atresia',
#   'Gonadal Dysgenesis, XO',
#   'Complete Trisomy 13 Syndrome',
#   "Fallot's Tetralogy",
#   'Criss-cross Heart',
#   'Noonan Syndrome 1',
#   'Endocardial Cushion Defect',
#   'Lentiginosis Cardiomyopathic',
#   'Ventricular Dysplasia, Right, Arrhythmogenic',
#   'Right Atrial Isomerism with Asplenia',
#   'Congenital Quadricuspid Aortic Valve',
#   'Aorticoventricular Tunnel',
#   'Atrial Septal Defect',
#   'Velocardiofacial Syndrome',
#   'Cor Triatriatum Sinistrum',
#   'Thymic Aplasia Syndrome',
#   'Chromosome 13 Duplication',
#   'Aorticopulmonary Septal Defect',
#   'Congenital Heart Defect',
#   'Heart Defects, Congenital',
#   'Marfan Syndrome Type 1',
#   'Double Outlet Right Ventricle, Subpulmonary VSD',
#   'Ventricular Septal Defect',
#   'Ductus Arteriosus, Patent',
#   'Double-Outlet Right Ventricle',
#   'Catch22',
#   'Patau Syndrome',
#   'Cardio-Cutaneous Syndrome',
#   'Dextrocardia, Bronchiectasis, and Sinusitis',
#   'Aortic Valve, Bicuspid',
#   'Double Outlet Right Ventricle, Subaortic VSD',
#   'Polysplenia Syndrome',
#   'Heart Abnormalities',
#   'Patent Oval Foramen',
#   'Patent Foramen Ovale',
#   "Tetralogy, Fallot's",
#   'Hypoplastic Left Heart Syndrome',
#   'MGA Type II',
#   'Noncompaction of the Left Ventricular Myocardium, Autosomal Dominant',
#   'Coarctation of Aorta Dominant',
#   'Aorto-Ventricular Tunnel',
#   'Foramen Ovale, Patent',
#   "Kartagener's Triad",
#   'Situs Ambiguus with Asplenia',
#   'Noonan Syndrome',
#   'Trisomy 18 Syndrome',
#   'Siewert Syndrome',
#   'Marfan Like Connective Tissue Disorder',
#   'Congenitally Corrected Transposition of the Great Arteries',
#   'Multiple Lentigines Syndrome',
#   '3-Methylglutaconicaciduria Type II',
#   'Marfan Syndrome Type 2',
#   'Septal Defects, Aortopulmonary',
#   'VCF Syndrome',
#   'Aortico-Left Ventricular Tunnel',
#   'Pharyngeal Pouch Syndrome',
#   'Persistent Truncus Arteriosus',
#   'Marfan Syndrome, Type II',
#   'Levocardia',
#   'Left Heart Hypoplasia Syndrome',
#   'Abnormality, Heart',
#   'Septal Defect, Aortopulmonary',
#   'Left Atrial Isomerism',
#   'Crisscross Heart',
#   "Ebstein's Malformation",
#   'Quadricuspid Aortic Valve Disease',
#   'Aortopulmonary Septal Defect',
#   'Situs Inversus with Levocardia',
#   'Isolated Levocardia',
#   'Septal Defect, Aorticopulmonary',
#   'Marfan Syndrome',
#   'Heart Septal Defects',
#   'Mosaic Trisomy 13 Syndrome',
#   '22q11 Deletion Syndrome',
#   'Congenital Heart Disease',
#   '22q11.2 Deletion Syndrome',
#   'Cardiomyopathic Lentiginosis',
#   'Congenital Heart Defects',
#   'Polynesian Bronchiectasis',
#   'Arrhythmogenic Right Ventricular Dysplasia',
#   'Ciliary Dyskinesia, Primary, 1, With Or Without Situs Inversus',
#   'Noonan Syndrome with Multiple Lentigines',
#   'Truncus Arteriosus, Persistent',
#   'DiGeorge Anomaly',
#   'Bicuspid Aortic Valve',
#   'Tricuspid Valve Atresia',
#   'Persistent Common Atrioventricular Canal',
#   'Cardiac Septal Defect',
#   'Coronary Vessel Anomalies',
#   'Marfan Syndrome, Type I',
#   'Subdivided Left Atrium',
#   'Leopard Syndrome 1',
#   'Persistent Ostium Primum',
#   'Isolated Noncompaction of the Ventricular Myocardium',
#   'Cardiac Septal Defects',
#   'Aortoventricular Tunnel',
#   'Aortico-Ventricular Tunnel',
#   'Barth Syndrome',
#   'Autosomal Dominant Opitz G-Bbb Syndrome',
#   'Turner Syndrome',
#   'ALCAPA',
#   'Sedlackova Syndrome',
#   'ARVD-C',
#   'Kartagener Triad',
#   'Endocardial Cushion Defects',
#   'Heart Septal Defects, Atrial',
#   'Tetralogy of Fallot',
#   'Aorto-Right Ventricular Tunnel',
#   'Quadricuspid Aortic Valve Disorder',
#   'Cor Triatriatum',
#   'Atresia, Tricuspid',
#   'Hypoplasia of Thymus and Parathyroids',
#   'Bicuspid Aortic Valve Disease',
#   'Right Atrial Isomerism',
#   'Isolated Non-compaction of the Ventricular Myocardium',
#   'DiGeorge Syndrome',
#   'Cardioskeletal Myopathy with Neutropenia and Abnormal Mitochondria',
#   'Absent Right Atrioventricular Connection',
#   'Deletion 22q11.2 Syndrome',
#   'Quadricuspid Aortic Valve',
#   'Arrhythmogenic Right Ventricular Cardiomyopathy',
#   'Arrhythmogenic Right Ventricular Dysplasia-Cardiomyopathy',
#   'Trisomy 18',
#   'Ivemark Syndrome',
#   '3-Methylglutaconicaciduria Type 2',
#   'Aortopulmonary Septal Defects',
#   'Bland White Garland Syndrome',
#   'LEOPARD Syndrome, 1',
#   'Third and Fourth Pharyngeal Pouch Syndrome',
#   'Pseudo-Ullrich-Turner Syndrome',
#   'ALCAPA Syndrome',
#   'Left Heart Syndrome, Hypoplastic',
#   'Shprintzen Syndrome',
#   'Congenitally Corrected Transposition of the Great Vessels',
#   'Situs Ambiguus Viscerum',
#   'Eisenmenger Syndrome',
#   'Defects, Congenital Heart',
#   'Complex Single Ventricle',
#   'Ciliary Dyskinesia, Primary, 1',
#   '22q11.2DS',
#   "Ebstein's Anomaly",
#   'Monosomy X',
#   "Marfan's Syndrome",
#   'Aortic Valve Disease 1',
#   "Kartagener's Syndrome",
#   'Intraventricular Septal Defects',
#   'Conotruncal Anomaly Face Syndrome',
#   'Asplenia with Cardiovascular Anomalies',
#   'Aortic Coarctation',
#   'Trisomy E Syndrome',
#   'Trilogy of Fallot',
#   'Bonnevie-Ullrich Syndrome',
#   "Eisenmenger's Complex",
#   'Eisenmenger Complex',
#   'Kartagener Syndrome',
#   'MGA Type 2',
#   'Dextrocardia',
#   'Ostium Secundum Atrial Septal Defect',
#   '3-Methylglutaconic Aciduria, Type II',
#   'Arrhythmogenic Right Ventricular Cardiomyopathy-Dysplasia',
#   'Aortic-Right Ventricular Tunnel',
#   'Transposition of Great Arteries',
#   "Patau's Syndrome",
#   'Aortico-Right Ventricular Tunnel',
#   'DiGeorge Sequence',
#   'Lutembacher Syndrome',
#   'Asplenia Syndrome',
#   'Trisomy 13 Syndrome',
#   'Turner Phenotype with Normal Karyotype',
#   'Myocardial Bridging',
#   'Heart Defect, Congenital',
#   'Ullrich-Noonan Syndrome',
#   'Edwards Syndrome',
#   'Complete Trisomy 18 Syndrome',
#   'Familial Third and Fourth Pharyngeal Pouch Syndrome',
#   'Aortic-Ventricular Tunnel',
#   'Female Pseudo-Turner Syndrome',
#   'Aorticopulmonary Septal Defects',
#   'Velo-Cardio-Facial Syndrome',
#   'Trisomy 13 Syndromes',
#   'Right Ventricular Dysplasia, Arrhythmogenic',
#   'Isolated Noncompaction of the Left Ventricular Myocardium, X-Linked',
#   "Eisenmenger's Syndrome",
#   'Situs Ambiguus',
#   'Triatrial Heart',
#   'Visceral Heterotaxy',
#   'Gonadal Dysgenesis, 45,X',
#   'Patent Ductus Arteriosus',
#   'Heart Septal Defect',
#   'Atrial Septal Defects',
#   'Situs Ambiguus with Polysplenia',
#   'Congenitally Corrected Transposition',
#   'Atrial Septal Defect Ostium Primum',
#   'Heart, Malformation Of',
#   'Noonan-Ehmke Syndrome',
#   'Patent Ductus Arteriosus Familial',
#   "Turner's Phenotype, Karyotype Normal",
#   'Turner-Like Syndrome',
#   'Ventricular Septal Defects',
#   'Patency of the Ductus Arteriosus',
#   'Bartholin-Patau Syndrome',
#   "Familial Ebstein's Anomaly",
#   'Double Outlet Right Ventricle, Noncommitted VSD',
#   'Male Turner Syndrome',
#   'Coarctation of Aorta',
#   'LEOPARD Syndrome',
#   'Progressive Cardiomyopathic Lentiginosis',
#   'Heterotaxy Syndrome',
#   'Turner Syndrome, Male',
#   'Left Atrial Isomerism with Polysplenia',
#   "Fallot's Trilogy",
#   'Status Bonnevie-Ullrich',
#   'Ullrich-Turner Syndrome',
#   'Shprintzen VCF Syndrome',
#   "Turner's Syndrome, Male",
#   'Quadricuspid Aortic Valvular Disease',
#   'Quadricuspid Aortic Valve Condition'],
#  'VD': ['Pulmonary Valve Atresias',
#   'Supravalvular Stenosis, Aortic',
#   'Pulmonary Infundibular Stenosis',
#   'Stenosis, Pulmonary Subvalvular',
#   'Atresias, Pulmonary',
#   'Atresia, Pulmonary Valve',
#   'Regurgitation, Pulmonary',
#   'Stenosis, Subvalvular Pulmonary',
#   'Familial Hypertrophic Cardiomyopathy',
#   'Pulmonary Stenosis, Subvalvular',
#   'Supravalvular Aortic Stenosis',
#   'Tricuspid Atresia',
#   'Heart Valvular Disease',
#   'Stenoses, Subvalvular Pulmonary',
#   'Lentiginosis Cardiomyopathic',
#   'Heart Valve Diseases',
#   'Atresias, Pulmonary Valve',
#   'Congenital Quadricuspid Aortic Valve',
#   'Ventricular Hypertrophy, Hereditary',
#   'Heart Valve Prolapse',
#   'Cardiomyopathy, Hypertrophic Obstructive',
#   'Aortic Valve Stenosis',
#   'Subvalvular Aortic Stenosis',
#   'Pulmonary Stenoses',
#   'Cardio-Cutaneous Syndrome',
#   'Subvalvular Pulmonary Stenoses',
#   'Aortic Valve, Bicuspid',
#   'Pulmonary Valve Regurgitation',
#   'Hypertrophic Subaortic Stenosis, Idiopathic',
#   'Pulmonary Stenosis',
#   'Stenosis, Pulmonary',
#   'Pulmonary Atresia',
#   'Tricuspid Incompetence',
#   'Floppy Mitral Valve',
#   'Stenoses, Pulmonary Subvalvular',
#   'Mitral Valve Stenosis',
#   'Regurgitation, Aortic Valve',
#   'Multiple Lentigines Syndrome',
#   'Williams Syndrome',
#   'Tricuspid Valve Insufficiency',
#   'Aortic Heart Disease',
#   'Aortic Valve Incompetence',
#   'Subvalvular Stenoses, Pulmonary',
#   'Valve Regurgitation, Pulmonary',
#   'Pulmonary Atresias',
#   'Mitral Valve Insufficiency',
#   'Pulmonary Regurgitation',
#   'Quadricuspid Aortic Valve Disease',
#   'Contiguous Gene Syndrome, Williams',
#   'Tricuspid Valve Prolapse',
#   'Pulmonary Valve Insufficiency',
#   'Obstructive Asymmetric Septal Hypertrophy',
#   'Valve Incompetence, Pulmonary',
#   'Pulmonic Stenosis',
#   'Infundibular Stenoses, Pulmonary',
#   'Cardiomyopathic Lentiginosis',
#   'Mitral Insufficiency',
#   'Aortic Supravalvular Stenosis',
#   'Stenosis, Supravalvular Aortic',
#   'Noonan Syndrome with Multiple Lentigines',
#   'Aortic Valve Disease',
#   'Bicuspid Aortic Valve',
#   'Ventricular Hypertrophy, Familial',
#   'Tricuspid Valve Atresia',
#   'Prolapsed Mitral Valve',
#   'Leopard Syndrome 1',
#   'Hereditary Ventricular Hypertrophy',
#   'Asymmetric Septal Hypertrophy, Familial',
#   'Hypercalcemia-Supravalvar Aortic Stenosis',
#   'Click-Murmur Syndrome',
#   'Aortic Valve Prolapse',
#   'Aortic Valvular Heart Disorder',
#   'Incompetence, Pulmonary Valve',
#   'Pulmonary Valve Stenoses',
#   'Quadricuspid Aortic Valve Disorder',
#   'Regurgitation, Pulmonary Valve',
#   'Pulmonary Subvalvular Stenosis',
#   'Pulmonary Infundibular Stenoses',
#   'Insufficiency, Pulmonary Valve',
#   'Atresia, Tricuspid',
#   'Mitral Valve Prolapse',
#   'Bicuspid Aortic Valve Disease',
#   'Absent Right Atrioventricular Connection',
#   'Quadricuspid Aortic Valve',
#   'Beuren Syndrome',
#   'Mitral Click-Murmur Syndrome',
#   'Aortic Regurgitation',
#   'LEOPARD Syndrome, 1',
#   'Systolic Click-Murmur Syndrome',
#   'Stenoses, Pulmonary Valve',
#   'Stenosis, Pulmonary Infundibular',
#   'Aortic Valve Insufficiency',
#   'Aortic Valve Disease 1',
#   'Mitral Regurgitation',
#   'Pulmonary Subvalvular Stenoses',
#   'Cardiomyopathy, Hypertrophic',
#   'Aortic Subvalvular Stenosis',
#   'Aortic Stenosis, Supravalvular',
#   'Tricuspid Regurgitation',
#   'Subaortic Stenosis, Discrete',
#   'Tricuspid Valve Incompetence',
#   'Pulmonary Stenoses, Subvalvular',
#   'Williams-Beuren Syndrome',
#   'Supravalvar Aortic Stenosis Syndrome',
#   'Williams Contiguous Gene Syndrome',
#   'Mitral Valve Incompetence',
#   'Aortic Valve Disorder',
#   'Stenosis, Pulmonary Valve',
#   'Infundibular Stenosis, Pulmonary',
#   'Mitral Valve Prolapse Syndrome',
#   'Valve Insufficiency, Pulmonary',
#   'Stenosis, Aortic Supravalvular',
#   'Supravalvar Aortic Stenosis',
#   'Atresia, Pulmonary',
#   'Chromosome 7q11.23 Deletion Syndrome',
#   'Tricuspid Valve Stenosis',
#   'Aortic Stenosis, Subvalvular',
#   'Valvular Pulmonic Stenosis',
#   'Cardiomyopathy, Familial Hypertrophic',
#   'Valvular Heart Diseases',
#   'Pulmonary Valve Incompetence',
#   'Subvalvular Pulmonary Stenosis',
#   'Obstructive Subaortic Conus',
#   'Aortic Valvular Heart Disease',
#   'Mitral Valve Regurgitation',
#   'Aortic Incompetence',
#   'Pulmonary Valve Stenosis',
#   'Cardiomyopathy, Hypertrophic, Familial',
#   'Mitral Stenosis',
#   'Subvalvular Stenosis, Pulmonary',
#   'Tricuspid Valve Regurgitation',
#   'Aortic Stenosis',
#   'Pulmonary Valve Atresia',
#   'LEOPARD Syndrome',
#   'Progressive Cardiomyopathic Lentiginosis',
#   'Stenoses, Pulmonary Infundibular',
#   'Stenoses, Pulmonary',
#   'Discrete Subaortic Stenosis',
#   'Quadricuspid Aortic Valvular Disease',
#   'Quadricuspid Aortic Valve Condition',
#   'Mitral Incompetence'],
#  'IHD': ['X Syndrome, Angina',
#   'Shock, Cardiogenic',
#   "Prinzmetal's Angina",
#   'Angor Pectoris',
#   'Coronary Thrombosis',
#   'Coronary Aneurysm',
#   'Injury, Myocardial Reperfusion',
#   'Coronary Disease',
#   'ST Elevated Myocardial Infarction',
#   'Angina, Microvascular',
#   'Angina, Preinfarction',
#   'Allergic Myocardial Infarction',
#   'Thrombosis, Coronary',
#   'Anterolateral Myocardial Infarction',
#   'Myocardial Infarction with Nonobstructive Coronary Arteries',
#   'Angina Pectoris',
#   'Heart Attack',
#   'Myocardial Infarction with Non-obstructive Coronary Arteries',
#   'Angina, Stable',
#   'Coronary Stenosis',
#   'Coronary Arteriosclerosis',
#   'Myocardial Infarction, Anterior Wall',
#   'Diaphragmatic Myocardial Infarction',
#   'Myocardial Preinfarction Syndrome',
#   'Cardiac Syndrome X',
#   'Myocardial Ischemic Reperfusion Injury',
#   'Coronary-Subclavian Steal Syndrome',
#   'Prinzmetal Angina',
#   'Anterior Wall Myocardial Infarction',
#   'Allergic Acute Coronary Syndrome',
#   'Myocardial Infarction and Non-obstructed Coronary Arteries',
#   'Coronary Artery Disease',
#   'Coronary Restenosis',
#   'Myocardial Ischemia',
#   'Anteroseptal Myocardial Infarction',
#   'Syndrome X, Cardiac',
#   'Heart Disease, Ischemic',
#   'Angina Pectoris, Variant',
#   'Inferior Myocardial Infarction',
#   'Allergic Angina Syndrome',
#   'Cardiovascular Stroke',
#   'STEMI',
#   'Myocardial Reperfusion Injury',
#   'ST Segment Elevation Myocardial Infarction',
#   'Stenocardia',
#   'Angina Pectoris with Normal Coronary Arteriogram',
#   'Kounis Syndrome',
#   'Left Main Coronary Artery Disease',
#   'Inferior Wall Myocardial Infarction',
#   'Acute Coronary Syndrome',
#   'Chronic Stable Angina',
#   'Acute Inferior Myocardial Infarction',
#   'Ischemic Heart Disease',
#   'Microvascular Angina',
#   'Left Main Disease',
#   'Arteriosclerosis, Coronary',
#   'MINOCA',
#   'Coronary Atherosclerosis',
#   'Myocardial Infarction and Nonobstructed Coronary Arteries',
#   'Coronary Occlusion',
#   'Non-ST Elevated Myocardial Infarction',
#   'Acute Anterior Wall Myocardial Infarction',
#   'NSTEMI',
#   'Coronary Artery Vasospasm',
#   'Angina at Rest',
#   'Angina Pectoris, Stable',
#   'Atherosclerosis, Coronary',
#   'ST Elevation Myocardial Infarction',
#   'Myocardial Infarction, Inferior Wall',
#   'Angina, Unstable',
#   'Angina Pectoris, Unstable',
#   'Aneurysm, Coronary',
#   'Syndrome X, Angina',
#   'Coronary Heart Disease',
#   'Non-ST-Elevation Myocardial Infarction',
#   'Left Main Coronary Disease',
#   'Unstable Angina',
#   'Coronary Artery Stenosis',
#   'Coronary Vasospasm',
#   'Myocardial Infarction',
#   'Ischemia, Myocardial',
#   'Myocardial Infarct',
#   'Coronary Stenoses',
#   'Reperfusion Injury, Myocardial'],
#  'CCD': ['Wolff-Parkinson-White Syndrome',
#   'Tachycardia, Paroxysmal',
#   'Cardiac Conduction Defects',
#   'Surdo-Cardiac Syndrome',
#   'Right Bundle-Branch Block',
#   'Adam-Stokes Attacks',
#   'Extrasystole, Ventricular',
#   'Ventricular Tachycardia',
#   'Atrioventricular Conduction Block',
#   'Tachycardia, Ventricular',
#   'Ventricular Tachyarrhythmias',
#   'Nonsustained Ventricular Tachycardia',
#   'Sinus Node Dysfunction',
#   'Long QT Syndrome Type 1',
#   'Right Bundle Branch Block, ST Segment Elevation, and Sudden Death Syndrome',
#   'Andersen Syndrome',
#   'Premature Ventricular Contractions',
#   'Sinoatrial Nodal Reentry Tachycardia',
#   'Tachycardia',
#   'Tachycardia, Ectopic Atrial',
#   'AV Block',
#   'Cardiac Conduction System Diseases',
#   'Premature Cardiac Complexes',
#   'Nodofascicular Mahaim-Type Pre-Excitation',
#   'Mahaim-Type Pre-Excitation, Nodoventricular',
#   'Sinoatrial Exit Block',
#   'Junctional Ectopic Tachycardia',
#   'WPW Syndrome',
#   'Auriculo-Ventricular Dissociation',
#   'Ectopic Junctional Tachycardia',
#   'Accelerated Idioventricular Rhythm',
#   'Mahaim-Type Pre-Excitation, Nodofascicular',
#   'Ectopic Atrial Tachycardia',
#   'Atrioventricular Nodal Re-Entrant Tachycardia',
#   'Jervell And Lange-Nielsen Syndrome 1',
#   'Fascicular Block',
#   'Interatrial Block',
#   'Cardiac Conduction System Disease',
#   'Pre-Excitation Syndromes',
#   'Periodic Paralysis, Potassium-Sensitive Cardiodysrhythmic Type',
#   'Extrasystole',
#   'Lown-Ganong-Levine Syndrome',
#   'Tachycardia, Ectopic Junctional',
#   'Tachycardia, Reciprocating',
#   'Short PR-Normal QRS Complex Syndrome',
#   'Long QT Syndrome',
#   'Sinus Node Disease',
#   'Torsades de Pointes',
#   'Paroxysmal Supraventricular Tachycardia',
#   'Idiopathic Ventricular Tachycardia',
#   'Extrasystoles',
#   'Sudden Unexplained Nocturnal Death Syndrome (SUNDS)',
#   'Left Bundle-Branch Block',
#   'Pre-Excitation, Mahaim-Type',
#   'Mahaim-Type Pre-Excitation',
#   'Bundle Branch Block',
#   'Jervell-Lange Nielsen Syndrome',
#   'Premature Cardiac Complex',
#   'Tachycardia, SA Nodal Reentrant',
#   'Atrioventricular Nodal Reentry Tachycardia',
#   'Heart Block',
#   'Premature Atrial Contractions',
#   'Tachycardia, Atrioventricular Nodal Reentry',
#   'Mahaim-Type Preexcitation',
#   'Paroxysmal Reciprocal Tachycardia',
#   'Tachycardia, Reciprocal',
#   'Bayes Syndrome',
#   'Long QT Syndrome 1',
#   'Tachycardia, Supraventricular',
#   'Premature Supraventricular Beats',
#   'Andersen-Tawil Syndrome',
#   'Brugada Syndrome',
#   'Romano-Ward Syndrome',
#   'Adams-Stokes Syndrome',
#   'Premature Ventricular Beats',
#   'Premature Ventricular Complex',
#   'Stokes-Adams Attacks',
#   'AIVR',
#   'Atrial Ectopic Beats',
#   'Atrioventricular Nodal Reentrant Tachycardia',
#   'Brugada ECG Pattern',
#   'Reciprocal Tachycardia',
#   'Atrial Premature Complexes',
#   'Ward-Romano Syndrome',
#   'Premature Beats',
#   'Jervell and Lange-Nielsen Syndrome',
#   "Bayes' Syndrome",
#   'Ventricular Premature Complexes',
#   'Sinoatrial Block',
#   'Interatrial Conduction Delay',
#   'Slow Ventricular Tachycardia',
#   'Premature Atrial Beats',
#   'Potassium-Sensitive Periodic Paralysis, Ventricular Ectopy, and Dysmorphic Features',
#   'Cardiac Complex, Premature',
#   'Cardio-Auditory-Syncope Syndrome',
#   'Sudden Unexplained Death Syndrome',
#   'Ventricular Premature Complex',
#   'A-V Dissociation',
#   'Cardiac Conduction Defect',
#   'Anterior Fascicular Block',
#   'Nodoventricular Mahaim-Type Pre-Excitation',
#   'Premature Atrial Complex',
#   'Ventricular Ectopic Beats',
#   'Tachycardia, Sinus',
#   'Tachycardia, Sinoatrial Nodal Reentry',
#   'Sinus Node Reentrant Tachycardia',
#   'Deafness, Congenital, and Functional Heart Disease',
#   'Anomalous Ventricular Excitation Syndrome',
#   'Andersen Cardiodysrhythmic Periodic Paralysis',
#   'Bundle-Branch Block',
#   'Atrioventricular Dissociation',
#   'Extrasystole, Atrial',
#   'Tachycardia, AV Nodal Reentrant',
#   'Preexcitation Syndrome',
#   'AV Nodal Reentrant Tachycardia',
#   'Prolonged QT Interval in EKG and Sudden Death',
#   'Ventricular Pre-Excitation with Arrhythmia',
#   'Ventricular Fibrillation with Prolonged QT Interval',
#   'Electrocardiogram QT Prolonged',
#   'Brugada Syndrome 1',
#   'Atrial Premature Complex',
#   'Atrioventricular Reentrant Tachycardia',
#   'Ectopic Heartbeats',
#   'Reciprocating Tachycardia',
#   'Cardioauditory Syndrome of Jervell and Lange-Nielsen',
#   'Sick Sinus Syndrome',
#   'Sudden Unexplained Nocturnal Death Syndrome',
#   'Posterior Fascicular Block',
#   'Andersen Tawil Syndrome',
#   'Sinus Tachycardia',
#   'Sick Sinus Node Syndrome',
#   'Tachyarrhythmia',
#   'False Bundle-Branch Block Syndrome',
#   'Atrial Ectopic Tachycardia',
#   'Andersen Cardiodysrythmic Periodic Paralysis',
#   'Long QT Syndrome 7',
#   'Torsade de Pointes',
#   'Auriculoventricular Accessory Pathway Syndrome',
#   'Stokes-Adams Syndrome',
#   'Cardiac Complexes, Premature',
#   'Atrioventricular Block',
#   'Wolf-Parkinson-White Syndrome',
#   'Brugada Type ECG Pattern'],
#  'VOO': ['Supravalvular Stenosis, Aortic',
#   'Outflow Obstruction, Right Ventricular',
#   'Pulmonary Infundibular Stenosis',
#   'Outflow Obstruction, Left Ventricular',
#   'Pulmonary Valve Stenoses',
#   'Stenoses, Pulmonary Subvalvular',
#   'Stenosis, Pulmonary Subvalvular',
#   'Ventricular Outflow Obstruction, Left',
#   'Pulmonary Subvalvular Stenosis',
#   'Stenosis, Pulmonary Valve',
#   'Infundibular Stenosis, Pulmonary',
#   'Pulmonary Infundibular Stenoses',
#   'Stenosis, Subvalvular Pulmonary',
#   'Subvalvular Stenoses, Pulmonary',
#   'Pulmonary Stenosis, Subvalvular',
#   'Stenosis, Aortic Supravalvular',
#   'Right Ventricular Outflow Obstruction',
#   'Supravalvar Aortic Stenosis',
#   'Supravalvular Aortic Stenosis',
#   'Valvular Pulmonic Stenosis',
#   'Stenoses, Subvalvular Pulmonary',
#   'Aortic Stenosis, Subvalvular',
#   'Ventricular Outflow Obstruction',
#   'Subvalvular Pulmonary Stenosis',
#   'Pulmonic Stenosis',
#   'Infundibular Stenoses, Pulmonary',
#   'Obstructive Subaortic Conus',
#   'Stenoses, Pulmonary Valve',
#   'Ventricular Outflow Obstruction, Right',
#   'Aortic Supravalvular Stenosis',
#   'Pulmonary Valve Stenosis',
#   'Stenosis, Pulmonary Infundibular',
#   'Aortic Valve Stenosis',
#   'Subvalvular Aortic Stenosis',
#   'Stenosis, Supravalvular Aortic',
#   'Pulmonary Subvalvular Stenoses',
#   'Subvalvular Stenosis, Pulmonary',
#   'Pulmonary Stenoses',
#   'Subvalvular Pulmonary Stenoses',
#   'Aortic Stenosis',
#   'Aortic Subvalvular Stenosis',
#   'Stenoses, Pulmonary Infundibular',
#   'Pulmonary Stenosis',
#   'Aortic Stenosis, Supravalvular',
#   'Left Ventricular Outflow Obstruction',
#   'Subaortic Stenosis, Discrete',
#   'Stenoses, Pulmonary',
#   'Discrete Subaortic Stenosis',
#   'Pulmonary Stenoses, Subvalvular',
#   'Stenosis, Pulmonary'],
#  'OTH': ['Cardiomyopathy, Congestive',
#   'Cardiopulmonary Arrest',
#   'Cardiomegaly',
#   'Broken Heart Syndrome',
#   'Cardiomyopathy, Familial Idiopathic',
#   'Pick Disease of Heart',
#   'Congestive Cardiomyopathy',
#   'Dilated Cardiomyopathy',
#   'Endocarditis, Non-Bacterial Thrombotic',
#   'Papillary Fibroelastoma',
#   'Apical Ballooning Syndrome',
#   'NAME Syndrome',
#   'Bacterial Endocarditides, Subacute',
#   'Karoshi Death',
#   'Death, Sudden, Cardiac',
#   'Constrictive Pericarditis',
#   'Left Ventricular Hypertrophy',
#   'Sudden Cardiac Death',
#   'Left Ventricular Apical Ballooning Syndrome',
#   'Bacterial Endocarditis',
#   'Cardiac Free Wall Rupture',
#   'Endocarditis',
#   'Cardiac Rupture',
#   'Right Ventricular Hypertrophy',
#   'Neoplasms, Cardiac',
#   'Post-Infarction Heart Rupture',
#   'Cardiac Arrest, Sudden',
#   'Out-of-Hospital Heart Arrest',
#   'Marantic Endocarditis',
#   'Intracavitary Tumors of the Heart',
#   'Cardiomyopathy, Dilated, with Conduction Deffect1',
#   'Ventricular Hypertrophy, Right',
#   'LAMB Syndrome',
#   'Cardiomyopathy, Dilated, Autosomal Recessive',
#   'Cardiac Carcinoma',
#   'Pericarditis, Tuberculous',
#   'Neoplasms, Heart',
#   'Endocarditis, Bacterial',
#   'Cardiac Tumor',
#   'Infective Endocarditis',
#   'Heart Arrest',
#   'Ventricular Hypertrophy, Left',
#   'Cardiac Sudden Death',
#   'Ventricular Dysfunction, Right',
#   'Cardiac Neoplasms',
#   'Asystole',
#   'Cardiomyopathy, Dilated, 1a',
#   'Pericarditis',
#   'Heart Rupture',
#   'Carney Myxoma-Endocrine Complex',
#   'Carney Complex',
#   'Ventricular Septal Perforation',
#   'Pericarditis, Constrictive',
#   'Cardiac Hypertrophy',
#   'Takotsubo Syndrome',
#   'Heart Enlargement',
#   'Sudden Cardiac Arrest',
#   'Tako-tsubo Cardiomyopathy',
#   'Heart Neoplasms',
#   'Non-Bacterial Thrombotic Endocarditis',
#   'Endocarditides, Bacterial',
#   'Cardiac Papillary Fibroelastoma',
#   'Cardiac Tumors',
#   'Carney Myxoma-Endocrine Complex, Type II',
#   'Ventricular Septal Rupture',
#   'Stress Cardiomyopathy',
#   'Cardiomyopathy, Dilated, With Conduction Defect 1',
#   'Takotsubo Cardiomyopathy',
#   'Cardiac Cancer',
#   'LAMB - Lentigines, Atrial Myxoma, Mucocutaneous Myoma, Blue Nevus Syndrome',
#   'Carney Complex, Type 1',
#   'Myxoma, Spotty Pigmentation, and Endocrine Overactivity',
#   'Subacute Bacterial Endocarditis',
#   'Hypertrophy, Left Ventricular',
#   "Pick's Disease of Heart",
#   'Heart Tumor',
#   'Heart Rupture, Post-Infarction',
#   'Endocarditides, Subacute Bacterial',
#   'Cardiomyopathy, Dilated, CMD1A',
#   'Ventricular Dysfunction',
#   'Right Ventricular Dysfunction',
#   'Myocardial Tumors (Rhabdomyomas and Fibromas)',
#   'Transient Apical Ballooning Syndrome',
#   'Cardiac Arrest',
#   'Ventricular Dysfunction, Left',
#   'Subacute Bacterial Endocarditides',
#   'Cardiomyopathy, Dilated',
#   'Bacterial Endocarditides',
#   'Tuberculous Pericarditis',
#   'Enlarged Heart',
#   'Tako-tsubo Syndrome',
#   'Endocarditis, Subacute Bacterial',
#   'Bacterial Endocarditis, Subacute',
#   'Carney Syndrome',
#   'Pleuropericarditis',
#   'Endocarditis, Non-Infective',
#   'Out-of-Hospital Cardiac Arrest',
#   'Carney Complex, Type I',
#   'Cardiac Rupture, Post-Infarction',
#   'Non-Infective Endocarditis',
#   'Heart Cancer',
#   'Karoshi-Death',
#   'Primary Cardiac Tumors, Childhood',
#   'Cardiomyopathy, Dilated, LMNA',
#   'Nevi, Atrial Myxoma, Skin Myxoma, Ephelides Syndrome',
#   'Carney Complex, Type 2',
#   'Carney Complex, Type II',
#   'Heart Hypertrophy',
#   'Endocarditis Lenta',
#   'Cardiomyopathy, Idiopathic Dilated',
#   'Hypertrophy, Right Ventricular',
#   'Left Ventricular Dysfunction',
#   'Free Wall Rupture, Heart',
#   'Ventricular Free Wall Rupture']}

# %%
docs_1 = json.load(open('drive/MyDrive/bertopic/caseolap_lift/text_mining/docs_1.json'))

# %%
seed = list(category2synonyms.values())

# %%
order = ["CM", "ARR", "CHD", "VD", "IHD", "CCD", "VOO", "OTH"]

# %% [markdown]
# #### model

# %%
! pip install bertopic
# Out:
# Collecting bertopic
#   Downloading bertopic-0.15.0-py2.py3-none-any.whl (143 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 143.4/143.4 kB 2.5 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.20.0 in /usr/local/lib/python3.10/dist-packages (from bertopic) (1.23.5)
# Collecting hdbscan>=0.8.29 (from bertopic)
#   Downloading hdbscan-0.8.33.tar.gz (5.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.2/5.2 MB 18.3 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting umap-learn>=0.5.0 (from bertopic)
#   Downloading umap-learn-0.5.3.tar.gz (88 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 88.2/88.2 kB 10.9 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: pandas>=1.1.5 in /usr/local/lib/python3.10/dist-packages (from bertopic) (1.5.3)
# Requirement already satisfied: scikit-learn>=0.22.2.post1 in /usr/local/lib/python3.10/dist-packages (from bertopic) (1.2.2)
# Requirement already satisfied: tqdm>=4.41.1 in /usr/local/lib/python3.10/dist-packages (from bertopic) (4.66.1)
# Collecting sentence-transformers>=0.4.1 (from bertopic)
#   Downloading sentence-transformers-2.2.2.tar.gz (85 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.0/86.0 kB 11.0 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: plotly>=4.7.0 in /usr/local/lib/python3.10/dist-packages (from bertopic) (5.15.0)
# Requirement already satisfied: cython<3,>=0.27 in /usr/local/lib/python3.10/dist-packages (from hdbscan>=0.8.29->bertopic) (0.29.36)
# Requirement already satisfied: scipy>=1.0 in /usr/local/lib/python3.10/dist-packages (from hdbscan>=0.8.29->bertopic) (1.10.1)
# Requirement already satisfied: joblib>=1.0 in /usr/local/lib/python3.10/dist-packages (from hdbscan>=0.8.29->bertopic) (1.3.2)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.1.5->bertopic) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.1.5->bertopic) (2023.3)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from plotly>=4.7.0->bertopic) (8.2.3)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from plotly>=4.7.0->bertopic) (23.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.22.2.post1->bertopic) (3.2.0)
# Collecting transformers<5.0.0,>=4.6.0 (from sentence-transformers>=0.4.1->bertopic)
#   Downloading transformers-4.33.1-py3-none-any.whl (7.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.6/7.6 MB 49.1 MB/s eta 0:00:00
# Requirement already satisfied: torch>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from sentence-transformers>=0.4.1->bertopic) (2.0.1+cu118)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.10/dist-packages (from sentence-transformers>=0.4.1->bertopic) (0.15.2+cu118)
# Requirement already satisfied: nltk in /usr/local/lib/python3.10/dist-packages (from sentence-transformers>=0.4.1->bertopic) (3.8.1)
# Collecting sentencepiece (from sentence-transformers>=0.4.1->bertopic)
#   Downloading sentencepiece-0.1.99-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 53.7 MB/s eta 0:00:00
# Collecting huggingface-hub>=0.4.0 (from sentence-transformers>=0.4.1->bertopic)
#   Downloading huggingface_hub-0.16.4-py3-none-any.whl (268 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 268.8/268.8 kB 31.3 MB/s eta 0:00:00
# Requirement already satisfied: numba>=0.49 in /usr/local/lib/python3.10/dist-packages (from umap-learn>=0.5.0->bertopic) (0.56.4)
# Collecting pynndescent>=0.5 (from umap-learn>=0.5.0->bertopic)
#   Downloading pynndescent-0.5.10.tar.gz (1.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 63.7 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.4.0->sentence-transformers>=0.4.1->bertopic) (3.12.2)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.4.0->sentence-transformers>=0.4.1->bertopic) (2023.6.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.4.0->sentence-transformers>=0.4.1->bertopic) (2.31.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.4.0->sentence-transformers>=0.4.1->bertopic) (6.0.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.4.0->sentence-transformers>=0.4.1->bertopic) (4.7.1)
# Requirement already satisfied: llvmlite<0.40,>=0.39.0dev0 in /usr/local/lib/python3.10/dist-packages (from numba>=0.49->umap-learn>=0.5.0->bertopic) (0.39.1)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from numba>=0.49->umap-learn>=0.5.0->bertopic) (67.7.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.1->pandas>=1.1.5->bertopic) (1.16.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.6.0->sentence-transformers>=0.4.1->bertopic) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.6.0->sentence-transformers>=0.4.1->bertopic) (3.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.6.0->sentence-transformers>=0.4.1->bertopic) (3.1.2)
# Requirement already satisfied: triton==2.0.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.6.0->sentence-transformers>=0.4.1->bertopic) (2.0.0)
# Requirement already satisfied: cmake in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch>=1.6.0->sentence-transformers>=0.4.1->bertopic) (3.27.2)
# Requirement already satisfied: lit in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch>=1.6.0->sentence-transformers>=0.4.1->bertopic) (16.0.6)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers<5.0.0,>=4.6.0->sentence-transformers>=0.4.1->bertopic) (2023.6.3)
# Collecting tokenizers!=0.11.3,<0.14,>=0.11.1 (from transformers<5.0.0,>=4.6.0->sentence-transformers>=0.4.1->bertopic)
#   Downloading tokenizers-0.13.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (7.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 80.9 MB/s eta 0:00:00
# Collecting safetensors>=0.3.1 (from transformers<5.0.0,>=4.6.0->sentence-transformers>=0.4.1->bertopic)
#   Downloading safetensors-0.3.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 63.0 MB/s eta 0:00:00
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from nltk->sentence-transformers>=0.4.1->bertopic) (8.1.7)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.10/dist-packages (from torchvision->sentence-transformers>=0.4.1->bertopic) (9.4.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.6.0->sentence-transformers>=0.4.1->bertopic) (2.1.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.4.0->sentence-transformers>=0.4.1->bertopic) (3.2.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.4.0->sentence-transformers>=0.4.1->bertopic) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.4.0->sentence-transformers>=0.4.1->bertopic) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.4.0->sentence-transformers>=0.4.1->bertopic) (2023.7.22)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.6.0->sentence-transformers>=0.4.1->bertopic) (1.3.0)
# Building wheels for collected packages: hdbscan, sentence-transformers, umap-learn, pynndescent
#   Building wheel for hdbscan (pyproject.toml) ... done
#   Created wheel for hdbscan: filename=hdbscan-0.8.33-cp310-cp310-linux_x86_64.whl size=3039159 sha256=8e83c765ff273b373990f69d322f0015c0b4e09f69065e02f2abebb915d3557d
#   Stored in directory: /root/.cache/pip/wheels/75/0b/3b/dc4f60b7cc455efaefb62883a7483e76f09d06ca81cf87d610
#   Building wheel for sentence-transformers (setup.py) ... done
#   Created wheel for sentence-transformers: filename=sentence_transformers-2.2.2-py3-none-any.whl size=125923 sha256=a6a02acfb4c1b30fbf1af09b7c610ed44efac64adb0b08a6ef18f6e111a64c6d
#   Stored in directory: /root/.cache/pip/wheels/62/f2/10/1e606fd5f02395388f74e7462910fe851042f97238cbbd902f
#   Building wheel for umap-learn (setup.py) ... done
#   Created wheel for umap-learn: filename=umap_learn-0.5.3-py3-none-any.whl size=82807 sha256=2442abd2e7e90df8ee7d59096b163c6d9ab1c5987125c5278a981bf8f0e290cd
#   Stored in directory: /root/.cache/pip/wheels/a0/e8/c6/a37ea663620bd5200ea1ba0907ab3c217042c1d035ef606acc
#   Building wheel for pynndescent (setup.py) ... done
#   Created wheel for pynndescent: filename=pynndescent-0.5.10-py3-none-any.whl size=55615 sha256=cb277a7265ff9fc2877519d8735100831da0fe3b0aaa97ec37b6670fcaae092f
#   Stored in directory: /root/.cache/pip/wheels/4a/38/5d/f60a40a66a9512b7e5e83517ebc2d1b42d857be97d135f1096
# Successfully built hdbscan sentence-transformers umap-learn pynndescent
# Installing collected packages: tokenizers, sentencepiece, safetensors, huggingface-hub, transformers, pynndescent, hdbscan, umap-learn, sentence-transformers, bertopic
# Successfully installed bertopic-0.15.0 hdbscan-0.8.33 huggingface-hub-0.16.4 pynndescent-0.5.10 safetensors-0.3.3 sentence-transformers-2.2.2 sentencepiece-0.1.99 tokenizers-0.13.3 transformers-4.33.1 umap-learn-0.5.3

# %%
from bertopic import BERTopic
from bertopic.backend import BaseEmbedder
from bertopic.cluster import BaseCluster
from bertopic.vectorizers import ClassTfidfTransformer
from bertopic.dimensionality import BaseDimensionalityReduction
# from sklearn.datasets import fetch_20newsgroups

# %%
empty_embedding_model = BaseEmbedder()
empty_dimensionality_model = BaseDimensionalityReduction()
empty_cluster_model = BaseCluster()
ctfidf_model = ClassTfidfTransformer(reduce_frequent_words=True)

# %%
from sklearn.feature_extraction.text import CountVectorizer
from bertopic.representation import KeyBERTInspired

docs_1_ = docs_1['data']
seed = list(category2synonyms.values())

vectorizer_model = CountVectorizer(stop_words="english")
representation_model = KeyBERTInspired()

topic_model_1 = BERTopic(
    umap_model=empty_dimensionality_model,
    hdbscan_model=empty_cluster_model,
    ctfidf_model=ctfidf_model,
    # vectorizer_model=vectorizer_model,
    representation_model=representation_model,
    seed_topic_list=seed,
    n_gram_range=(1,2)
)
topics_1, probs_1 = topic_model_1.fit_transform(docs_1_, y=docs_1['labels'])

# %%
df_1 = topic_model_1.get_topic_info()
df_1
# Out:
#    Topic  Count                                               Name  \
# 0     -1   7147  -1_heart failure_cardiac_aortic valve_ventricular
# 1      0    388  0_turner syndrome_turners syndrome_trisomy_abn...
# 2      1    167  1_qt syndrome_arrhythmias_ventricular fibrilla...
# 3      2    134      2_arrhythmias_qt syndrome_cardiac_tachycardia
# 4      3     84  3_bacterial endocarditis_bacteraemia_bacterial...
# 5      4     38  4_cardiac myosin_myocarditis and_myocarditis_a...
# 6      5     22  5_bronchiectasis in_of bronchiectasis_bronchie...
# 7      6     15  6_lipoproteins_triglycerides and_palmoplantar ...
# 8      7      5  7_american correction_tracheostomy as_required...
#
#                                       Representation  \
# 0  [heart failure, cardiac, aortic valve, ventric...
# 1  [turner syndrome, turners syndrome, trisomy, a...
# 2  [qt syndrome, arrhythmias, ventricular fibrill...
# 3  [arrhythmias, qt syndrome, cardiac, tachycardi...
# 4  [bacterial endocarditis, bacteraemia, bacteria...
# 5  [cardiac myosin, myocarditis and, myocarditis,...
# 6  [bronchiectasis in, of bronchiectasis, bronchi...
# 7  [lipoproteins, triglycerides and, palmoplantar...
# 8  [american correction, tracheostomy as, require...
#
#                                  Representative_Docs
# 0  [Aortic stiffness as a marker of cardiac funct...
# 1  [The knee alignment and the foot arch in patie...
# 2  [Effect of sodium channel blockers on ST segme...
# 3  [A missense mutation (G604S) in the S5/pore re...
# 4  [Methanobrevibacter smithii Archaemia in Febri...
# 5  [Genetic susceptibility to Chagas disease card...
# 6  [Aetiology of bronchiectasis in Guangzhou, sou...
# 7  [DGCR8 recognizes primary transcripts of micro...
# 8  [[TRACHEOSTOMY AS A MEANS OF PREVENTING RESPIR...

# %%
topic_model_2 = BERTopic(
    # umap_model=empty_dimensionality_model,
    # hdbscan_model=empty_cluster_model,
    # ctfidf_model=ctfidf_model,
    # vectorizer_model=vectorizer_model,
    representation_model=representation_model,
    seed_topic_list=seed,
    n_gram_range=(1,2)
)
topics_2, probs_2 = topic_model_2.fit_transform(docs_1_, y=docs_1['labels'])

df_2 = topic_model_2.get_topic_info()
df_2
# Out:
#      Topic  Count                                               Name  \
# 0       -1   2745  -1_aortic stenosis_aortic valve_aortic_heart f...
# 1        0    415  0_turner syndrome_turners syndrome_turner_marf...
# 2        1    337  1_heart failure_chronic heart_cardiac_ventricular
# 3        2    282  2_cardiac arrest_cardiopulmonary resuscitation...
# 4        3    114  3_myocardial ischemia_ischemiareperfusion inju...
# ..     ...    ...                                                ...
# 115    114     12  114_hyperthyroid heart_hyperthyroid patients_o...
# 116    115     12  115_antiphospholipid syndrome_antiphospholipid...
# 117    116     11  116_coronary disease_coronary insufficiency_th...
# 118    117     11  117_occupational poisoning_oxide poisoning_qui...
# 119    118     10  118_aortic stenosis_valve stenosis_aortic valv...
#
#                                         Representation  \
# 0    [aortic stenosis, aortic valve, aortic, heart ...
# 1    [turner syndrome, turners syndrome, turner, ma...
# 2    [heart failure, chronic heart, cardiac, ventri...
# 3    [cardiac arrest, cardiopulmonary resuscitation...
# 4    [myocardial ischemia, ischemiareperfusion inju...
# ..                                                 ...
# 115  [hyperthyroid heart, hyperthyroid patients, of...
# 116  [antiphospholipid syndrome, antiphospholipid a...
# 117  [coronary disease, coronary insufficiency, thr...
# 118  [occupational poisoning, oxide poisoning, quin...
# 119  [aortic stenosis, valve stenosis, aortic valve...
#
#                                    Representative_Docs
# 0    [Severe aortic stenosis in octogenarians: is o...
# 1    [The knee alignment and the foot arch in patie...
# 2    [[Value of aldosterone receptor blockade in di...
# 3    [Admission of out-of-hospital cardiac arrest v...
# 4    [Myocardial infarct extension during reperfusi...
# ..                                                 ...
# 115  [Occult thyrotoxicosis: a correctable cause of...
# 116  [[Severe, non-infectious mitral valve endocard...
# 117  [[Coronary sclerosis and its sequelae (Statist...
# 118  [Presence or absence of elevated acute total s...
# 119  [Progression of isolated aortic stenosis: anal...
#
# [120 rows x 5 columns]

# %%
topic_model_3 = BERTopic(
    # umap_model=empty_dimensionality_model,
    # hdbscan_model=empty_cluster_model,
    ctfidf_model=ctfidf_model,
    # vectorizer_model=vectorizer_model,
    representation_model=representation_model,
    seed_topic_list=seed,
    n_gram_range=(1,2)
)

topics_3, probs_3 = topic_model_3.fit_transform(docs_1_, y=docs_1['labels'])

df_3 = topic_model_3.get_topic_info()
df_3
# Out:
#      Topic  Count                                               Name  \
# 0       -1   2963  -1_aortic stenosis_heart failure_aortic valve_...
# 1        0    408  0_turner syndrome_turners syndrome_growth horm...
# 2        1    284  1_cardiac arrest_cardiac arrests_resuscitation...
# 3        2    125  2_myocardial ischemia_ischemia reperfusion_of ...
# 4        3     99  3_atrial fibrillation_oral anticoagulants_anti...
# ..     ...    ...                                                ...
# 126    125     11  125_leadless pacing_leadless pacemaker_ventric...
# 127    126     11  126_atrial fibrosis_atrial fibrillation_inhibi...
# 128    127     11            127_published tavi_tavi_of tavi_tavi is
# 129    128     10  128_heart murmur_systolic murmur_systolic murm...
# 130    129     10  129_myocardial infarction_myocardial infarct_a...
#
#                                         Representation  \
# 0    [aortic stenosis, heart failure, aortic valve,...
# 1    [turner syndrome, turners syndrome, growth hor...
# 2    [cardiac arrest, cardiac arrests, resuscitatio...
# 3    [myocardial ischemia, ischemia reperfusion, of...
# 4    [atrial fibrillation, oral anticoagulants, ant...
# ..                                                 ...
# 126  [leadless pacing, leadless pacemaker, ventricu...
# 127  [atrial fibrosis, atrial fibrillation, inhibit...
# 128  [published tavi, tavi, of tavi, tavi is, in ta...
# 129  [heart murmur, systolic murmur, systolic murmu...
# 130  [myocardial infarction, myocardial infarct, ac...
#
#                                    Representative_Docs
# 0    [Prognostic significance of frequent premature...
# 1    [Current indications for growth hormone therap...
# 2    [A retrospective study of pulseless electrical...
# 3    [[Morphine-induced late cardioprotection: pote...
# 4    [Stroke prophylaxis in atrial fibrillation: se...
# ..                                                 ...
# 126  [Recent advances in pacemaker and implantable ...
# 127  [Role of Rac1 GTPase activation in atrial fibr...
# 128  [The official position of the Latin American A...
# 129  [Critical evaluation of atrial presystolic mur...
# 130  [[Recovery of a patient with myocardial infarc...
#
# [131 rows x 5 columns]

# %%
topic_model_4 = BERTopic(
    umap_model=empty_dimensionality_model,
    # hdbscan_model=empty_cluster_model,
    # ctfidf_model=ctfidf_model,
    # vectorizer_model=vectorizer_model,
    representation_model=representation_model,
    seed_topic_list=seed,
    n_gram_range=(1,2)
)
topics_4, probs_4 = topic_model_4.fit_transform(docs_1_, y=docs_1['labels'])

df_4 = topic_model_4.get_topic_info()
df_4
# Out:
#    Topic  Count                                               Name  \
# 0     -1   3073  -1_heart failure_cardiovascular_myocardial inf...
# 1      0   4914  0_aortic stenosis_heart failure_aortic valve_a...
# 2      1     13  1_discussion_discussion hard_hard discussion_d...
#
#                                       Representation  \
# 0  [heart failure, cardiovascular, myocardial inf...
# 1  [aortic stenosis, heart failure, aortic valve,...
# 2  [discussion, discussion hard, hard discussion,...
#
#                                  Representative_Docs
# 0  [[The QDF-HF (Quality of life, Depression and ...
# 1  [Occult aortic stenosis as cause of intractabl...
# 2         [Discussion. , Discussion. , Discussion. ]

# %%
topic_model_5 = BERTopic(
    # umap_model=empty_dimensionality_model,
    hdbscan_model=empty_cluster_model,
    # ctfidf_model=ctfidf_model,
    # vectorizer_model=vectorizer_model,
    representation_model=representation_model,
    seed_topic_list=seed,
    n_gram_range=(1,2)
)
topics_5, probs_5 = topic_model_5.fit_transform(docs_1_, y=docs_1['labels'])

df_5 = topic_model_5.get_topic_info()
df_5
# Out:
#    Topic  Count                                               Name  \
# 0     -1   7147  -1_heart failure_aortic valve_ventricular_cardiac
# 1      0    388  0_turner syndrome_turners syndrome_syndrome an...
# 2      1    167  1_qt syndrome_arrhythmias_ventricular tachycar...
# 3      2    134      2_qt syndrome_arrhythmias_cardiac_ventricular
# 4      3     84  3_bacterial myocarditis_bacterial endocarditis...
# 5      4     38  4_myocarditis and_myocarditis_autoantibodies_c...
# 6      5     22  5_bronchiectasis in_of bronchiectasis_bronchie...
# 7      6     15  6_platelet survival_platelets_triglycerides_my...
# 8      7      5  7_american correction_tracheostomy as_required...
#
#                                       Representation  \
# 0  [heart failure, aortic valve, ventricular, car...
# 1  [turner syndrome, turners syndrome, syndrome a...
# 2  [qt syndrome, arrhythmias, ventricular tachyca...
# 3  [qt syndrome, arrhythmias, cardiac, ventricula...
# 4  [bacterial myocarditis, bacterial endocarditis...
# 5  [myocarditis and, myocarditis, autoantibodies,...
# 6  [bronchiectasis in, of bronchiectasis, bronchi...
# 7  [platelet survival, platelets, triglycerides, ...
# 8  [american correction, tracheostomy as, require...
#
#                                  Representative_Docs
# 0  [Essential ECG clues in patients with congenit...
# 1  [Social and medical determinants of quality of...
# 2  [The spectrum of symptoms and QT intervals in ...
# 3  [A missense mutation (G604S) in the S5/pore re...
# 4  [Bacteraemia during Transurethral Resection of...
# 5  [Acute susceptibility of aged mice to infectio...
# 6  [Aetiology of bronchiectasis in Guangzhou, sou...
# 7  [Unrecognized diabetes and myocardial necrosis...
# 8  [[TRACHEOSTOMY AS A MEANS OF PREVENTING RESPIR...

# %%
from umap import UMAP
from hdbscan import HDBSCAN
from sentence_transformers import SentenceTransformer
from sklearn.feature_extraction.text import CountVectorizer

from bertopic import BERTopic
from bertopic.representation import KeyBERTInspired
from bertopic.vectorizers import ClassTfidfTransformer


# Step 1 - Extract embeddings
embedding_model = SentenceTransformer("all-MiniLM-L6-v2")

# Step 2 - Reduce dimensionality
umap_model = UMAP(n_neighbors=15, n_components=5, min_dist=0.0, metric='cosine')

# Step 3 - Cluster reduced embeddings
hdbscan_model = HDBSCAN(min_cluster_size=15, metric='euclidean', cluster_selection_method='eom', prediction_data=True)

# Step 4 - Tokenize topics
vectorizer_model = CountVectorizer(stop_words="english")

# Step 5 - Create topic representation
ctfidf_model = ClassTfidfTransformer(reduce_frequent_words=True)

# Step 6 - (Optional) Fine-tune topic representations with
# a `bertopic.representation` model
representation_model = KeyBERTInspired()

# All steps together
topic_model_6 = BERTopic(
  top_n_words=100,
  embedding_model=embedding_model,           # Step 1 - Extract embeddings
  umap_model=umap_model,                     # Step 2 - Reduce dimensionality
  hdbscan_model=hdbscan_model,               # Step 3 - Cluster reduced embeddings
  vectorizer_model=vectorizer_model,         # Step 4 - Tokenize topics
  ctfidf_model=ctfidf_model,                 # Step 5 - Extract topic words
  representation_model=representation_model, # Step 6 - (Optional) Fine-tune topic represenations
  seed_topic_list=seed,
  n_gram_range=(1,2)
)

# %%
topics_6, probs_6 = topic_model_6.fit_transform(docs_1_, y=docs_1['labels'])

df_6 = topic_model_6.get_topic_info()
df_6
# Out:
#     Topic  Count                                               Name  \
# 0      -1   2948          -1_echocardiography_aortic_aorta_stenosis
# 1       0    343  0_diuretics_antihypertensive_angiotensin_hyper...
# 2       1    329  1_cardiomyocytes_cardioprotection_cardioprotec...
# 3       2    272  2_resuscitation_resuscitated_defibrillation_po...
# 4       3    204  3_mitral_regurgitation_echocardiographic_mitra...
# ..    ...    ...                                                ...
# 86     85     17  85_antiarrhythmic_fibrillation_atrial_pharmaco...
# 87     86     16        86_myocardial_biomarkers_biomarker_troponin
# 88     87     16   87_transplantation_transplant_donor_transplanted
# 89     88     16  88_echocardiography_echocardiographic_echocard...
# 90     89     16       89_syndrome_adams_electrocardiography_stokes
#
#                                        Representation  \
# 0   [echocardiography, aortic, aorta, stenosis, ve...
# 1   [diuretics, antihypertensive, angiotensin, hyp...
# 2   [cardiomyocytes, cardioprotection, cardioprote...
# 3   [resuscitation, resuscitated, defibrillation, ...
# 4   [mitral, regurgitation, echocardiographic, mit...
# ..                                                ...
# 86  [antiarrhythmic, fibrillation, atrial, pharmac...
# 87  [myocardial, biomarkers, biomarker, troponin, ...
# 88  [transplantation, transplant, donor, transplan...
# 89  [echocardiography, echocardiographic, echocard...
# 90  [syndrome, adams, electrocardiography, stokes,...
#
#                                   Representative_Docs
# 0   [Sequential balloon dilatation for combined ao...
# 1   [OUTpatient intravenous LASix Trial in reducin...
# 2   [Changes in PPAR gene expression and myocardia...
# 3   [[Cardiac arrest management: any news? When th...
# 4   [Ischemic mitral regurgitation: intraventricul...
# ..                                                ...
# 86  [Pharmacologic approaches to rhythm versus rat...
# 87  [Prediction of Recurrent Events by D-Dimer and...
# 88  [Development of a successful non-heart-beating...
# 89  [Detection of ventricular thrombi by ultrasoun...
# 90  [[TREATMENT OF THE ADAMS-STOKES SYNDROME]. , [...
#
# [91 rows x 5 columns]

# %%
topic_model_6._extract_words_per_topic()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-50-181325fd60b8> in <cell line: 1>()
# ----> 1 topic_model_6._extract_words_per_topic()
#
# TypeError: BERTopic._extract_words_per_topic() missing 2 required positional arguments: 'words' and 'documents'

# %%
# Step 3 - Cluster reduced embeddings
hdbscan_model = HDBSCAN(min_cluster_size=100, max_cluster_size=1000, leaf_size=20, metric='euclidean', cluster_selection_method='eom', prediction_data=True)

# All steps together
topic_model_7 = BERTopic(
  top_n_words=100,
  embedding_model=embedding_model,           # Step 1 - Extract embeddings
  umap_model=umap_model,                     # Step 2 - Reduce dimensionality
  hdbscan_model=hdbscan_model,               # Step 3 - Cluster reduced embeddings
  vectorizer_model=vectorizer_model,         # Step 4 - Tokenize topics
  ctfidf_model=ctfidf_model,                 # Step 5 - Extract topic words
  representation_model=representation_model, # Step 6 - (Optional) Fine-tune topic represenations
  seed_topic_list=seed,
  n_gram_range=(1,2)
)

topics_7, probs_7 = topic_model_7.fit_transform(docs_1['data'], y=docs_1['labels'])

df_7 = topic_model_7.get_topic_info()
df_7
# Out:
#     Topic  Count                                               Name  \
# 0      -1   3489  -1_cardiovascular_echocardiography_cardiac_ven...
# 1       0    886    0_ventricular_ventricle_atrioventricular_aortic
# 2       1    775    1_inhibitor_cardioprotective_myocardial_cardiac
# 3       2    515  2_tachyarrhythmias_antiarrhythmic_arrhythmias_...
# 4       3    446               3_aortic_tavi_transcatheter_stenosis
# 5       4    433  4_cardiac_myocarditis_endocarditis_echocardiog...
# 6       5    400        5_trisomy_abnormalities_syndrome_congenital
# 7       6    276  6_atrial_fibrillation_cardioversion_anticoagul...
# 8       7    265    7_resuscitation_resuscitated_defibrillation_cpr
# 9       8    220  8_mitral_regurgitation_echocardiography_ventri...
# 10      9    190   9_coronary_atherosclerosis_cardiovascular_angina
# 11     10    105  10_stenosis_angiodysplasia_aortoarteritis_sten...
#
#                                        Representation  \
# 0   [cardiovascular, echocardiography, cardiac, ve...
# 1   [ventricular, ventricle, atrioventricular, aor...
# 2   [inhibitor, cardioprotective, myocardial, card...
# 3   [tachyarrhythmias, antiarrhythmic, arrhythmias...
# 4   [aortic, tavi, transcatheter, stenosis, valve,...
# 5   [cardiac, myocarditis, endocarditis, echocardi...
# 6   [trisomy, abnormalities, syndrome, congenital,...
# 7   [atrial, fibrillation, cardioversion, anticoag...
# 8   [resuscitation, resuscitated, defibrillation, ...
# 9   [mitral, regurgitation, echocardiography, vent...
# 10  [coronary, atherosclerosis, cardiovascular, an...
# 11  [stenosis, angiodysplasia, aortoarteritis, ste...
#
#                                   Representative_Docs
# 0   [Risk factors for sepsis and endocarditis and ...
# 1   [Biventricular repair of transposition of the ...
# 2   [A review of heart failure management in the e...
# 3   [Combined use of time and frequency domain var...
# 4   [The Outcomes of Pulmonary Hypertension Patien...
# 5   [Pediatric cardiac tumors: a 45-year, single-i...
# 6   [Gender Dysphoria and Gender Change in Disorde...
# 7   [[Analysis of risk factors for all cause-morta...
# 8   [Duration of cardiopulmonary resuscitation in ...
# 9   [How does the use of polytetrafluoroethylene n...
# 10  [[Diagnostic and prognostic value of atheroscl...
# 11  [Endoscopic diagnosis and therapy of mucosal v...

# %%
topic_model_7.visualize_topics()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="cc062c10-b871-4276-bd13-29c082aba258" class="plotly-graph-div" style="height:650px; width:650px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("cc062c10-b871-4276-bd13-29c082aba258")) {                    Plotly.newPlot(                        "cc062c10-b871-4276-bd13-29c082aba258",                        [{"customdata":[[0,"ventricular | ventricle | atrioventricular | aortic | regurgitation",886],[1,"inhibitor | cardioprotective | myocardial | cardiac | angiotensin",775],[2,"tachyarrhythmias | antiarrhythmic | arrhythmias | tachycardia | arrhythmia",515],[3,"aortic | tavi | transcatheter | stenosis | valve",446],[4,"cardiac | myocarditis | endocarditis | echocardiography | intracardiac",433],[5,"trisomy | abnormalities | syndrome | congenital | syndromes",400],[6,"atrial | fibrillation | cardioversion | anticoagulation | anticoagulants",276],[7,"resuscitation | resuscitated | defibrillation | cpr | cardiopulmonary",265],[8,"mitral | regurgitation | echocardiography | ventricular | echocardiographic",220],[9,"coronary | atherosclerosis | cardiovascular | angina | angioplasty",190],[10,"stenosis | angiodysplasia | aortoarteritis | stenocardiac | aorta",105]],"hovertemplate":"\u003cb\u003eTopic %{customdata[0]}\u003c\u002fb\u003e\u003cbr\u003e%{customdata[1]}\u003cbr\u003eSize: %{customdata[2]}","legendgroup":"","marker":{"color":"#B0BEC5","size":[886,775,515,446,433,400,276,265,220,190,105],"sizemode":"area","sizeref":0.55375,"symbol":"circle","line":{"color":"DarkSlateGrey","width":2}},"mode":"markers","name":"","orientation":"v","showlegend":false,"x":[6.602290153503418,-2.915616512298584,-7.864007472991943,7.34503698348999,6.18154764175415,5.9958391189575195,-8.553065299987793,-8.092845916748047,7.703726291656494,-3.2006778717041016,7.010129928588867],"xaxis":"x","y":[6.132650852203369,18.683088302612305,-17.882966995239258,5.152825832366943,5.616093158721924,6.229490280151367,-18.571910858154297,-18.111377716064453,5.288158893585205,18.968130111694336,5.591395378112793],"yaxis":"y","type":"scatter"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"rgb(36,36,36)"},"error_y":{"color":"rgb(36,36,36)"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"rgb(36,36,36)","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"rgb(36,36,36)"},"baxis":{"endlinecolor":"rgb(36,36,36)","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"rgb(36,36,36)"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde ...

# %% [markdown]
# #### Edit seed topic list

# %%
unique_seed = []

# Iterate through the list of strings
for ls in seed:
    unique_list = set()

    for string in ls:

        words = string.split()
        unique_list.update(words)

    unique_seed.append(list(unique_list))

# %%
topic_model_8 = BERTopic(
  embedding_model=embedding_model,           # Step 1 - Extract embeddings
  umap_model=umap_model,                     # Step 2 - Reduce dimensionality
  hdbscan_model=hdbscan_model,               # Step 3 - Cluster reduced embeddings
  vectorizer_model=vectorizer_model,         # Step 4 - Tokenize topics
  ctfidf_model=ctfidf_model,                 # Step 5 - Extract topic words
  representation_model=representation_model, # Step 6 - (Optional) Fine-tune topic represenations
  seed_topic_list=unique_seed,
)

topics_8, probs_8 = topic_model_8.fit_transform(docs_1['data'], y=docs_1['labels'])

df_8 = topic_model_8.get_topic_info()
df_8
# Out:
#     Topic  Count                                               Name  \
# 0      -1   4057  -1_echocardiography_ventricular_cardiac_ventricle
# 1       0    814  0_cardiovascular_cardiomyocytes_cardioprotecti...
# 2       1    432                   1_aortic_tavi_stentless_stenosis
# 3       2    401  2_coronary_stenting_cardiovascular_atheroscler...
# 4       3    343  3_tachyarrhythmias_antiarrhythmic_arrhythmias_...
# 5       4    297        4_atrial_antiarrhythmic_ablation_arrhythmia
# 6       5    273  5_endocarditis_myocarditis_myopericarditis_per...
# 7       6    270  6_resuscitation_resuscitated_defibrillation_po...
# 8       7    198  7_mitral_regurgitation_echocardiography_ventri...
# 9       8    186  8_ventricular_ventricle_atrioventricular_stenosis
# 10      9    185              9_cardiac_leiomyosarcoma_tumor_tumors
# 11     10    174                10_hormone_hormonal_trisomy_ovarian
# 12     11    132     11_abnormalities_congenital_syndrome_syndromes
# 13     12    120            12_pacemaker_ventricular_cardiac_pacing
# 14     13    118            13_aortic_stenosis_aorta_aortoarteritis
#
#                                        Representation  \
# 0   [echocardiography, ventricular, cardiac, ventr...
# 1   [cardiovascular, cardiomyocytes, cardioprotect...
# 2   [aortic, tavi, stentless, stenosis, valves, va...
# 3   [coronary, stenting, cardiovascular, atheroscl...
# 4   [tachyarrhythmias, antiarrhythmic, arrhythmias...
# 5   [atrial, antiarrhythmic, ablation, arrhythmia,...
# 6   [endocarditis, myocarditis, myopericarditis, p...
# 7   [resuscitation, resuscitated, defibrillation, ...
# 8   [mitral, regurgitation, echocardiography, vent...
# 9   [ventricular, ventricle, atrioventricular, ste...
# 10  [cardiac, leiomyosarcoma, tumor, tumors, fibro...
# 11  [hormone, hormonal, trisomy, ovarian, deficien...
# 12  [abnormalities, congenital, syndrome, syndrome...
# 13  [pacemaker, ventricular, cardiac, pacing, pace...
# 14  [aortic, stenosis, aorta, aortoarteritis, sten...
#
#                                   Representative_Docs
# 0   [Left ventricular reconstruction: Early and la...
# 1   [Beneficial effect of prolonged heme oxygenase...
# 2   [Early- and mid-term outcomes of transcatheter...
# 3   [Relationship of interleukin-6-572C/G promoter...
# 4   [[Syncope in supraventricular tachycardia. Inc...
# 5   [Is there still a role for additional linear a...
# 6   [Bacteraemia during Transurethral Resection of...
# 7   [Usefulness of cooling and coronary catheteriz...
# 8   [Ischemic mitral regurgitation: intraventricul...
# 9   [Surgical management of double-outlet right ve...
# 10  [Massive right atrial myxoma with dyspnea at r...
# 11  [Current indications for growth hormone therap...
# 12  [Rare copy number variants and congenital hear...
# 13  [Permanent, direct His-bundle pacing: a novel ...
# 14  [Aortic root subadventitial hematoma. A 51-yea...

# %%
topic_model_8.visualize_topics()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="19f18f92-f2d2-4d6f-ba53-8186199a2bf5" class="plotly-graph-div" style="height:650px; width:650px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("19f18f92-f2d2-4d6f-ba53-8186199a2bf5")) {                    Plotly.newPlot(                        "19f18f92-f2d2-4d6f-ba53-8186199a2bf5",                        [{"customdata":[[0,"cardiovascular | cardiomyocytes | cardioprotective | myocardial | cardiac",814],[1,"aortic | tavi | stentless | stenosis | valves",432],[2,"coronary | stenting | cardiovascular | atherosclerosis | angina",401],[3,"tachyarrhythmias | antiarrhythmic | arrhythmias | tachycardia | arrhythmia",343],[4,"atrial | antiarrhythmic | ablation | arrhythmia | fibrillation",297],[5,"endocarditis | myocarditis | myopericarditis | pericarditis | infection",273],[6,"resuscitation | resuscitated | defibrillation | postresuscitation | cpr",270],[7,"mitral | regurgitation | echocardiography | ventricular | echocardiographic",198],[8,"ventricular | ventricle | atrioventricular | stenosis | congenital",186],[9,"cardiac | leiomyosarcoma | tumor | tumors | fibroelastoma",185],[10,"hormone | hormonal | trisomy | ovarian | deficiency",174],[11,"abnormalities | congenital | syndrome | syndromes | mutations",132],[12,"pacemaker | ventricular | cardiac | pacing | pacemaking",120],[13,"aortic | stenosis | aorta | aortoarteritis | stenocardiac",118]],"hovertemplate":"\u003cb\u003eTopic %{customdata[0]}\u003c\u002fb\u003e\u003cbr\u003e%{customdata[1]}\u003cbr\u003eSize: %{customdata[2]}","legendgroup":"","marker":{"color":"#B0BEC5","size":[814,432,401,343,297,273,270,198,186,185,174,132,120,118],"sizemode":"area","sizeref":0.50875,"symbol":"circle","line":{"color":"DarkSlateGrey","width":2}},"mode":"markers","name":"","orientation":"v","showlegend":false,"x":[-5.442545413970947,11.159207344055176,-5.734470844268799,14.122745513916016,13.910730361938477,-2.5394816398620605,-5.081614971160889,11.19523811340332,10.697527885437012,-2.3696792125701904,17.334705352783203,17.06243133544922,14.454882621765137,10.892224311828613],"xaxis":"x","y":[6.24628210067749,-0.2114323526620865,6.537804126739502,-15.395270347595215,-15.606903076171875,-4.865581035614014,5.885555267333984,0.2240622192621231,-0.9739515781402588,-4.695821285247803,-1.8300436735153198,-1.5571554899215698,-15.063106536865234,-0.7820208072662354],"yaxis":"y","type":"scatter"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"rgb(36,36,36)"},"error_y":{"color":"rgb(36,36,36)"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"rgb(36,36,36)","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"rgb(36,36,36)"},"baxis":{"endlinecolor":"rgb(36,36,36)","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"rgb(36,36,36)"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":1,"tickcolo ...

# %%
# Define a list of lists containing words
list_of_lists = unique_seed.copy()

# Create a set to store words that have been seen
seen_words = set()

# Create a set to store overlapping words
overlapping_words = set()

# Iterate through the list of lists
for word_list in list_of_lists:
    for word in word_list:
        # If the word has been seen before, add it to the overlapping set
        if word in seen_words:
            overlapping_words.add(word)
        else:
            seen_words.add(word)

# Create a new list of lists without overlapping words
new_unique_seed = []

# Iterate through the original list of lists
for word_list in list_of_lists:
    # Create a new list containing words that are not in the overlapping set
    unique_word_list = [word for word in word_list if word not in overlapping_words]

    # Add the unique word list to the new list of lists
    new_unique_seed.append(unique_word_list)

# new_list_of_lists now contains lists without overlapping words

# %%
[len(x) for x in new_unique_seed]
# Out:
# [91, 15, 184, 20, 59, 1, 3, 73]

# %%
# Define a list of lists containing words
list_of_lists = seed.copy()

# Create a set to store words that have been seen
seen_words = set()

# Create a set to store overlapping words
overlapping_words = set()

# Iterate through the list of lists
for word_list in list_of_lists:
    for word in word_list:
        # If the word has been seen before, add it to the overlapping set
        if word in seen_words:
            overlapping_words.add(word)
        else:
            seen_words.add(word)

# Create a new list of lists without overlapping words
new_seed = []

# Iterate through the original list of lists
for word_list in list_of_lists:
    # Create a new list containing words that are not in the overlapping set
    unique_word_list = [word for word in word_list if word not in overlapping_words]

    # Add the unique word list to the new list of lists
    new_seed.append(unique_word_list)

# new_list_of_lists now contains lists without overlapping words

# %%
[len(x) for x in new_seed]
# Out:
# [92, 28, 204, 64, 80, 4, 7, 102]

# %%
category2synonyms.keys()
# Out:
# dict_keys(['CM', 'ARR', 'CHD', 'VD', 'IHD', 'CCD', 'VOO', 'OTH'])

# %%
new_seed[5:7]
# Out:
# [['Cardiac Conduction Defects',
#   'Cardiac Conduction System Diseases',
#   'Cardiac Conduction System Disease',
#   'Cardiac Conduction Defect'],
#  ['Outflow Obstruction, Right Ventricular',
#   'Outflow Obstruction, Left Ventricular',
#   'Ventricular Outflow Obstruction, Left',
#   'Right Ventricular Outflow Obstruction',
#   'Ventricular Outflow Obstruction',
#   'Ventricular Outflow Obstruction, Right',
#   'Left Ventricular Outflow Obstruction']]

# %%
list_of_lists = seed.copy()

# Create a set to store words that have been seen
seen_words = {}

# Create a set to store overlapping words
overlapping_words = {}

# Iterate through the list of lists
for idx, word_list in enumerate(list_of_lists):
    for word in word_list:
        # If the word has been seen before, add it to the overlapping set
        if word in seen_words:
            if word in overlapping_words:
                overlapping_words[word].append(idx)
            else:
                overlapping_words[word] = [seen_words[word], idx]
            overlapping_words[word] = list(set(overlapping_words[word]))
        else:
            seen_words[word] = idx

# %% [markdown]
# To-do list: 09/05
# - change the weights of the seed to 2 or 3 (line 3506 in _bertopic.py)
# - run the topic reduction on the model we already had
# - fuzzy synonym matching

# %% [markdown]
# #### with seed = 2

# %%
topic_model_6.reduce_topics(docs_1_, nr_topics=9)

# %%
df_6_ = topic_model_6.get_topic_info()
df_6_
# Out:
#    Topic  Count                                               Name  \
# 0     -1   2948          -1_stenosis_echocardiography_aorta_aortic
# 1      0   1520       0_ventricular_aortic_regurgitation_ventricle
# 2      1   1374   1_cardiovascular_coronary_myocardial_angiotensin
# 3      2   1207    2_antiarrhythmic_arrhythmias_arrhythmia_cardiac
# 4      3    553  3_cardiac_cardiomyopathy_myocarditis_echocardi...
# 5      4    310         4_trisomy_abnormalities_disorders_syndrome
# 6      5     36     5_ventricle_diagnosis_atrioventricular_ebstein
# 7      6     29  6_clinical_clinicopathological_clinicoradiolog...
# 8      7     23           7_commentary_invited_discussion_response
#
#                                       Representation  \
# 0  [stenosis, echocardiography, aorta, aortic, ca...
# 1  [ventricular, aortic, regurgitation, ventricle...
# 2  [cardiovascular, coronary, myocardial, angiote...
# 3  [antiarrhythmic, arrhythmias, arrhythmia, card...
# 4  [cardiac, cardiomyopathy, myocarditis, echocar...
# 5  [trisomy, abnormalities, disorders, syndrome, ...
# 6  [ventricle, diagnosis, atrioventricular, ebste...
# 7  [clinical, clinicopathological, clinicoradiolo...
# 8  [commentary, invited, discussion, response, , ...
#
#                                  Representative_Docs
# 0  [Comparison of procedural and in-hospital outc...
# 1  [Should high risk patients with concomitant se...
# 2  [Augmentation of endogenous adenosine attenuat...
# 3  [Congenital long QT syndrome. Congenital long ...
# 4  [Surgical Treatment of Cardiac Tumors: Insight...
# 5  [Gender Dysphoria and Gender Change in Disorde...
# 6  [Multiplanar review of three-dimensional echoc...
# 7  [Case records of the Massachusetts General Hos...
# 8  [Invited Commentary. , Invited commentary. , I...

# %%
', '.join(list(topic_model_6.get_topic_info(-1)['Representation'])[0])
# Out:
# 'echocardiography, aortic, aorta, stenosis, ventricular, cardiovascular, atrioventricular, ventricle, artery, coronary'

# %%
topic_model_7.reduce_topics(docs_1['data'], nr_topics=9)
df_7_ = topic_model_7.get_topic_info()
df_7_
# Out:
#    Topic  Count                                               Name  \
# 0     -1   3441  -1_echocardiography_cardiac_ventricular_cardio...
# 1      0   1239   0_ventricular_ventricle_cardiac_atrioventricular
# 2      1   1146   1_cardiovascular_coronary_angiotensin_myocardial
# 3      2    547               2_aortic_transcatheter_tavi_stenosis
# 4      3    450  3_tachyarrhythmias_tachycardia_antiarrhythmic_...
# 5      4    397        4_trisomy_abnormalities_congenital_syndrome
# 6      5    276  5_resuscitation_resuscitated_postresuscitation...
# 7      6    273       6_atrial_fibrillation_cardioversion_ablation
# 8      7    231  7_mitral_regurgitation_ventricular_echocardiog...
#
#                                       Representation  \
# 0  [echocardiography, cardiac, ventricular, cardi...
# 1  [ventricular, ventricle, cardiac, atrioventric...
# 2  [cardiovascular, coronary, angiotensin, myocar...
# 3  [aortic, transcatheter, tavi, stenosis, transf...
# 4  [tachyarrhythmias, tachycardia, antiarrhythmic...
# 5  [trisomy, abnormalities, congenital, syndrome,...
# 6  [resuscitation, resuscitated, postresuscitatio...
# 7  [atrial, fibrillation, cardioversion, ablation...
# 8  [mitral, regurgitation, ventricular, echocardi...
#
#                                  Representative_Docs
# 0  [Hemodynamic findings during exercise on a bic...
# 1  [Intracardiac repair of lesions associated wit...
# 2  [[Diagnostic and prognostic value of atheroscl...
# 3  [The Outcomes of Pulmonary Hypertension Patien...
# 4  [Role of late potentials in identifying patien...
# 5  [Etiological classification and clinical asses...
# 6  [Usefulness of cooling and coronary catheteriz...
# 7  [Novel surgical ablation through a septal-supe...
# 8  [How does the use of polytetrafluoroethylene n...

# %%
topic_model_7.visualize_topics()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="52473559-d13e-4484-9d81-f63326b4455a" class="plotly-graph-div" style="height:650px; width:650px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("52473559-d13e-4484-9d81-f63326b4455a")) {                    Plotly.newPlot(                        "52473559-d13e-4484-9d81-f63326b4455a",                        [{"customdata":[[0,"ventricular | ventricle | cardiac | atrioventricular | echocardiography",1239],[1,"cardiovascular | coronary | angiotensin | myocardial | angina",1146],[2,"aortic | transcatheter | tavi | stenosis | transfemoral",547],[3,"tachyarrhythmias | tachycardia | antiarrhythmic | arrhythmias | electrocardiographic",450],[4,"trisomy | abnormalities | congenital | syndrome | syndromes",397],[5,"resuscitation | resuscitated | postresuscitation | cardiopulmonary | defibrillation",276],[6,"atrial | fibrillation | cardioversion | ablation | thromboembolism",273],[7,"mitral | regurgitation | ventricular | echocardiography | cardiomyopathy",231]],"hovertemplate":"\u003cb\u003eTopic %{customdata[0]}\u003c\u002fb\u003e\u003cbr\u003e%{customdata[1]}\u003cbr\u003eSize: %{customdata[2]}","legendgroup":"","marker":{"color":"#B0BEC5","size":[1239,1146,547,450,397,276,273,231],"sizemode":"area","sizeref":0.774375,"symbol":"circle","line":{"color":"DarkSlateGrey","width":2}},"mode":"markers","name":"","orientation":"v","showlegend":false,"x":[20.111682891845703,1.772591233253479,18.929798126220703,0.44322311878204346,20.073102951049805,1.477937936782837,-0.032844267785549164,19.416419982910156],"xaxis":"x","y":[5.638485908508301,13.803768157958984,5.336249828338623,15.121485710144043,6.22935152053833,14.094374656677246,15.59337043762207,5.472646236419678],"yaxis":"y","type":"scatter"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"rgb(36,36,36)"},"error_y":{"color":"rgb(36,36,36)"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"rgb(36,36,36)","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"rgb(36,36,36)"},"baxis":{"endlinecolor":"rgb(36,36,36)","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"rgb(36,36,36)"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"type":"heatmapgl"}],"heatmap":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779 ...

# %%
topic_model_1.reduce_topics(docs_1['data'], nr_topics=9)
df_1_ = topic_model_1.get_topic_info()
df_1_
# Out:
#    Topic  Count                                   Name  \
# 0     -1   3038                       -1_the_of_and_in
# 1      0   2456                        0_the_of_and_in
# 2      1   2028                        1_the_of_and_in
# 3      2    315                   2_the_of_syndrome_in
# 4      3     47                 3_the_case_practice_of
# 5      4     46                        4_of_and_the_in
# 6      5     30        5_lyme_adamsstokes_psoriasis_of
# 7      6     27  6_invited_commentary_discussion_reply
# 8      7     13    7_digitalis_glycosides_treatment_of
#
#                                       Representation  \
# 0  [the, of, and, in, with, to, patients, was, fo...
# 1  [the, of, and, in, to, with, patients, was, we...
# 2  [the, of, and, in, with, to, valve, aortic, pa...
# 3  [the, of, syndrome, in, and, with, to, is, pat...
# 4  [the, case, practice, of, to, massachusetts, y...
# 5  [of, and, the, in, with, intoxication, to, wer...
# 6  [lyme, adamsstokes, psoriasis, of, syndrome, c...
# 7  [invited, commentary, discussion, reply, rouma...
# 8  [digitalis, glycosides, treatment, of, sdigoxi...
#
#                                  Representative_Docs
# 0  [Ascending aortic aneurysms in unicommissural ...
# 1  [[Correlation of the parameters of myocardial ...
# 2  [Ross procedure in congenital patients: result...
# 3  [Social and medical determinants of quality of...
# 4  [Case records of the Massachusetts General Hos...
# 5  [Clinicopathologic analysis of cardiac dysfunc...
# 6  [Successful treatment of hand and foot psorias...
# 7  [Invited commentary. , Invited commentary. , I...
# 8  [[DIGITALIS GLYCOSIDES IN RHYTHM DISORDERS]. ,...

# %%
topic_model_1.visualize_topics()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="6bee049d-4d45-46ad-a1c3-f5094d61750d" class="plotly-graph-div" style="height:650px; width:650px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("6bee049d-4d45-46ad-a1c3-f5094d61750d")) {                    Plotly.newPlot(                        "6bee049d-4d45-46ad-a1c3-f5094d61750d",                        [{"customdata":[[0,"the | of | and | in | to",2456],[1,"the | of | and | in | with",2028],[2,"the | of | syndrome | in | and",315],[3,"the | case | practice | of | to",47],[4,"of | and | the | in | with",46],[5,"lyme | adamsstokes | psoriasis | of | syndrome",30],[6,"invited | commentary | discussion | reply | rouman",27],[7,"digitalis | glycosides | treatment | of | sdigoxin",13]],"hovertemplate":"\u003cb\u003eTopic %{customdata[0]}\u003c\u002fb\u003e\u003cbr\u003e%{customdata[1]}\u003cbr\u003eSize: %{customdata[2]}","legendgroup":"","marker":{"color":"#B0BEC5","size":[2456,2028,315,47,46,30,27,13],"sizemode":"area","sizeref":1.535,"symbol":"circle","line":{"color":"DarkSlateGrey","width":2}},"mode":"markers","name":"","orientation":"v","showlegend":false,"x":[-5.277139663696289,-4.2395710945129395,-4.893250465393066,-3.539459466934204,-5.672917366027832,-5.0949530601501465,-3.016554594039917,-5.589747428894043],"xaxis":"x","y":[13.628087997436523,-8.470873832702637,-7.37307596206665,-8.22535514831543,13.343794822692871,-8.166055679321289,-8.067094802856445,-7.739692687988281],"yaxis":"y","type":"scatter"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"rgb(36,36,36)"},"error_y":{"color":"rgb(36,36,36)"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"rgb(36,36,36)","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"rgb(36,36,36)"},"baxis":{"endlinecolor":"rgb(36,36,36)","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"rgb(36,36,36)"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"type":"heatmapgl"}],"heatmap":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"type":"heatmap"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222 ...

# %%
topic_model_8.reduce_topics(docs_1['data'], nr_topics=9)
df_8_ = topic_model_8.get_topic_info()
df_8_
# Out:
#    Topic  Count                                               Name  \
# 0     -1   4057  -1_echocardiography_ventricular_cardiac_ventricle
# 1      0   1215       0_cardiovascular_coronary_cardiac_myocardial
# 2      1    736        1_aortic_ventricular_transcatheter_stenosis
# 3      2    463  2_tachyarrhythmias_antiarrhythmic_arrhythmias_...
# 4      3    458  3_cardiac_myocarditis_endocarditis_echocardiog...
# 5      4    306             4_hormone_trisomy_ovarian_hypogonadism
# 6      5    297      5_atrial_antiarrhythmic_fibrillation_ablation
# 7      6    270  6_resuscitation_resuscitated_defibrillation_po...
# 8      7    198  7_mitral_regurgitation_echocardiography_ventri...
#
#                                       Representation  \
# 0  [echocardiography, ventricular, cardiac, ventr...
# 1  [cardiovascular, coronary, cardiac, myocardial...
# 2  [aortic, ventricular, transcatheter, stenosis,...
# 3  [tachyarrhythmias, antiarrhythmic, arrhythmias...
# 4  [cardiac, myocarditis, endocarditis, echocardi...
# 5  [hormone, trisomy, ovarian, hypogonadism, abno...
# 6  [atrial, antiarrhythmic, fibrillation, ablatio...
# 7  [resuscitation, resuscitated, defibrillation, ...
# 8  [mitral, regurgitation, echocardiography, vent...
#
#                                  Representative_Docs
# 0  [Left ventricular reconstruction: Early and la...
# 1  [Prognostic value of uric acid in patients wit...
# 2  [Outcomes of definitive surgical repair for co...
# 3  [Combined use of time and frequency domain var...
# 4  [Pediatric cardiac tumors: a 45-year, single-i...
# 5  [Gender Dysphoria and Gender Change in Disorde...
# 6  [Novel surgical ablation through a septal-supe...
# 7  [Usefulness of cooling and coronary catheteriz...
# 8  [How does the use of polytetrafluoroethylene n...

# %%
topic_model_8.visualize_topics()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="00e1d123-1ffa-4b1f-8fb1-df7994510e96" class="plotly-graph-div" style="height:650px; width:650px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("00e1d123-1ffa-4b1f-8fb1-df7994510e96")) {                    Plotly.newPlot(                        "00e1d123-1ffa-4b1f-8fb1-df7994510e96",                        [{"customdata":[[0,"cardiovascular | coronary | cardiac | myocardial | angina",1215],[1,"aortic | ventricular | transcatheter | stenosis | tavi",736],[2,"tachyarrhythmias | antiarrhythmic | arrhythmias | tachycardia | arrhythmia",463],[3,"cardiac | myocarditis | endocarditis | echocardiography | pericarditis",458],[4,"hormone | trisomy | ovarian | hypogonadism | abnormalities",306],[5,"atrial | antiarrhythmic | fibrillation | ablation | arrhythmia",297],[6,"resuscitation | resuscitated | defibrillation | postresuscitation | cardiopulmonary",270],[7,"mitral | regurgitation | echocardiography | ventricular | echocardiographic",198]],"hovertemplate":"\u003cb\u003eTopic %{customdata[0]}\u003c\u002fb\u003e\u003cbr\u003e%{customdata[1]}\u003cbr\u003eSize: %{customdata[2]}","legendgroup":"","marker":{"color":"#B0BEC5","size":[1215,736,463,458,306,297,270,198],"sizemode":"area","sizeref":0.759375,"symbol":"circle","line":{"color":"DarkSlateGrey","width":2}},"mode":"markers","name":"","orientation":"v","showlegend":false,"x":[20.65624237060547,12.48187255859375,21.397480010986328,17.05769920349121,17.248565673828125,21.53078269958496,20.834877014160156,12.811844825744629],"xaxis":"x","y":[12.95215892791748,-5.573309421539307,14.14856243133545,16.07483673095703,15.577707290649414,13.539154052734375,13.99669075012207,-5.903529644012451],"yaxis":"y","type":"scatter"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"rgb(36,36,36)"},"error_y":{"color":"rgb(36,36,36)"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"rgb(36,36,36)","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"rgb(36,36,36)"},"baxis":{"endlinecolor":"rgb(36,36,36)","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"rgb(36,36,36)"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"type":"heatmapgl"}],"heatmap":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778," ...

# %%
topic_model_0 = BERTopic(seed_topic_list=seed, n_gram_range=(1,4))
topics_0, probs_0 = topic_model_0.fit_transform(docs_1_)

# %%
topic_model_0.reduce_topics(docs_1_, nr_topics=9)
df_0_ = topic_model_0.get_topic_info()
df_0_
# Out:
#    Topic  Count                                               Name  \
# 0     -1   2813                                   -1_the_of_and_in
# 1      0   2621                                    0_the_of_and_in
# 2      1   1439                                    1_the_of_and_in
# 3      2   1022                                    2_the_of_and_in
# 4      3     35                               3_ebsteins_the_of_in
# 5      4     34  4_case_the_case records of the_records of the ...
# 6      5     13                5_digitalis_of_glycosides_treatment
# 7      6     12  6_invited commentary_invited_commentary_discus...
# 8      7     11  7_reply hard_reply hard lightning_lightning_ha...
#
#                                       Representation  \
# 0  [the, of, and, in, with, to, patients, was, fo...
# 1  [the, of, and, in, with, to, patients, was, of...
# 2  [the, of, and, in, with, to, patients, was, fo...
# 3  [the, of, and, in, to, with, patients, was, he...
# 4  [ebsteins, the, of, in, tricuspid, of the, ano...
# 5  [case, the, case records of the, records of th...
# 6  [digitalis, of, glycosides, treatment, intoxic...
# 7  [invited commentary, invited, commentary, disc...
# 8  [reply hard, reply hard lightning, lightning, ...
#
#                                  Representative_Docs
# 0  [Estimation of the left ventricular diastolic ...
# 1  [Early left ventricular remodeling after aorti...
# 2  [[Establishment of porcine model of prolonged ...
# 3  [Developmental changes in tolerance to ischaem...
# 4  [Long-term ECG in ambulatory clinical practice...
# 5  [Case records of the Massachusetts General Hos...
# 6  [Digitalis intoxication. , Digitalis therapy i...
# 7  [Invited commentary. , Invited commentary. , I...
# 8                     [Reply. , Hard. , Lightning. ]

# %% [markdown]
# To-do:
# - see if we can edit the number of words in Representation
# - compare the Representation words to the synonyms
# - see if we can edit the English stop words in the vectorizer model

# %% [markdown]
# ### Manual modeling

# %%
from sklearn.datasets import fetch_20newsgroups

# Get labeled data
data = fetch_20newsgroups(subset='all',  remove=('headers', 'footers', 'quotes'))
docs = data['data']
y = data['target']

# %%
from bertopic import BERTopic
from bertopic.backend import BaseEmbedder
from bertopic.cluster import BaseCluster
from bertopic.vectorizers import ClassTfidfTransformer
from bertopic.dimensionality import BaseDimensionalityReduction

# Prepare our empty sub-models and reduce frequent words while we are at it.
empty_embedding_model = BaseEmbedder()
empty_dimensionality_model = BaseDimensionalityReduction()
empty_cluster_model = BaseCluster()
ctfidf_model = ClassTfidfTransformer(reduce_frequent_words=True)

# Fit BERTopic without actually performing any clustering
topic_model= BERTopic(
        embedding_model=empty_embedding_model,
        umap_model=empty_dimensionality_model,
        hdbscan_model=empty_cluster_model,
        ctfidf_model=ctfidf_model
)
# topics, probs = topic_model.fit_transform(docs, y=y)

# %%
docs_1.keys()
# Out:
# dict_keys(['data', 'labels', 'names'])

# %%
# Map input `y` to topics
mappings = topic_model.topic_mapper_.get_mappings()
mappings = {value: data["target_names"][key] for key, value in mappings.items()}

# Assign original classes to our topics
df = topic_model.get_topic_info()
df["Class"] = df.Topic.map(mappings)
df

# %%
# Prepare our empty sub-models and reduce frequent words while we are at it.
empty_embedding_model = BaseEmbedder()
empty_dimensionality_model = BaseDimensionalityReduction()
empty_cluster_model = BaseCluster()
ctfidf_model = ClassTfidfTransformer(reduce_frequent_words=True)

# Fit BERTopic without actually performing any clustering
topic_model= BERTopic(
        embedding_model=empty_embedding_model,
        umap_model=empty_dimensionality_model,
        hdbscan_model=empty_cluster_model,
        ctfidf_model=ctfidf_model
)
topics, probs = topic_model.fit_transform(docs_1['data'], y=docs_1['labels'])

# %%
mappings = topic_model.topic_mapper_.get_mappings()
mappings = {value: docs_1["names"][key] for key, value in mappings.items()}

# Assign original classes to our topics
df = topic_model.get_topic_info()
df["Class"] = df.Topic.map(mappings)
df
# Out:
#    Topic  Count                                 Name  \
# 0      0   1000                0_failure_heart_hf_in
# 1      1   1000        1_af_atrial_fibrillation_with
# 2      2   1000               2_syndrome_the_of_with
# 3      3   1000  3_valve_mitral_aortic_regurgitation
# 4      4   1000  4_coronary_myocardial_infarction_in
# 5      5   1000   5_block_tachycardia_qt_ventricular
# 6      6   1000     6_aortic_valve_stenosis_patients
# 7      7   1000      7_arrest_cardiac_hypertrophy_of
#
#                                       Representation  \
# 0  [failure, heart, hf, in, and, to, of, with, th...
# 1  [af, atrial, fibrillation, with, patients, of,...
# 2  [syndrome, the, of, with, artery, and, in, pul...
# 3  [valve, mitral, aortic, regurgitation, patient...
# 4  [coronary, myocardial, infarction, in, of, and...
# 5  [block, tachycardia, qt, ventricular, the, in,...
# 6  [aortic, valve, stenosis, patients, tavr, repl...
# 7  [arrest, cardiac, hypertrophy, of, and, to, in...
#
#                                  Representative_Docs Class
# 0  [Mode of death in heart failure: findings from...    CM
# 1  [Tachycardias of right ventricular origin. Ven...    CM
# 2  [Right Ventricular Outflow Tract Reconstructio...    CM
# 3  [[Percutaneous balloon valvuloplasty for sever...    CM
# 4  [Bivalirudin versus heparin with or without gl...    CM
# 5  [Effect of propranolol on ventricular rate dur...    CM
# 6  [Repair of interrupted aortic arch: a ten-year...    CM
# 7  [Successful use of therapeutic hypothermia aft...    CM

# %%
topic_model.get_topic_info()
# Out:
#    Topic  Count                                 Name  \
# 0      0   1000                0_failure_heart_hf_in
# 1      1   1000        1_af_atrial_fibrillation_with
# 2      2   1000               2_syndrome_the_of_with
# 3      3   1000  3_valve_mitral_aortic_regurgitation
# 4      4   1000  4_coronary_myocardial_infarction_in
# 5      5   1000   5_block_tachycardia_qt_ventricular
# 6      6   1000     6_aortic_valve_stenosis_patients
# 7      7   1000      7_arrest_cardiac_hypertrophy_of
#
#                                       Representation  \
# 0  [failure, heart, hf, in, and, to, of, with, th...
# 1  [af, atrial, fibrillation, with, patients, of,...
# 2  [syndrome, the, of, with, artery, and, in, pul...
# 3  [valve, mitral, aortic, regurgitation, patient...
# 4  [coronary, myocardial, infarction, in, of, and...
# 5  [block, tachycardia, qt, ventricular, the, in,...
# 6  [aortic, valve, stenosis, patients, tavr, repl...
# 7  [arrest, cardiac, hypertrophy, of, and, to, in...
#
#                                  Representative_Docs
# 0  [Mode of death in heart failure: findings from...
# 1  [Tachycardias of right ventricular origin. Ven...
# 2  [Right Ventricular Outflow Tract Reconstructio...
# 3  [[Percutaneous balloon valvuloplasty for sever...
# 4  [Bivalirudin versus heparin with or without gl...
# 5  [Effect of propranolol on ventricular rate dur...
# 6  [Repair of interrupted aortic arch: a ten-year...
# 7  [Successful use of therapeutic hypothermia aft...

# %%
topic_model.visualize_topics()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="b868f489-38a9-416a-9f39-ecc681f8b94f" class="plotly-graph-div" style="height:650px; width:650px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("b868f489-38a9-416a-9f39-ecc681f8b94f")) {                    Plotly.newPlot(                        "b868f489-38a9-416a-9f39-ecc681f8b94f",                        [{"customdata":[[0,"failure | heart | hf | in | and",1000],[1,"af | atrial | fibrillation | with | patients",1000],[2,"syndrome | the | of | with | artery",1000],[3,"valve | mitral | aortic | regurgitation | patients",1000],[4,"coronary | myocardial | infarction | in | of",1000],[5,"block | tachycardia | qt | ventricular | the",1000],[6,"aortic | valve | stenosis | patients | tavr",1000],[7,"arrest | cardiac | hypertrophy | of | and",1000]],"hovertemplate":"\u003cb\u003eTopic %{customdata[0]}\u003c\u002fb\u003e\u003cbr\u003e%{customdata[1]}\u003cbr\u003eSize: %{customdata[2]}","legendgroup":"","marker":{"color":"#B0BEC5","size":[1000,1000,1000,1000,1000,1000,1000,1000],"sizemode":"area","sizeref":0.625,"symbol":"circle","line":{"color":"DarkSlateGrey","width":2}},"mode":"markers","name":"","orientation":"v","showlegend":false,"x":[30.048629760742188,18.407115936279297,-5.276354789733887,-4.928918838500977,30.328474044799805,18.10306739807129,-4.57061767578125,30.904827117919922],"xaxis":"x","y":[23.46628761291504,-10.916296005249023,-3.822613477706909,-4.17052698135376,23.746721267700195,-10.612276077270508,-4.528231620788574,24.322561264038086],"yaxis":"y","type":"scatter"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"rgb(36,36,36)"},"error_y":{"color":"rgb(36,36,36)"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"rgb(36,36,36)","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"rgb(36,36,36)"},"baxis":{"endlinecolor":"rgb(36,36,36)","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"rgb(36,36,36)"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"type":"heatmapgl"}],"heatmap":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"type":"heatmap"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorsc ...

# %%
from sentence_transformers import SentenceTransformer

# %%
dir(embedding_model)

# %%
embedding_model = SentenceTransformer("all-MiniLM-L6-v2")
embeddings = embedding_model.embed(docs_1['data'][:10])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-24-1566e750ffc4> in <cell line: 2>()
#       1 embedding_model = SentenceTransformer("all-MiniLM-L6-v2")
# ----> 2 embeddings = embedding_model.embed(docs_1['data'][:10])
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in __getattr__(self, name)
#    1612             if name in modules:
#    1613                 return modules[name]
# -> 1614         raise AttributeError("'{}' object has no attribute '{}'".format(
#    1615             type(self).__name__, name))
#    1616
#
# AttributeError: 'SentenceTransformer' object has no attribute 'embed'

# %%
embeddings

# %%
topic_model.transform(docs_1['data'][:10])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-21-eff1c5070fa9> in <cell line: 1>()
# ----> 1 topic_model.transform(docs_1['data'][:10])
#
# /usr/local/lib/python3.10/dist-packages/bertopic/_bertopic.py in transform(self, documents, embeddings, images)
#     485         # Check if an embedding model was found
#     486         if embeddings is None:
# --> 487             raise ValueError("No embedding model was found to embed the documents."
#     488                              "Make sure when loading in the model using BERTopic.load()"
#     489                              "to also specify the embedding model.")
#
# ValueError: No embedding model was found to embed the documents.Make sure when loading in the model using BERTopic.load()to also specify the embedding model.

# %%
topic_model
